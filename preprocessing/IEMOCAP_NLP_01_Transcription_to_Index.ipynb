# %% [markdown]
# ### case 1 : using label
# ### case 2 : using G cloud speech api

# %% [markdown]
# ## 01 create voca from transcription

# %%
import os
import sys
import csv
import pickle
import numpy as np
from nlp_util import *
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/vincentwu-
# [nltk_data]     cmlab/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
lines = []
with open('../data/processed/IEMOCAP/processed_tran.csv') as f:
# with open('../data/processed/IEMOCAP/processed_tran_fromG.csv') as f:
    read = csv.reader(f)
    lines = [ x[1] for x in read]
    
token_lines = [ word_tokenize(x) for x in lines]
token_lines_lower = [ [t.lower() for t in x] for x in token_lines]

sent_len = [ len(x) for x in token_lines]
print(np.max(sent_len))
print(np.min(sent_len))
print(np.mean(sent_len))
print(np.std(sent_len))
# Out:
# 128
# 1
# 14.819005877079391
# 12.20187522097008

# %%
def read_data(dic, lines):

    for tokens in lines:
        
        for token in tokens:
            token = token.lower()
            
            if token in dic :
                dic[token] += 1
            else:
                dic[token] = 1
        
    return dic

# %%
dic_count = {}
dic_count = read_data(dic_count, token_lines_lower)
print('dic size : ' + str(len(dic_count)))
# Out:
# dic size : 3745

# %%
dic_count
# Out:
# {'excuse': 11,
#  'me': 1018,
#  '.': 12081,
#  'yeah': 654,
#  'is': 1298,
#  'there': 553,
#  'a': 2091,
#  'problem': 50,
#  '?': 3318,
#  'you': 5840,
#  'did': 568,
#  'were': 168,
#  'standing': 53,
#  'at': 442,
#  'the': 2544,
#  'beginning': 9,
#  'and': 2349,
#  'directed': 1,
#  'well': 725,
#  'what': 1423,
#  "'s": 2669,
#  'let': 188,
#  'change': 6,
#  'it': 3241,
#  'i': 6874,
#  "'m": 988,
#  'getting': 72,
#  'an': 134,
#  'id': 37,
#  'this': 1006,
#  'why': 390,
#  'here': 500,
#  'my': 734,
#  'wallet': 4,
#  'was': 737,
#  'stolen': 4,
#  'how': 366,
#  'am': 168,
#  'supposed': 85,
#  'to': 3240,
#  'get': 549,
#  'without': 23,
#  'does': 173,
#  'person': 45,
#  'in': 982,
#  'first': 100,
#  'place': 62,
#  'like': 1184,
#  'birth': 15,
#  'certificate': 18,
#  'who': 136,
#  'hell': 69,
#  'has': 75,
#  'yes': 258,
#  'but': 742,
#  ',': 6965,
#  'do': 2381,
#  "n't": 2485,
#  'have': 1012,
#  'anything': 157,
#  'any': 150,
#  'credit': 5,
#  'cards': 4,
#  'things': 143,
#  'on': 603,
#  'file': 16,
#  'that': 2422,
#  'out': 530,
#  'of': 1361,
#  'control': 13,
#  'long': 191,
#  'been': 252,
#  'working': 34,
#  'clearly': 5,
#  'know': 1704,
#  'supervisor': 22,
#  'or': 282,
#  'something': 252,
#  'would': 327,
#  '-': 105,
#  'appreciate': 6,
#  'your': 529,
#  'forms': 23,
#  'see': 353,
#  'them': 250,
#  'told': 88,
#  'line': 138,
#  'okay': 416,
#  'tell': 170,
#  'if': 488,
#  'are': 498,
#  'filling': 3,
#  'particular': 25,
#  'form': 74,
#  'z.x.four': 3,
#  'ca': 370,
#  '--': 923,
#  'not': 857,
#  'for': 852,
#  "'re": 773,
#  'going': 707,
#  'fill': 41,
#  'need': 201,
#  'different': 44,
#  'no': 914,
#  'another': 49,
#  'set': 26,
#  'prove': 18,
#  'actually': 73,
#  'pass': 24,
#  'along': 17,
#  'just': 1116,
#  'send': 40,
#  'separate': 1,
#  'one': 327,
#  'passport': 6,
#  '...': 314,
#  'student': 8,
#  ';': 105,
#  'go': 528,
#  'school': 57,
#  'we': 1272,
#  'keep': 56,
#  'access': 2,
#  'understand': 136,
#  'so': 879,
#  'complicated': 6,
#  'people': 190,
#  'when': 228,
#  'they': 637,
#  'simple': 5,
#  'too': 189,
#  'want': 657,
#  'huh': 59,
#  'fine': 90,
#  "'ll": 427,
#  'be': 766,
#  'right': 616,
#  'back': 266,
#  'mail': 9,
#  'saw': 29,
#  'letter': 14,
#  'put': 74,
#  'request': 4,
#  'guess': 116,
#  'everybody': 24,
#  'make': 185,
#  'sacrifices': 1,
#  'given': 16,
#  'more': 118,
#  'though': 62,
#  'babies': 2,
#  'over': 131,
#  'mothers': 1,
#  'with': 535,
#  'choice': 18,
#  'crying': 7,
#  'about': 394,
#  'fix': 4,
#  'kicking': 1,
#  'myself': 71,
#  'sign': 12,
#  'up': 354,
#  'because': 259,
#  'money': 91,
#  'seem': 34,
#  'doing': 126,
#  'thing': 219,
#  'then': 379,
#  'videotape': 1,
#  'everything': 140,
#  'maybe': 197,
#  'can': 615,
#  'stream': 1,
#  'last': 115,
#  'month': 15,
#  'find': 69,
#  'sitters': 1,
#  "'ve": 394,
#  'got': 411,
#  'friends': 17,
#  'moved': 2,
#  'day': 97,
#  'care': 89,
#  'down': 113,
#  'street': 3,
#  'mother': 36,
#  'close': 15,
#  'by': 54,
#  'lots': 20,
#  'letters': 30,
#  'pictures': 13,
#  'fair': 20,
#  'already': 41,
#  'done': 50,
#  'much': 192,
#  'think': 398,
#  'made': 45,
#  'sacrifice': 2,
#  'leave': 68,
#  'new': 135,
#  'baby': 26,
#  'kid': 37,
#  'trying': 72,
#  'way': 154,
#  'stupid': 48,
#  'war': 22,
#  'guys': 63,
#  'computers': 2,
#  'raise': 3,
#  'vegas': 3,
#  'awesome': 45,
#  'um': 139,
#  'married': 90,
#  'old': 30,
#  'town': 9,
#  'part': 23,
#  'chuck': 8,
#  '[': 271,
#  'laughter': 167,
#  ']': 271,
#  'um-': 73,
#  'very': 213,
#  'romantic': 6,
#  'slot': 2,
#  'machines': 1,
#  'uhuh': 4,
#  'he': 553,
#  'won': 1,
#  'big': 61,
#  'he-and': 1,
#  'realized': 13,
#  'only': 127,
#  'better': 85,
#  'as': 303,
#  'his': 136,
#  'bride': 1,
#  'hey': 54,
#  'said': 135,
#  'leaving': 11,
#  'next': 55,
#  'honeymoon': 3,
#  'cruise': 1,
#  'oh': 557,
#  'had': 216,
#  'even': 122,
#  'thought': 100,
#  'citizen': 3,
#  'totally': 31,
#  "i'll-": 1,
#  'internet': 8,
#  'husband': 2,
#  'boyfriend': 2,
#  'juggle': 2,
#  'two': 101,
#  'cheating': 1,
#  'hmm': 27,
#  'calling': 16,
#  'now': 303,
#  'likes': 5,
#  'tabs': 1,
#  'uh': 118,
#  'seven': 16,
#  'hundred': 49,
#  'fifty': 63,
#  'dollars': 54,
#  'penny': 2,
#  'slots': 3,
#  'plays': 2,
#  'played': 10,
#  'wheel': 3,
#  'fortune': 23,
#  'pennies': 3,
#  'giant': 4,
#  'like-': 22,
#  'bucks': 6,
#  'mmhmm': 22,
#  'cat': 2,
#  'children': 14,
#  'renamed': 1,
#  'brenda': 1,
#  'lumber': 1,
#  'janet': 1,
#  'she': 399,
#  'needs': 14,
#  'name': 50,
#  'each': 39,
#  'state': 5,
#  'into': 78,
#  'heard': 24,
#  'shut': 39,
#  'no-': 6,
#  'marry': 87,
#  'propose': 2,
#  'turned': 21,
#  'really': 319,
#  'mean': 715,
#  'citizenship': 2,
#  'in-': 4,
#  'england': 2,
#  'whatever': 48,
#  'visa': 3,
#  'visit': 3,
#  'time': 309,
#  'distance': 3,
#  'wait': 70,
#  'move': 31,
#  'those': 52,
#  'phone': 65,
#  'loves': 12,
#  'win': 10,
#  'wow': 44,
#  'fan': 3,
#  'quarters': 1,
#  'costs': 1,
#  'always': 119,
#  'end': 43,
#  'spending': 3,
#  'minute': 48,
#  'enough': 56,
#  'craig': 3,
#  'list': 6,
#  'all': 723,
#  'escort': 2,
#  'services': 2,
#  'looking': 43,
#  'figured': 15,
#  'monster': 3,
#  'lot': 102,
#  'reliable': 1,
#  'than': 68,
#  'some': 225,
#  'random': 6,
#  'free': 24,
#  'board': 1,
#  'kind': 128,
#  'job': 98,
#  'applied': 8,
#  'posting': 1,
#  'theatre': 4,
#  'great': 139,
#  'pick': 10,
#  'him': 278,
#  'resume': 5,
#  'just-': 30,
#  'call': 84,
#  'good': 244,
#  'sending': 4,
#  'information': 18,
#  'front': 17,
#  'telling': 18,
#  'piece': 8,
#  'paper': 9,
#  'trail': 1,
#  'following': 1,
#  'around': 123,
#  'before': 76,
#  '..i': 1,
#  'just-..i': 1,
#  'prejudiced': 1,
#  'discriminating': 1,
#  'against': 3,
#  'baloney': 2,
#  'please': 60,
#  'car': 57,
#  'riding': 5,
#  'bus': 18,
#  'saving': 2,
#  'environment': 3,
#  'interesting': 12,
#  'fantastic': 4,
#  'frustrated': 7,
#  'high': 6,
#  'mighty': 1,
#  'i-': 70,
#  'nobody': 77,
#  'ride': 5,
#  'tried': 24,
#  'regular': 11,
#  'jobs': 11,
#  'saying': 60,
#  'friend': 19,
#  'recommending': 1,
#  'manager': 28,
#  'house': 43,
#  'ago': 25,
#  'helpful': 12,
#  'should': 150,
#  'sit': 29,
#  'stuff': 72,
#  'write': 34,
#  'can-': 9,
#  'bring': 40,
#  'generally': 1,
#  'helps': 6,
#  'outline': 1,
#  'imagine': 11,
#  'sometimes': 34,
#  'necessarily': 2,
#  'affords': 1,
#  'wo': 68,
#  'taking': 12,
#  'try': 47,
#  'little': 272,
#  'harder': 5,
#  'say': 143,
#  'save': 1,
#  'carpool': 1,
#  'less': 13,
#  'take': 184,
#  'frustration': 1,
#  'refuse': 1,
#  'anyone': 6,
#  'i-i': 26,
#  'anger': 1,
#  'hurt': 14,
#  'hi': 24,
#  'fourth': 1,
#  'bag': 76,
#  'flew': 4,
#  'three': 156,
#  'hours': 21,
#  'four': 73,
#  'lines': 2,
#  'waited': 40,
#  'entire': 24,
#  'baggage-': 1,
#  'whole': 113,
#  'baggage': 22,
#  'carousel': 2,
#  'times': 33,
#  'through': 69,
#  'planes': 12,
#  'nash': 4,
#  'g': 1,
#  'flight': 33,
#  'fourteen': 1,
#  'tickets': 8,
#  'mileage': 1,
#  'expect': 12,
#  'kidding': 21,
#  'joke': 17,
#  'candid': 1,
#  'cameras': 2,
#  'movie': 5,
#  'show': 37,
#  'airplane': 3,
#  'airline': 20,
#  'give': 149,
#  'idea': 48,
#  'replace': 4,
#  'packed': 1,
#  'sentimental': 5,
#  'value': 4,
#  'replaced': 1,
#  'incredibly': 2,
#  'expensive': 3,
#  'from': 179,
#  'paris': 4,
#  'shopping': 3,
#  'weeks': 20,
#  'freaking': 13,
#  'says': 20,
#  'somebody-': 1,
#  'somebody': 76,
#  'inconvenience': 7,
#  "you're-": 4,
#  'lawsuit': 1,
#  'found': 19,
#  'oh-oh': 1,
#  'gift': 6,
#  "you're-you": 1,
#  'helping': 10,
#  'cruising': 1,
#  'bruising': 1,
#  'trouble': 31,
#  'charge': 9,
#  'president': 1,
#  'jet': 2,
#  'blue': 17,
#  'probably': 83,
#  'clothes': 2,
#  'sean': 2,
#  'badge': 2,
#  'number': 32,
#  'could': 218,
#  'yet': 29,
#  'personal': 5,
#  'thanks': 42,
#  'waiting': 97,
#  'help': 140,
#  'sorry': 166,
#  'start': 53,
#  'right-': 2,
#  'lost': 59,
#  'that-': 17,
#  'issue': 8,
#  'uh-huh': 3,
#  'see-': 1,
#  'record': 7,
#  'i-usually': 1,
#  'means': 5,
#  'mistakenly': 1,
#  'behalf': 2,
#  'apologize': 2,
#  'allowed': 2,
#  'dollar': 28,
#  'card': 18,
#  'which': 25,
#  'use': 14,
#  'future': 5,
#  'flights': 4,
#  'us': 115,
#  'once': 26,
#  'again': 157,
#  'such': 56,
#  'real': 48,
#  'giving': 21,
#  'gone': 37,
#  'nothing': 144,
#  'track': 4,
#  'listed': 1,
#  'anywhere': 15,
#  'really-': 4,
#  'behind': 29,
#  'spells': 1,
#  'held': 2,
#  'liable': 2,
#  'calm-': 1,
#  'you-': 39,
#  'actually-': 2,
#  'airlines': 5,
#  'responsible': 5,
#  'every': 82,
#  'luggage': 48,
#  'comes': 32,
#  'amount': 4,
#  'employee': 1,
#  'wrong': 117,
#  'bad': 34,
#  'service': 22,
#  'feel': 122,
#  'best': 71,
#  'address': 15,
#  'angry': 3,
#  'might': 72,
#  'impression': 1,
#  'sweet': 26,
#  'thank': 81,
#  'went': 94,
#  'her': 240,
#  'headstone': 3,
#  'week': 37,
#  'used': 16,
#  'cemeteries': 1,
#  'died': 23,
#  'felt': 33,
#  'urban': 1,
#  'oasis': 1,
#  'green': 15,
#  'city': 6,
#  'wandering': 1,
#  'takes': 15,
#  'forever': 29,
#  'lose': 22,
#  'other': 115,
#  'candy': 2,
#  'and-': 38,
#  'woman': 24,
#  'came': 113,
#  'hers': 1,
#  'pathetic': 2,
#  'hope': 72,
#  'enjoy': 21,
#  'brought': 37,
#  'ground': 1,
#  'rather': 42,
#  'honestly': 8,
#  'cemetery': 3,
#  'couple': 12,
#  'brought-': 1,
#  'redlands': 2,
#  'ran': 12,
#  'sprinklers': 2,
#  'hot': 6,
#  'lipsmack': 1,
#  'huge': 17,
#  'stones': 1,
#  'weird': 15,
#  'whenever': 5,
#  'grew': 11,
#  'together': 27,
#  'twenty': 19,
#  'cancer': 6,
#  'brain': 2,
#  'tumors': 1,
#  'heather': 1,
#  'a-': 14,
#  'built': 2,
#  'park': 3,
#  'prospect': 1,
#  'garden': 1,
#  'section': 1,
#  'these': 91,
#  'poetry': 3,
#  'parties': 4,
#  'memorial': 12,
#  'umm': 13,
#  'remember': 105,
#  'stand': 34,
#  'was-': 5,
#  'sitting': 7,
#  'feet': 2,
#  'holding': 2,
#  'poems': 1,
#  'memorized': 2,
#  'curly': 1,
#  'red': 6,
#  'hair': 14,
#  'palm': 4,
#  'tree': 1,
#  'crown': 1,
#  'growing': 7,
#  'head': 18,
#  'cool': 39,
#  'john': 1,
#  'dunn': 1,
#  'called': 14,
#  'death': 20,
#  'proud': 13,
#  'u.c.l.a': 2,
#  'surgery': 2,
#  'begin': 2,
#  'gave': 27,
#  'blood': 14,
#  'mom': 71,
#  'dropped': 3,
#  'off': 147,
#  'room': 18,
#  'wheelchair': 1,
#  'hardly': 16,
#  'reciting': 1,
#  'god': 176,
#  'damn': 24,
#  'audience': 2,
#  'joy': 4,
#  'welcome': 15,
#  'stay': 83,
#  'check': 29,
#  'days': 40,
#  'hang': 9,
#  'ones': 14,
#  'wrote': 9,
#  'mmhmm.mmhmm.mmhmm': 1,
#  'envelope': 1,
#  'ghetto': 1,
#  'excited': 76,
#  'pay': 37,
#  'also-': 2,
#  'loans': 5,
#  'bunch': 6,
#  'grants': 1,
#  'scholarships': 6,
#  'still': 113,
#  'hear': 64,
#  'oh-': 7,
#  'spend': 7,
#  'commuting': 2,
#  "'d": 157,
#  'throw': 11,
#  'party': 32,
#  'arapaho': 1,
#  'afford': 7,
#  'garbage': 46,
#  'summer': 5,
#  'staying': 8,
#  'relief': 2,
#  'thinking': 87,
#  'pack': 10,
#  'hooray': 2,
#  'u.s.c': 25,
#  'uhh': 7,
#  'critical': 1,
#  'studies': 1,
#  'prestigious': 3,
#  'program': 5,
#  'sure': 117,
#  'p.h.d': 1,
#  'ta': 21,
#  'sessions': 1,
#  'mold': 1,
#  'young': 10,
#  'minds': 1,
#  'mrs.': 5,
#  'millionaire': 1,
#  'graduate': 3,
#  'works': 3,
#  'mess': 1,
#  'ruined': 2,
#  'mm-hmm': 3,
#  'oh-yeah': 1,
#  'bet': 3,
#  'exactly': 44,
#  'neighborhood-': 1,
#  'neighborhood': 3,
#  'so-': 21,
#  'happy': 95,
#  'rapper': 1,
#  'ho': 1,
#  'sticking': 2,
#  'living': 19,
#  'glad': 15,
#  'woo': 1,
#  'yay': 7,
#  'major': 10,
#  'ooh': 9,
#  'fancy': 1,
#  'masters': 1,
#  'p.h.d.': 1,
#  'nice': 52,
#  'teach': 2,
#  'class': 2,
#  'teacher': 1,
#  'question': 18,
#  'confused': 3,
#  'mrs': 1,
#  'dash': 1,
#  'popular': 1,
#  'seasoning': 1,
#  'fun': 31,
#  'course': 80,
#  'where': 169,
#  'being': 84,
#  'messing': 2,
#  'chair': 9,
#  'ruin': 2,
#  'sees': 10,
#  'bed': 27,
#  'o': 2,
#  'clock': 4,
#  'morning': 28,
#  'dreaming': 9,
#  'walking': 15,
#  'after': 92,
#  'meaning': 43,
#  'dishonest': 20,
#  'argue': 29,
#  'proof': 5,
#  'father': 82,
#  'talk': 78,
#  'yourself': 86,
#  'until': 24,
#  'face': 24,
#  'grave': 11,
#  'body': 23,
#  'newspapers': 10,
#  'boy': 19,
#  'larry': 89,
#  'story': 23,
#  'business': 125,
#  'chris': 84,
#  'own': 33,
#  'mind': 65,
#  'ignore': 22,
#  'girl': 77,
#  'point': 113,
#  'view': 37,
#  'dead': 22,
#  'thinks': 16,
#  'alive': 19,
#  'considerate': 11,
#  'fellow': 8,
#  'asked': 53,
#  'annie': 113,
#  'feels': 15,
#  'same': 73,
#  'women': 28,
#  'never': 192,
#  'reason': 27,
#  'seen': 23,
#  'since': 40,
#  'away': 105,
#  'five': 46,
#  'years': 144,
#  'diagram': 16,
#  'coming': 106,
#  'pronouncing': 11,
#  'crazy': 33,
#  'must': 92,
#  'inspired': 10,
#  'shooting': 7,
#  'match': 12,
#  'broke': 13,
#  'crack': 7,
#  'woke': 7,
#  'looked': 14,
#  'cracked': 14,
#  'terrible': 14,
#  'mistake': 12,
#  'pays': 10,
#  'paying': 16,
#  'allow': 5,
#  'believe': 111,
#  'believes': 10,
#  'walk': 26,
#  'nights': 6,
#  'contradict': 10,
#  'anymore': 47,
#  'sake': 32,
#  'insane': 13,
#  'ask': 99,
#  'ahead': 29,
#  'infuriate': 11,
#  'throws': 10,
#  'fit': 15,
#  'talent': 12,
#  'ignoring': 10,
#  'reach': 12,
#  'pull': 14,
#  'afraid': 10,
#  'will': 209,
#  'suffer': 8,
#  'bloody': 11,
#  'life': 112,
#  'wanted': 76,
#  'settled': 9,
#  'pretty': 60,
#  'forgotten': 15,
#  'thrash': 9,
#  'avoid': 10,
#  'fast': 16,
#  'door': 19,
#  'someone': 38,
#  'wife': 12,
#  'breathing': 57,
#  'forget': 33,
#  'wedding': 26,
#  'everyone': 33,
#  'may': 7,
#  'somewhere': 57,
#  'else': 137,
#  'york': 29,
#  'son': 11,
#  'sucker': 12,
#  'inspire': 10,
#  'hour': 38,
#  'grub': 10,
#  'come': 194,
#  'home': 83,
#  'kids': 37,
#  'family': 28,
#  'center': 8,
#  'tough': 16,
#  'guy': 26,
#  'invite': 10,
#  'half': 29,
#  'sudden': 10,
#  'miles': 11,
#  'joe': 50,
#  'knows': 42,
#  'single': 32,
#  'full': 35,
#  'men': 33,
#  'foolish': 7,
#  'faithful': 9,
#  'rock': 13,
#  'darkest': 2,
#  'moments': 9,
#  'dares': 8,
#  'faith': 15,
#  'strangers': 10,
#  'brother': 22,
#  'act': 7,
#  'both': 22,
#  'noticed': 14,
#  'invited': 9,
#  'nonsense': 27,
#  'kill': 22,
#  'laugh': 80,
#  'happen': 85,
#  'night': 64,
#  'goes': 26,
#  'sleep': 8,
#  'breaks': 8,
#  'pieces': 14,
#  'look': 260,
#  'man': 111,
#  'detroit': 8,
#  'missing': 11,
#  'longer': 19,
#  'above': 29,
#  'bother': 10,
#  'lived': 10,
#  'listen': 68,
#  'read': 21,
#  'arguing': 13,
#  'kate': 22,
#  'calm': 46,
#  'shaking': 11,
#  'hide': 10,
#  'matter': 58,
#  'parents': 22,
#  'lovely': 9,
#  'air': 22,
#  'sort': 46,
#  'embarrassed': 10,
#  'ever': 85,
#  'knew': 53,
#  'ready': 22,
#  'almost': 17,
#  'started': 33,
#  'ambiguous': 10,
#  'finally': 30,
#  'beating': 1,
#  'bush': 1,
#  'forgive': 20,
#  'wondering': 6,
#  'ashamed': 19,
#  'work': 131,
#  'many': 42,
#  'aw': 4,
#  'geez': 6,
#  'earned': 1,
#  'hundreds': 13,
#  'paid': 27,
#  'style': 10,
#  'planning': 10,
#  'sneaking': 9,
#  'granted': 11,
#  'love': 111,
#  'imagination': 20,
#  'embarrassing': 11,
#  'yard': 11,
#  'porch': 2,
#  'fresh': 1,
#  'uncomfortable': 1,
#  'somehow': 21,
#  'far': 28,
#  'kiss': 46,
#  'kissed': 28,
#  'live': 72,
#  'drive': 32,
#  "it's-": 23,
#  'suppose': 29,
#  'mixed': 8,
#  'overseas': 12,
#  'command': 9,
#  'company': 18,
#  'toss': 10,
#  'instance': 10,
#  'raining': 10,
#  'several': 11,
#  'pair': 10,
#  'dry': 10,
#  'socks': 10,
#  'pocket': 13,
#  'die': 37,
#  'killed': 11,
#  'themselves': 28,
#  'selfish': 11,
#  'today': 28,
#  'watching': 18,
#  'destroyed': 11,
#  'monument': 9,
#  'responsibility': 14,
#  'earth': 9,
#  'difference': 13,
#  'incredible': 16,
#  'accident': 13,
#  'rat': 12,
#  'race': 20,
#  'driving': 22,
#  'seeing': 9,
#  'refrigerator': 11,
#  'included': 11,
#  'flashlight': 94,
#  'ours': 19,
#  'yours': 23,
#  'cold': 31,
#  'eleven': 12,
#  'particularly': 11,
#  'fish': 162,
#  'swim': 26,
#  'ocean': 2,
#  'flop': 11,
#  'beach': 72,
#  'moon': 59,
#  'landing': 8,
#  'talking': 57,
#  'eats': 10,
#  'augie': 58,
#  'also': 16,
#  'our': 129,
#  'shoes': 28,
#  'wet': 8,
#  'sand': 47,
#  'panties': 10,
#  'sore': 10,
#  'throat': 10,
#  'fight': 18,
#  ...}

# %%
# not required - already small dictionary
# dic_count = apply_mincut(dic_count, 0)

# %%
dic = {}
dic['_PAD_'] = len(dic)
dic['_UNK_'] = len(dic)

for word in dic_count.keys():
    dic[word] = len(dic)    
print(len(dic))
print(dic['_PAD_'])

with open('../data/processed/IEMOCAP/dic.pkl', 'wb') as f:
# with open('../data/processed/IEMOCAP/dic_G.pkl', 'wb') as f:
    pickle.dump( dic, f )
# Out:
# 3747
# 0

# %% [markdown]
# ## 02 create indexed data with voca

# %%
lines = []
with open('../data/processed/IEMOCAP/processed_tran.csv') as f:
# with open('../data/processed/IEMOCAP/processed_tran_fromG.csv') as f:
    read = csv.reader(f)
    lines = [ x[1] for x in read]
    
token_lines = [ word_tokenize(x) for x in lines]
token_lines_lower = [ [t.lower() for t in x] for x in token_lines]

sent_len = [ len(x) for x in token_lines]
print(np.max(sent_len))
print(np.min(sent_len))
print(np.mean(sent_len))
print(np.std(sent_len))
# Out:
# 128
# 1
# 14.819005877079391
# 12.20187522097008

# %%
# dic = {}
# with open('../data/processed/IEMOCAP/dic_G.pkl') as f:
#     dic = pickle.load(f)
# print dic['_PAD_']
# print len(dic)

# %%
# convert to index
index_lines = [ [ dic[t] for t in x ] for x in token_lines_lower ]

# %%
index_lines
# Out:
# [[2, 3, 4],
#  [5, 4],
#  [6, 7, 8, 9, 10],
#  [11, 12, 4],
#  [11, 13, 14, 15, 16, 17, 18, 11, 19, 3, 4],
#  [20, 21, 22, 16, 9, 10, 23, 3, 24, 25, 4],
#  [21, 10, 26, 27, 28, 29, 30, 4, 31, 6, 32, 26, 27, 33, 4, 34, 35, 36, 37, 4],
#  [38,
#   39,
#   26,
#   40,
#   41,
#   42,
#   29,
#   30,
#   43,
#   29,
#   30,
#   10,
#   38,
#   44,
#   8,
#   45,
#   42,
#   29,
#   30,
#   46,
#   16,
#   47,
#   48,
#   10],
#  [26, 27, 33, 41, 42, 29, 30, 4],
#  [49, 21, 10, 49, 8, 50, 51, 10],
#  [52, 16, 53, 54, 8, 50, 51, 10],
#  [55,
#   56,
#   34,
#   35,
#   36,
#   37,
#   57,
#   26,
#   58,
#   59,
#   60,
#   61,
#   4,
#   26,
#   58,
#   59,
#   60,
#   62,
#   63,
#   64,
#   57,
#   26,
#   58,
#   59,
#   60,
#   34,
#   30,
#   4,
#   58,
#   59,
#   11,
#   60,
#   65,
#   66,
#   67,
#   33,
#   10],
#  [68, 22, 69, 70, 71, 4],
#  [38, 72, 60, 11, 73, 74, 33, 10],
#  [75, 4, 11, 76, 57, 58, 11, 60, 49, 8, 77, 78, 79, 10],
#  [68, 80, 81, 26, 80, 82, 68, 4, 5, 4],
#  [58, 11, 60, 83, 84, 10],
#  [23, 3, 85, 86, 4],
#  [52, 87, 11, 41, 42, 46, 31, 88, 10],
#  [89,
#   4,
#   56,
#   26,
#   12,
#   59,
#   90,
#   11,
#   41,
#   42,
#   46,
#   31,
#   88,
#   91,
#   11,
#   92,
#   93,
#   69,
#   31,
#   94,
#   95,
#   4],
#  [31, 95, 6, 8, 96, 4],
#  [11,
#   97,
#   59,
#   98,
#   31,
#   6,
#   99,
#   16,
#   88,
#   100,
#   96,
#   4,
#   91,
#   11,
#   101,
#   102,
#   41,
#   103,
#   69,
#   16,
#   96,
#   57,
#   11,
#   104,
#   41,
#   60,
#   8,
#   105,
#   95,
#   70,
#   30,
#   4],
#  [106, 4, 26, 104, 107, 108, 70, 30, 41, 109, 31, 6, 110, 11, 4],
#  [26,
#   58,
#   59,
#   76,
#   4,
#   56,
#   26,
#   104,
#   29,
#   30,
#   41,
#   111,
#   31,
#   95,
#   112,
#   4,
#   26,
#   97,
#   59,
#   113,
#   114,
#   25,
#   112,
#   43,
#   29,
#   30,
#   4],
#  [106, 4, 26, 104, 107, 30, 57, 8, 115, 116, 4],
#  [8,
#   50,
#   51,
#   57,
#   8,
#   117,
#   118,
#   8,
#   119,
#   30,
#   120,
#   12,
#   59,
#   11,
#   121,
#   41,
#   122,
#   10,
#   61,
#   10],
#  [5, 4, 123, 124, 25, 66, 67, 57, 56, 123, 104, 29, 30, 41, 125, 68, 67, 4],
#  [26,
#   58,
#   59,
#   126,
#   32,
#   31,
#   6,
#   127,
#   128,
#   100,
#   129,
#   130,
#   131,
#   42,
#   33,
#   4,
#   25,
#   22,
#   113,
#   8,
#   132,
#   95,
#   4,
#   26,
#   113,
#   104,
#   29,
#   30,
#   4],
#  [110, 133, 72, 4],
#  [5,
#   4,
#   58,
#   11,
#   134,
#   41,
#   85,
#   34,
#   77,
#   10,
#   135,
#   10,
#   5,
#   4,
#   58,
#   11,
#   134,
#   41,
#   85,
#   34,
#   77,
#   10,
#   136,
#   4,
#   26,
#   137,
#   138,
#   139,
#   140,
#   4],
#  [12, 11, 42, 16, 141, 10, 127, 11, 142, 34, 143, 10],
#  [5, 4, 26, 76, 4],
#  [26, 58, 59, 76, 4, 26, 144, 46, 68, 4, 145, 133, 4, 131, 12, 59, 118],
#  [26, 146, 57, 11, 76, 57, 147, 54, 41, 148, 149, 4],
#  [7, 22, 129, 68, 60, 150, 151, 152, 57, 11, 76, 10],
#  [26, 76, 4],
#  [7, 22, 153, 154, 7, 57, 152, 57, 68, 104, 155, 4],
#  [26,
#   27,
#   99,
#   89,
#   156,
#   25,
#   57,
#   56,
#   26,
#   58,
#   59,
#   98,
#   25,
#   22,
#   99,
#   49,
#   26,
#   60,
#   8,
#   157,
#   4,
#   26,
#   58,
#   59,
#   85,
#   21,
#   158,
#   159,
#   25,
#   6,
#   102,
#   41,
#   160,
#   4],
#  [113, 57, 11, 76, 57, 161, 162, 4],
#  [49, 11, 163, 164, 165, 11, 104, 166, 18],
#  [65, 113, 92, 59, 21, 131, 167, 4],
#  [123, 101, 168, 16, 139, 169, 57, 152, 4],
#  [91, 99, 3, 170, 57, 52, 10],
#  [11, 137, 171, 172, 57, 5, 10],
#  [173, 11, 174, 114, 25, 41, 3, 57, 49, 175, 25, 57, 5, 10],
#  [176, 177, 98, 5, 4],
#  [26, 60, 41, 178, 179, 4],
#  [123,
#   180,
#   181,
#   182,
#   57,
#   68,
#   22,
#   32,
#   123,
#   183,
#   33,
#   57,
#   135,
#   10,
#   165,
#   7,
#   6,
#   8,
#   184,
#   185,
#   186,
#   16,
#   187,
#   4],
#  [18, 83, 188, 6, 189, 190, 4],
#  [26, 137, 114, 11, 191, 70, 192, 4],
#  [18, 26, 134, 191, 18, 191, 18, 191, 70, 193, 4],
#  [25, 22, 99, 194, 4],
#  [26,
#   58,
#   59,
#   126,
#   4,
#   11,
#   180,
#   195,
#   196,
#   127,
#   197,
#   57,
#   26,
#   58,
#   59,
#   76,
#   32,
#   58,
#   11,
#   60,
#   41,
#   121,
#   140,
#   4],
#  [26,
#   58,
#   59,
#   76,
#   57,
#   25,
#   22,
#   113,
#   99,
#   194,
#   4,
#   26,
#   198,
#   11,
#   180,
#   195,
#   199,
#   83,
#   200,
#   4],
#  [26,
#   113,
#   58,
#   59,
#   85,
#   38,
#   131,
#   174,
#   148,
#   11,
#   201,
#   130,
#   11,
#   60,
#   8,
#   202,
#   203,
#   81,
#   123,
#   60,
#   8,
#   202,
#   204,
#   4],
#  [170, 32, 6, 68, 194, 10, 32, 98],
#  [26,
#   58,
#   59,
#   76,
#   38,
#   11,
#   174,
#   138,
#   89,
#   156,
#   31,
#   10,
#   26,
#   58,
#   59,
#   76,
#   32,
#   11,
#   101,
#   99,
#   98,
#   11,
#   101,
#   136,
#   156,
#   25,
#   4],
#  [26, 27, 113, 205, 41, 198, 70, 107, 206, 4, 26, 27, 113, 205, 41, 118],
#  [31, 6, 8, 207, 208, 4],
#  [26, 76, 4],
#  [26, 113, 58, 59, 85, 32, 25, 54, 41, 138, 11, 4],
#  [21, 39, 26, 102, 41, 58, 10, 135, 10],
#  [5, 4],
#  [58, 59, 11, 209, 60, 125, 41, 210, 154, 7, 4],
#  [26, 113, 58, 59, 76, 38, 26, 27, 102, 41, 58, 25, 43, 11, 4],
#  [26, 97, 59, 211, 8, 203, 190, 162, 4, 38, 10],
#  [26, 76, 4],
#  [25, 22, 113, 99, 194, 4],
#  [20, 212, 36, 213, 4],
#  [18, 57, 214, 57, 26, 181, 215, 4],
#  [5, 4, 46, 16, 216, 217, 218, 4],
#  [219, 4, 220, 221, 222],
#  [223, 55, 4, 25, 36, 224, 225, 4],
#  [25, 36, 15, 16, 226, 227, 4],
#  [228,
#   57,
#   228,
#   4,
#   229,
#   230,
#   231,
#   18,
#   232,
#   229,
#   233,
#   68,
#   16,
#   234,
#   169,
#   68,
#   80,
#   148,
#   25,
#   235,
#   36,
#   3,
#   236,
#   237,
#   238,
#   4],
#  [239, 4, 23, 22, 42, 215, 18, 26, 240, 89, 4],
#  [5, 4, 20, 4, 11, 76, 57, 165, 229, 22, 241, 16, 242, 184, 4],
#  [56, 123, 101, 102, 41, 60, 8, 243, 244, 4],
#  [245, 4, 26, 246, 59, 247, 248, 159, 68, 4],
#  [229, 22, 99, 102, 41, 138, 8, 249, 57, 152, 4],
#  [245, 4, 250, 4],
#  [26, 146, 251, 26, 146, 26, 137, 60, 29, 252, 253, 4, 220, 221, 222],
#  [26,
#   60,
#   29,
#   252,
#   254,
#   4,
#   26,
#   146,
#   26,
#   137,
#   60,
#   41,
#   255,
#   16,
#   256,
#   4,
#   6,
#   68,
#   257,
#   10,
#   26,
#   58,
#   59,
#   76,
#   4,
#   258,
#   4],
#  [5, 57, 127, 220, 221, 222, 229, 22, 259, 3, 260],
#  [229, 261, 41, 124, 262, 57, 11, 76, 4],
#  [263, 57, 26, 198, 264, 265, 18, 266, 267, 4],
#  [268, 269, 4, 68, 22, 21, 229, 270, 4],
#  [5, 4],
#  [245, 4],
#  [5, 4, 123, 271, 272, 70, 273, 274, 4, 25, 22, 49, 8, 275, 169, 156, 276],
#  [266, 277, 4, 278, 4],
#  [5, 4],
#  [20, 127, 260, 123, 101, 215, 4, 123, 60, 279, 280, 4],
#  [123, 281, 282, 57, 283, 284, 4],
#  [285, 286, 8, 202, 287, 288, 289, 68, 123, 121, 290, 4, 220, 221, 222],
#  [127, 21, 22, 164, 10, 21, 22, 202, 10],
#  [5, 4, 26, 291, 4],
#  [292, 164, 4, 293, 46, 212, 10],
#  [52, 12, 11, 294, 10],
#  [12, 11, 295, 41, 11, 10],
#  [245, 4, 16, 272, 70, 273, 269, 10],
#  [229, 296, 41, 11, 18, 36, 49, 118],
#  [220, 221, 222, 68, 22, 297, 225, 4],
#  [5, 4],
#  [44,
#   68,
#   298,
#   68,
#   11,
#   101,
#   102,
#   41,
#   42,
#   299,
#   57,
#   133,
#   57,
#   300,
#   46,
#   301,
#   78,
#   302,
#   10],
#  [5, 4, 198, 159, 68, 4],
#  [5,
#   4,
#   56,
#   229,
#   137,
#   60,
#   49,
#   8,
#   72,
#   303,
#   4,
#   174,
#   11,
#   121,
#   304,
#   170,
#   100,
#   8,
#   72,
#   305,
#   10],
#  [245,
#   57,
#   38,
#   92,
#   11,
#   102,
#   41,
#   58,
#   16,
#   72,
#   306,
#   169,
#   10,
#   127,
#   307,
#   57,
#   92,
#   11,
#   102,
#   41,
#   308,
#   7,
#   10],
#  [49, 11, 104, 107, 116, 70, 309, 4, 220, 221, 222],
#  [6, 68, 83, 310, 10],
#  [229, 311, 11, 4],
#  [38, 197, 12, 229, 312, 15, 16, 226, 10],
#  [297, 10, 268, 269, 10],
#  [313, 4],
#  [26,
#   27,
#   8,
#   231,
#   314,
#   70,
#   16,
#   272,
#   70,
#   273,
#   315,
#   4,
#   56,
#   25,
#   113,
#   316,
#   127,
#   197,
#   4,
#   26,
#   58,
#   59,
#   76,
#   4],
#  [56,
#   16,
#   274,
#   317,
#   42,
#   11,
#   165,
#   11,
#   318,
#   164,
#   319,
#   49,
#   57,
#   11,
#   76,
#   57,
#   266,
#   277,
#   4],
#  [49,
#   57,
#   307,
#   57,
#   56,
#   25,
#   22,
#   113,
#   274,
#   4,
#   11,
#   101,
#   49,
#   57,
#   307,
#   8,
#   320,
#   26,
#   27,
#   66,
#   41,
#   11,
#   4],
#  [213, 4],
#  [220, 221, 222, 279, 153, 4],
#  [68, 22, 194, 321, 4],
#  [263, 57, 21, 10, 322, 22, 323, 10, 245, 16, 252, 169, 10],
#  [26,
#   58,
#   59,
#   76,
#   4,
#   6,
#   59,
#   68,
#   98,
#   68,
#   22,
#   324,
#   49,
#   325,
#   326,
#   18,
#   65,
#   49,
#   68,
#   4],
#  [26,
#   58,
#   59,
#   76,
#   4,
#   26,
#   298,
#   26,
#   180,
#   73,
#   327,
#   100,
#   127,
#   72,
#   68,
#   26,
#   113,
#   328,
#   68,
#   98,
#   26,
#   298,
#   57,
#   26,
#   198,
#   65,
#   49,
#   329,
#   92,
#   8,
#   330,
#   151,
#   331,
#   332,
#   113,
#   333,
#   334,
#   335,
#   336,
#   4],
#  [21, 337, 70, 8, 338, 10],
#  [297, 10],
#  [229, 113, 118],
#  [11, 76, 21, 10, 26, 291, 159, 68, 338, 4, 26, 339, 100, 68, 4],
#  [5, 4, 26, 142, 8, 340, 15, 16, 341, 4],
#  [229, 181, 25, 10],
#  [5, 4],
#  [21,
#   12,
#   229,
#   58,
#   10,
#   21,
#   36,
#   127,
#   342,
#   10,
#   26,
#   58,
#   59,
#   126,
#   32,
#   131,
#   80,
#   343,
#   344,
#   154,
#   3,
#   4],
#  [8, 345, 10],
#  [106, 4],
#  [26, 346, 26, 298, 26, 347, 129, 164, 18, 26, 90, 86, 21, 26, 27, 348, 15, 4],
#  [5, 4],
#  [26,
#   58,
#   59,
#   276,
#   26,
#   58,
#   59,
#   49,
#   349,
#   65,
#   46,
#   16,
#   141,
#   4,
#   26,
#   58,
#   59,
#   134,
#   34,
#   350,
#   69,
#   7,
#   4],
#  [26, 27, 7, 46, 351, 70, 86, 4, 26, 27, 352, 86, 21, 26, 27, 348, 15, 4],
#  [32, 10, 25, 22, 8, 353, 70, 354, 4],
#  [26,
#   113,
#   58,
#   59,
#   134,
#   31,
#   354,
#   355,
#   57,
#   11,
#   76,
#   4,
#   26,
#   113,
#   58,
#   59,
#   134,
#   65,
#   356,
#   3,
#   357,
#   57,
#   276,
#   4],
#  [25,
#   22,
#   113,
#   98,
#   11,
#   76,
#   57,
#   26,
#   180,
#   246,
#   31,
#   9,
#   358,
#   4,
#   11,
#   101,
#   99,
#   16,
#   47,
#   45,
#   41,
#   90,
#   3,
#   68,
#   26,
#   104,
#   8,
#   345,
#   56,
#   118],
#  [359,
#   360,
#   113,
#   198,
#   25,
#   22,
#   337,
#   70,
#   361,
#   18,
#   131,
#   92,
#   297,
#   362,
#   363,
#   129,
#   52,
#   113,
#   92,
#   59,
#   68,
#   206,
#   4],
#  [68, 22, 364, 57, 68, 22, 364, 4],
#  [365, 4],
#  [11, 198, 68, 11, 101, 235, 332, 3, 165, 26, 58, 59, 60, 8, 366, 10],
#  [11, 76, 57, 11, 101, 367, 16, 368, 57, 133, 4],
#  [32, 10, 21, 157, 10],
#  [11, 101, 369, 16, 370, 4, 278],
#  [371, 4, 68, 22, 372, 4],
#  [26, 27, 99, 373, 4],
#  [52, 58, 11, 198, 11, 92, 10],
#  [11, 92, 127, 374, 18, 375, 4, 26, 113, 98],
#  [245,
#   4,
#   26,
#   27,
#   369,
#   16,
#   370,
#   4,
#   26,
#   27,
#   367,
#   31,
#   366,
#   165,
#   376,
#   26,
#   134,
#   41,
#   4],
#  [16, 368, 57, 26, 27, 367, 16, 368, 165, 26, 134, 41, 4],
#  [26,
#   174,
#   99,
#   98,
#   11,
#   92,
#   99,
#   33,
#   190,
#   157,
#   4,
#   377,
#   80,
#   378,
#   31,
#   368,
#   190,
#   157,
#   4],
#  [60, 11, 379, 57, 263, 57, 322, 22, 323, 10],
#  [5, 4],
#  [106, 4, 7, 22, 380, 381, 66, 7, 4],
#  [263, 135, 4],
#  [26,
#   27,
#   113,
#   382,
#   26,
#   60,
#   8,
#   383,
#   68,
#   181,
#   8,
#   348,
#   338,
#   66,
#   25,
#   127,
#   26,
#   36,
#   113,
#   384,
#   25,
#   4],
#  [229, 22, 49, 8, 385, 100, 8, 341, 4],
#  [229, 22, 49, 8, 386, 385, 4, 5, 4, 25, 22, 8, 348, 338, 4],
#  [11, 12, 10],
#  [5, 4],
#  [11,
#   180,
#   73,
#   327,
#   100,
#   8,
#   338,
#   100,
#   8,
#   72,
#   305,
#   120,
#   68,
#   36,
#   8,
#   72,
#   305,
#   387,
#   4,
#   139,
#   10],
#  [258, 4],
#  [26, 58, 59, 76, 4, 229, 246, 8, 297, 348, 345, 26, 146, 18, 98],
#  [5, 4, 58, 11, 60, 8, 345, 10],
#  [25, 22, 337, 70, 388, 130, 28, 8, 338, 4],
#  [20,
#   173,
#   123,
#   389,
#   390,
#   186,
#   333,
#   305,
#   18,
#   11,
#   174,
#   113,
#   90,
#   3,
#   324,
#   16,
#   391,
#   68,
#   11,
#   60,
#   196,
#   18,
#   26,
#   137,
#   392,
#   25,
#   69,
#   4],
#  [106,
#   4,
#   11,
#   393,
#   78,
#   11,
#   174,
#   113,
#   394,
#   25,
#   46,
#   45,
#   4,
#   56,
#   131,
#   104,
#   57,
#   395,
#   57,
#   79,
#   41,
#   85,
#   57,
#   11,
#   76,
#   57,
#   21,
#   337,
#   70,
#   21,
#   68,
#   11,
#   180,
#   196,
#   57,
#   21,
#   337,
#   70,
#   98],
#  [5, 4, 56, 16, 353, 70, 354, 396, 57, 133, 4],
#  [106, 4, 56, 25, 54, 29, 397, 57, 11, 76, 4],
#  [26, 76, 4, 89, 4, 20, 57, 214, 4, 173, 98],
#  [5, 4],
#  [89, 57, 5, 4, 26, 80, 398, 4],
#  [20,
#   57,
#   399,
#   11,
#   60,
#   41,
#   58,
#   65,
#   68,
#   11,
#   58,
#   59,
#   400,
#   49,
#   41,
#   58,
#   41,
#   60,
#   8,
#   338,
#   4,
#   56,
#   16,
#   338,
#   401,
#   11,
#   166,
#   57,
#   11,
#   402,
#   59,
#   60,
#   41,
#   138,
#   403,
#   16,
#   368,
#   139,
#   260,
#   4],
#  [173, 42, 8, 366, 4],
#  [26, 113, 57, 11, 76, 57, 198, 11, 389, 404, 8, 405, 406, 173, 4],
#  [26, 12, 59, 407, 68, 4],
#  [26, 39, 367, 16, 368, 57, 56, 190, 157, 4],
#  [41, 408, 16, 370, 57, 409, 4],
#  [55, 4, 116, 410, 366, 15, 8, 305, 4],
#  [278, 4],
#  [11,
#   76,
#   57,
#   11,
#   58,
#   59,
#   60,
#   41,
#   411,
#   69,
#   83,
#   412,
#   66,
#   3,
#   57,
#   11,
#   76,
#   57,
#   113,
#   165,
#   118],
#  [118, 11, 97, 59, 42, 8, 338, 18, 413, 41, 60, 8, 345, 4],
#  [26, 58, 59, 198, 26, 27, 414, 4],
#  [376, 415, 12, 59, 98, 89, 4],
#  [21, 10, 106, 4],
#  [21, 10, 245, 4, 127, 260, 11, 101, 118],
#  [11, 76, 21, 10, 11, 58, 59, 60, 41, 411, 83, 416, 18, 83, 417, 69, 66, 3, 4],
#  [32, 99, 10],
#  [418, 4],
#  [5, 4, 31, 6, 16, 419, 88, 68, 26, 60, 73, 46, 4],
#  [26, 104, 34, 420, 4],
#  [26, 421, 46, 154, 422, 423, 387, 57, 26, 180, 73, 46, 424, 105, 425, 4],
#  [26,
#   426,
#   16,
#   427,
#   428,
#   26,
#   426,
#   100,
#   16,
#   429,
#   430,
#   431,
#   424,
#   432,
#   4,
#   131,
#   87,
#   3,
#   41,
#   121,
#   41,
#   16,
#   242,
#   116,
#   4,
#   26,
#   426,
#   433,
#   68,
#   100,
#   422,
#   434,
#   18,
#   260,
#   26,
#   27,
#   33,
#   4],
#  [435, 4],
#  [106, 436, 4],
#  [55, 4],
#  [437, 264, 438, 4],
#  [39,
#   26,
#   102,
#   41,
#   138,
#   28,
#   57,
#   49,
#   57,
#   335,
#   439,
#   57,
#   335,
#   440,
#   4,
#   130,
#   174,
#   26,
#   441,
#   34,
#   420,
#   33,
#   10],
#  [245, 57, 92, 11, 442, 3, 10],
#  [6, 31, 8, 443, 10],
#  [92,
#   7,
#   444,
#   445,
#   10,
#   6,
#   31,
#   68,
#   446,
#   10,
#   7,
#   22,
#   68,
#   447,
#   57,
#   139,
#   10,
#   448,
#   57,
#   449,
#   4],
#  [127, 11, 137, 450, 3, 166, 18, 170, 26, 137, 42, 34, 420, 10],
#  [11, 101, 442, 3, 57, 31, 6, 8, 443, 4],
#  [58,
#   11,
#   60,
#   62,
#   451,
#   98,
#   266,
#   267,
#   10,
#   68,
#   22,
#   40,
#   41,
#   452,
#   172,
#   68,
#   26,
#   60,
#   10,
#   58,
#   11,
#   126,
#   38,
#   197,
#   26,
#   60,
#   453,
#   46,
#   7,
#   10,
#   99,
#   234,
#   44,
#   25,
#   60,
#   454,
#   455,
#   120,
#   25,
#   97,
#   59,
#   138,
#   456,
#   49,
#   68,
#   4,
#   25,
#   36,
#   457,
#   458,
#   4],
#  [123, 421, 46, 459, 460, 4, 26, 180, 73, 461, 100, 422, 462, 4],
#  [26,
#   58,
#   59,
#   185,
#   21,
#   11,
#   101,
#   463,
#   163,
#   464,
#   4,
#   465,
#   466,
#   286,
#   41,
#   452,
#   172,
#   26,
#   180,
#   181,
#   7,
#   18,
#   450,
#   3,
#   166,
#   100,
#   34,
#   467,
#   4],
#  [58, 11, 126, 52, 34, 253, 6, 10],
#  [91,
#   468,
#   91,
#   468,
#   91,
#   11,
#   101,
#   327,
#   100,
#   8,
#   469,
#   57,
#   203,
#   57,
#   11,
#   180,
#   470,
#   25,
#   4],
#  [471, 4, 25, 22, 8, 472, 4, 473, 101, 474, 3, 69, 33, 10],
#  [11, 92, 475, 100, 8, 476, 4, 11, 92, 46, 127, 197, 477, 4],
#  [52, 22, 46, 478, 10, 52, 6, 16, 479, 70, 480, 481, 10],
#  [165, 26, 482, 76, 344, 4],
#  [5, 4],
#  [26, 58, 59, 134, 166, 57, 26, 134, 34, 483, 4],
#  [21, 22, 83, 287, 10],
#  [484, 4, 342, 4, 58, 11, 60, 8, 485, 486, 78, 79, 10],
#  [89, 4, 26, 137, 58, 68, 4],
#  [26,
#   58,
#   59,
#   198,
#   11,
#   60,
#   196,
#   172,
#   11,
#   487,
#   58,
#   165,
#   26,
#   58,
#   59,
#   60,
#   34,
#   420,
#   33,
#   488,
#   4],
#  [8, 143, 10, 26, 137, 148, 8, 489, 310, 347, 4],
#  [418, 4, 490, 100, 491, 4],
#  [174, 26, 492, 11, 10],
#  [263, 135, 4],
#  [89, 4],
#  [89, 4],
#  [89,
#   4,
#   342,
#   4,
#   26,
#   27,
#   297,
#   493,
#   68,
#   11,
#   246,
#   41,
#   58,
#   68,
#   4,
#   21,
#   22,
#   83,
#   176,
#   287,
#   10,
#   23,
#   22,
#   494,
#   7,
#   4],
#  [89, 4],
#  [324, 495, 89, 4, 18, 11, 496, 83, 420, 10, 6, 497, 68, 16, 498, 10],
#  [499, 4],
#  [5, 4, 5, 57, 26, 58, 59, 500, 26, 58, 59, 85, 62, 98],
#  [26,
#   58,
#   59,
#   85,
#   62,
#   501,
#   70,
#   25,
#   57,
#   18,
#   502,
#   130,
#   26,
#   58,
#   59,
#   85,
#   8,
#   501,
#   70,
#   25,
#   57,
#   68,
#   503,
#   223],
#  [123,
#   180,
#   504,
#   496,
#   83,
#   430,
#   4,
#   123,
#   101,
#   224,
#   493,
#   4,
#   66,
#   505,
#   70,
#   480,
#   481,
#   26,
#   80,
#   49,
#   41,
#   506,
#   100,
#   62,
#   467,
#   4,
#   26,
#   39,
#   507,
#   41,
#   498,
#   11,
#   8,
#   266,
#   508,
#   472,
#   509,
#   510,
#   11,
#   174,
#   511,
#   62,
#   512,
#   513,
#   11,
#   134,
#   41,
#   411,
#   156,
#   514,
#   4,
#   26,
#   27,
#   224,
#   493,
#   57,
#   515,
#   516,
#   118],
#  [100, 517, 29, 467, 18, 83, 420, 57, 56],
#  [5, 4],
#  [106, 57, 106, 4],
#  [106, 57, 106, 4, 31, 6, 518, 4],
#  [106,
#   4,
#   26,
#   27,
#   113,
#   519,
#   11,
#   166,
#   57,
#   16,
#   420,
#   6,
#   520,
#   4,
#   91,
#   25,
#   22,
#   99,
#   33,
#   57,
#   26,
#   27,
#   297,
#   493,
#   7,
#   6,
#   521,
#   26,
#   174,
#   58,
#   165,
#   118],
#  [31,
#   6,
#   16,
#   234,
#   522,
#   501,
#   68,
#   123,
#   60,
#   18,
#   91,
#   25,
#   22,
#   99,
#   523,
#   33,
#   170,
#   25,
#   22,
#   482,
#   99,
#   524,
#   4],
#  [515, 516, 57, 26, 27, 525, 26, 27, 297, 493, 4],
#  [55, 4],
#  [26, 76, 4],
#  [26,
#   27,
#   224,
#   493,
#   4,
#   56,
#   91,
#   11,
#   85,
#   16,
#   163,
#   68,
#   22,
#   139,
#   526,
#   3,
#   33,
#   57,
#   25,
#   527,
#   25,
#   69,
#   297,
#   75,
#   68,
#   123,
#   92,
#   99,
#   528,
#   529,
#   98],
#  [89, 4, 530],
#  [110,
#   57,
#   123,
#   92,
#   99,
#   400,
#   529,
#   41,
#   450,
#   531,
#   41,
#   247,
#   450,
#   11,
#   31,
#   266,
#   267,
#   127,
#   118,
#   25,
#   22,
#   532,
#   25,
#   22,
#   110,
#   297],
#  [123,
#   92,
#   110,
#   99,
#   247,
#   507,
#   98,
#   11,
#   76,
#   57,
#   49,
#   123,
#   58,
#   59,
#   60,
#   41,
#   450,
#   11,
#   31,
#   266,
#   267,
#   4,
#   123,
#   58,
#   59,
#   60,
#   41,
#   58,
#   68,
#   4],
#  [25, 22, 8, 472, 4],
#  [11,
#   76,
#   57,
#   16,
#   533,
#   174,
#   99,
#   138,
#   528,
#   534,
#   100,
#   535,
#   420,
#   70,
#   536,
#   68,
#   537,
#   433,
#   33,
#   4],
#  [156, 16, 538, 70, 98],
#  [214, 57, 110, 57, 26, 58, 59, 76, 4, 26, 58, 59, 76, 4, 245, 297, 10],
#  [20,
#   170,
#   173,
#   11,
#   174,
#   113,
#   347,
#   344,
#   18,
#   229,
#   174,
#   450,
#   11,
#   151,
#   166,
#   4,
#   56,
#   139,
#   260,
#   324,
#   26,
#   174,
#   58,
#   98],
#  [139,
#   260,
#   324,
#   26,
#   174,
#   58,
#   6,
#   113,
#   450,
#   11,
#   31,
#   266,
#   267,
#   57,
#   26,
#   27,
#   297,
#   493,
#   4],
#  [245, 4, 34, 287, 6, 484, 4, 418, 4],
#  [485, 486, 10, 263, 57, 106, 4, 11, 174, 113, 411, 34, 539, 486, 26, 146, 4],
#  [32,
#   10,
#   60,
#   26,
#   196,
#   79,
#   540,
#   10,
#   60,
#   26,
#   150,
#   11,
#   541,
#   542,
#   10,
#   26,
#   543,
#   49,
#   26,
#   60,
#   196,
#   16,
#   544,
#   26,
#   487,
#   4],
#  [91,
#   11,
#   134,
#   57,
#   11,
#   174,
#   392,
#   8,
#   143,
#   4,
#   26,
#   174,
#   450,
#   11,
#   16,
#   545,
#   4,
#   55,
#   4,
#   29,
#   546,
#   98],
#  [78,
#   11,
#   174,
#   148,
#   8,
#   310,
#   347,
#   4,
#   56,
#   26,
#   198,
#   8,
#   143,
#   547,
#   138,
#   8,
#   405,
#   151,
#   98,
#   46,
#   34,
#   548,
#   57,
#   192,
#   60,
#   151,
#   118],
#  [25, 22, 89, 4],
#  [106, 57, 106, 57, 106, 4],
#  [106, 4],
#  [68, 22, 549, 4],
#  [550, 11, 4],
#  [26, 551, 41, 85, 552, 553, 8, 554, 78, 256, 387, 4],
#  [26,
#   555,
#   41,
#   121,
#   41,
#   556,
#   8,
#   330,
#   358,
#   285,
#   557,
#   4,
#   26,
#   113,
#   57,
#   11,
#   76,
#   57,
#   26,
#   558,
#   49,
#   131,
#   13,
#   559,
#   560,
#   57,
#   11,
#   76,
#   57,
#   7,
#   6,
#   317,
#   31,
#   561,
#   46,
#   16,
#   562,
#   4],
#  [127,
#   26,
#   36,
#   49,
#   563,
#   357,
#   358,
#   4,
#   25,
#   564,
#   565,
#   41,
#   178,
#   552,
#   553,
#   120,
#   26,
#   317,
#   566,
#   25,
#   4,
#   11,
#   76,
#   4],
#  [127,
#   26,
#   36,
#   327,
#   15,
#   31,
#   567,
#   116,
#   18,
#   7,
#   36,
#   49,
#   8,
#   353,
#   70,
#   568,
#   7,
#   18,
#   26,
#   248,
#   68,
#   26,
#   80,
#   411,
#   16,
#   568,
#   18,
#   144,
#   25,
#   66,
#   552,
#   553,
#   4,
#   569],
#  [31,
#   570,
#   571,
#   164,
#   18,
#   57,
#   11,
#   76,
#   57,
#   25,
#   36,
#   572,
#   4,
#   25,
#   36,
#   552,
#   45,
#   68,
#   36,
#   7,
#   4],
#  [5, 4, 18, 285, 36, 49, 57, 68, 22, 573, 57, 26, 574, 11, 575, 25, 4],
#  [18,
#   26,
#   57,
#   11,
#   76,
#   57,
#   26,
#   298,
#   57,
#   26,
#   240,
#   26,
#   36,
#   493,
#   18,
#   26,
#   576,
#   25,
#   140,
#   41,
#   552,
#   337,
#   70,
#   18,
#   26,
#   49,
#   144,
#   25,
#   66,
#   16,
#   577,
#   18,
#   285,
#   36,
#   49,
#   57,
#   106,
#   57,
#   25,
#   22,
#   136,
#   4,
#   285,
#   36,
#   49,
#   57,
#   26,
#   80,
#   578,
#   60,
#   552,
#   140,
#   57,
#   579,
#   4],
#  [26,
#   58,
#   59,
#   76,
#   4,
#   25,
#   113,
#   57,
#   49,
#   57,
#   26,
#   558,
#   127,
#   541,
#   165,
#   26,
#   389,
#   59,
#   60,
#   196,
#   25,
#   4,
#   26,
#   58,
#   59,
#   76,
#   4,
#   302,
#   4],
#  [26, 58, 59, 76, 4],
#  [15, 16, 580, 10],
#  [581, 423, 4],
#  [26,
#   582,
#   26,
#   576,
#   219,
#   156,
#   3,
#   4,
#   229,
#   551,
#   41,
#   583,
#   57,
#   5,
#   57,
#   100,
#   16,
#   184,
#   4,
#   123,
#   584,
#   433,
#   16,
#   585,
#   4],
#  [25, 36, 586, 4, 220, 587, 222],
#  [5,
#   4,
#   25,
#   22,
#   588,
#   4,
#   583,
#   6,
#   29,
#   216,
#   562,
#   127,
#   131,
#   60,
#   191,
#   18,
#   191,
#   70,
#   589,
#   4],
#  [5, 4],
#  [25,
#   22,
#   590,
#   4,
#   591,
#   26,
#   121,
#   140,
#   41,
#   217,
#   57,
#   26,
#   198,
#   70,
#   552,
#   4,
#   26,
#   298,
#   57,
#   25,
#   22,
#   49,
#   118,
#   26,
#   298,
#   123,
#   592,
#   164,
#   593,
#   18,
#   285,
#   557,
#   130,
#   123,
#   13,
#   594,
#   116,
#   4,
#   18,
#   5,
#   4,
#   285,
#   246,
#   595,
#   57,
#   285,
#   246,
#   256,
#   596,
#   597,
#   4],
#  [34,
#   544,
#   383,
#   598,
#   4,
#   285,
#   22,
#   181,
#   599,
#   123,
#   60,
#   599,
#   123,
#   600,
#   31,
#   49,
#   405,
#   98,
#   7,
#   22,
#   8,
#   601,
#   57,
#   602,
#   601,
#   4,
#   18,
#   7,
#   6,
#   49,
#   8,
#   603,
#   604,
#   70,
#   25,
#   68,
#   123,
#   108,
#   164,
#   100,
#   552,
#   4],
#  [285, 555, 41, 60, 605, 606, 607, 66, 608, 184, 4],
#  [609, 4, 5, 4],
#  [18,
#   16,
#   176,
#   305,
#   358,
#   285,
#   557,
#   57,
#   26,
#   610,
#   285,
#   487,
#   59,
#   297,
#   611,
#   57,
#   609,
#   118],
#  [56,
#   26,
#   298,
#   285,
#   487,
#   57,
#   56,
#   25,
#   612,
#   127,
#   25,
#   36,
#   337,
#   70,
#   613,
#   15,
#   552,
#   614,
#   615,
#   552,
#   164,
#   18,
#   285,
#   246,
#   605,
#   616,
#   285,
#   246,
#   617,
#   4,
#   18,
#   26,
#   610,
#   327,
#   164,
#   57,
#   285,
#   246,
#   618,
#   619,
#   620,
#   18,
#   7,
#   36,
#   31,
#   621,
#   622,
#   139,
#   526,
#   552,
#   18,
#   25,
#   36,
#   49,
#   8,
#   623,
#   624,
#   139,
#   69,
#   70,
#   552,
#   625,
#   4,
#   25,
#   36,
#   626,
#   4],
#  [333,
#   57,
#   26,
#   146,
#   4,
#   285,
#   617,
#   31,
#   116,
#   57,
#   627,
#   628,
#   57,
#   25,
#   22,
#   629,
#   57,
#   630,
#   138,
#   99,
#   631,
#   4,
#   569],
#  [7, 22, 107, 116, 57, 26, 97, 59, 610, 4],
#  [26,
#   610,
#   57,
#   133,
#   57,
#   130,
#   123,
#   13,
#   98,
#   285,
#   557,
#   15,
#   632,
#   4,
#   285,
#   246,
#   596,
#   633,
#   18,
#   7,
#   36,
#   99,
#   197,
#   574,
#   41,
#   634,
#   156,
#   57,
#   56,
#   26,
#   635,
#   636,
#   100,
#   552,
#   633,
#   57,
#   552,
#   637,
#   18,
#   26,
#   358,
#   57,
#   127,
#   123,
#   638,
#   552,
#   639,
#   46,
#   16,
#   491,
#   640,
#   18,
#   170,
#   123,
#   13,
#   519,
#   636,
#   18,
#   571,
#   140,
#   4,
#   18,
#   285,
#   57,
#   46,
#   552,
#   641,
#   57,
#   49,
#   174,
#   642,
#   58,
#   61,
#   57,
#   643,
#   552,
#   606,
#   100,
#   605,
#   129,
#   49,
#   46,
#   16,
#   491,
#   640,
#   4,
#   324,
#   285,
#   286,
#   6,
#   8,
#   644,
#   645,
#   646,
#   4,
#   11,
#   76,
#   10],
#  [26, 27, 493, 57, 647, 4],
#  [6,
#   7,
#   61,
#   26,
#   174,
#   42,
#   11,
#   10,
#   58,
#   11,
#   134,
#   3,
#   41,
#   411,
#   185,
#   70,
#   61,
#   100,
#   11,
#   78,
#   118,
#   10],
#  [118, 343, 164, 61, 10],
#  [11,
#   76,
#   11,
#   92,
#   648,
#   41,
#   649,
#   15,
#   34,
#   386,
#   91,
#   11,
#   134,
#   41,
#   113,
#   650,
#   69,
#   100,
#   8,
#   581,
#   651,
#   18,
#   652,
#   69,
#   4],
#  [258, 4],
#  [245, 4, 285, 36, 7, 10],
#  [278, 4],
#  [5, 4],
#  [38, 72, 13, 11, 7, 100, 10],
#  [278, 4],
#  [245, 297, 10],
#  [11, 584, 433, 16, 585, 46, 16, 580, 10],
#  [6, 25, 8, 231, 580, 10],
#  [245, 57, 127, 131, 101, 49, 297, 216, 133, 57, 297, 216, 653, 10],
#  [278, 4],
#  [278, 4],
#  [127, 285, 654, 8, 330, 70, 606, 10],
#  [655, 4],
#  [55, 4, 7, 22, 8, 231, 656, 25, 464, 57, 11, 101, 46, 4, 26, 76, 4],
#  [127, 26, 60, 41, 308, 140, 41, 16, 657, 56, 118, 26, 76, 4],
#  [26,
#   27,
#   297,
#   658,
#   4,
#   5,
#   4,
#   26,
#   58,
#   59,
#   76,
#   38,
#   26,
#   27,
#   102,
#   41,
#   659,
#   100,
#   61,
#   57,
#   56,
#   118,
#   26,
#   660,
#   5,
#   4,
#   661,
#   57,
#   133,
#   57,
#   5,
#   4,
#   26,
#   339,
#   57,
#   152,
#   57,
#   100,
#   8,
#   662,
#   70,
#   663,
#   18,
#   664,
#   127,
#   26,
#   27,
#   665,
#   491,
#   41,
#   666,
#   66,
#   68,
#   4],
#  [667, 26, 76, 57, 26, 76, 57, 26, 76, 57, 26, 76, 4],
#  [26,
#   58,
#   59,
#   76,
#   4,
#   26,
#   668,
#   127,
#   197,
#   305,
#   669,
#   236,
#   25,
#   6,
#   57,
#   26,
#   670,
#   578,
#   4],
#  [26, 76, 4, 123, 389, 671, 8, 672, 4],
#  [15,
#   673,
#   123,
#   487,
#   674,
#   68,
#   4,
#   220,
#   675,
#   222,
#   4,
#   5,
#   4,
#   127,
#   21,
#   92,
#   11,
#   168,
#   31,
#   676,
#   57,
#   152,
#   10,
#   11,
#   101,
#   677,
#   357,
#   57,
#   133,
#   57,
#   5,
#   10],
#  [25,
#   22,
#   8,
#   678,
#   133,
#   4,
#   26,
#   298,
#   26,
#   36,
#   679,
#   26,
#   36,
#   102,
#   41,
#   60,
#   41,
#   680,
#   164,
#   324,
#   70,
#   34,
#   391,
#   56,
#   5,
#   4,
#   681,
#   100,
#   682,
#   4],
#  [609,
#   4,
#   25,
#   22,
#   118,
#   25,
#   22,
#   683,
#   118,
#   25,
#   22,
#   684,
#   685,
#   4,
#   25,
#   22,
#   8,
#   297,
#   686,
#   687,
#   57,
#   127,
#   131,
#   407,
#   4],
#  [5, 4, 26, 27, 99, 688, 4],
#  [609, 118, 689, 4, 220, 221, 222],
#  [214, 57, 5, 57, 5, 4, 26, 27, 8, 690, 100, 256, 691, 4, 278, 4],
#  [127, 26, 42, 41, 692, 693, 694, 4, 695, 10, 68, 22, 34, 188, 4],
#  [26, 80, 138, 276, 245, 4, 139, 57, 139, 57, 139, 4],
#  [5,
#   4,
#   5,
#   26,
#   27,
#   658,
#   4,
#   681,
#   4,
#   18,
#   170,
#   26,
#   137,
#   138,
#   8,
#   696,
#   515,
#   26,
#   697,
#   57,
#   11,
#   126,
#   10,
#   165,
#   68,
#   22,
#   16,
#   206,
#   25,
#   698,
#   4],
#  [5, 4, 250, 4, 220, 221, 222],
#  [26,
#   76,
#   4,
#   26,
#   199,
#   517,
#   8,
#   699,
#   70,
#   25,
#   57,
#   16,
#   427,
#   305,
#   4,
#   16,
#   176,
#   422,
#   65,
#   26,
#   180,
#   196,
#   57,
#   26,
#   180,
#   700,
#   172,
#   57,
#   26,
#   198,
#   4,
#   701,
#   4,
#   5,
#   4],
#  [12, 11, 42, 16, 143, 10],
#  [5, 4, 68, 6, 127, 213, 4],
#  [245, 34, 644, 4, 21, 92, 11, 102, 41, 58, 10, 220, 221, 222],
#  [702,
#   57,
#   26,
#   703,
#   11,
#   101,
#   297,
#   658,
#   4,
#   245,
#   4,
#   68,
#   22,
#   21,
#   661,
#   92,
#   100,
#   10,
#   139,
#   10,
#   704,
#   4],
#  [245,
#   4,
#   348,
#   57,
#   348,
#   4,
#   68,
#   22,
#   213,
#   4,
#   92,
#   11,
#   102,
#   41,
#   649,
#   357,
#   33,
#   10,
#   78,
#   92,
#   11,
#   102,
#   41,
#   49,
#   42,
#   8,
#   105,
#   705,
#   11,
#   102,
#   41,
#   308,
#   41,
#   8,
#   105,
#   706,
#   10],
#  [31,
#   6,
#   707,
#   26,
#   39,
#   127,
#   708,
#   68,
#   11,
#   101,
#   102,
#   41,
#   649,
#   4,
#   11,
#   101,
#   99,
#   102,
#   41,
#   118,
#   123,
#   389,
#   250,
#   671,
#   8,
#   672,
#   4],
#  [8, 709, 672, 710, 4, 5, 4, 89, 4],
#  [26,
#   39,
#   346,
#   5,
#   4,
#   26,
#   27,
#   711,
#   357,
#   57,
#   26,
#   27,
#   113,
#   168,
#   34,
#   169,
#   4,
#   26,
#   27,
#   712,
#   33,
#   4,
#   26,
#   27,
#   127,
#   713,
#   11,
#   101,
#   102,
#   41,
#   649,
#   57,
#   26,
#   27,
#   127,
#   713,
#   11,
#   101,
#   102,
#   41,
#   138,
#   33,
#   4,
#   5,
#   4,
#   714,
#   4],
#  [5, 4, 231, 305, 4],
#  [278, 4, 278, 4, 715, 4, 127, 21, 716, 10, 21, 92, 11, 168, 10],
#  [245, 57, 89, 4],
#  [717, 4, 718, 4],
#  [6, 31, 8, 719, 78, 8, 720, 10, 78, 174, 11, 118, 10, 721],
#  [68,
#   22,
#   348,
#   4,
#   58,
#   59,
#   11,
#   60,
#   41,
#   49,
#   722,
#   8,
#   723,
#   57,
#   133,
#   57,
#   130,
#   11,
#   58,
#   68,
#   10],
#  [724, 4, 695, 435, 57, 26, 60, 8, 725, 4],
#  [11,
#   60,
#   41,
#   42,
#   215,
#   4,
#   20,
#   11,
#   92,
#   215,
#   41,
#   219,
#   4,
#   11,
#   101,
#   695,
#   435,
#   4,
#   99,
#   41,
#   138,
#   726,
#   156,
#   727,
#   4,
#   728,
#   510,
#   6,
#   16,
#   729,
#   730,
#   4],
#  [695, 435, 4, 68, 22, 127, 213, 57, 152, 4],
#  [715, 118, 122, 22, 731, 4],
#  [70, 732, 57, 139, 4, 68, 22, 733, 16, 518, 166, 6, 57, 734, 8, 119, 4],
#  [68,
#   22,
#   38,
#   11,
#   42,
#   16,
#   231,
#   277,
#   4,
#   92,
#   11,
#   735,
#   156,
#   16,
#   736,
#   10,
#   58,
#   59,
#   737,
#   25,
#   4],
#  [21, 22, 229, 102, 41, 407, 10],
#  [173, 123, 389, 90, 344, 358, 229, 738, 25, 4],
#  [38,
#   487,
#   229,
#   85,
#   25,
#   10,
#   26,
#   36,
#   16,
#   47,
#   116,
#   164,
#   120,
#   229,
#   36,
#   665,
#   46,
#   739,
#   4],
#  [130, 10],
#  [21, 36, 229, 168, 69, 33, 15, 424, 740, 741, 46, 16, 742, 10],
#  [229, 22, 743, 70, 344, 516, 57, 744, 357, 4],
#  [25, 22, 28, 41, 138, 113, 49, 745, 229, 557, 4, 21, 22, 16, 746, 70, 68, 10],
#  [21, 10],
#  [21, 58, 11, 298, 747, 10],
#  [21, 58, 11, 134, 41, 58, 10, 748, 156, 344, 10],
#  [11, 97, 59, 407, 68, 41, 344, 4],
#  [733, 22, 16, 749, 10, 58, 11, 60, 62, 749, 10],
#  [41,
#   11,
#   25,
#   6,
#   57,
#   41,
#   3,
#   25,
#   6,
#   57,
#   56,
#   41,
#   83,
#   750,
#   57,
#   11,
#   174,
#   751,
#   752,
#   753,
#   11,
#   92,
#   481,
#   46,
#   16,
#   754,
#   4,
#   56,
#   7,
#   6,
#   106,
#   755,
#   18,
#   7,
#   6,
#   106,
#   756,
#   57,
#   127,
#   733,
#   92,
#   11,
#   10],
#  [25,
#   22,
#   68,
#   16,
#   477,
#   6,
#   309,
#   644,
#   645,
#   757,
#   4,
#   535,
#   177,
#   333,
#   202,
#   758,
#   537,
#   140,
#   18,
#   127,
#   16,
#   242,
#   116,
#   6,
#   102,
#   41,
#   138,
#   759,
#   57,
#   131,
#   113,
#   98],
#  [32, 10],
#  [20, 26, 181, 29, 451, 57, 56, 21, 22, 83, 760, 10],
#  [20, 68, 22, 234, 83, 761, 57, 762, 4],
#  [20,
#   21,
#   58,
#   11,
#   134,
#   3,
#   41,
#   58,
#   10,
#   11,
#   101,
#   216,
#   321,
#   41,
#   76,
#   83,
#   763,
#   764,
#   4],
#  [20, 11, 134, 41, 148, 688, 68, 83, 750, 6, 99, 102, 41, 98],
#  [26, 27, 113, 382, 4],
#  [245, 4, 26, 765, 21, 26, 181, 41, 765, 4, 68, 766, 6, 759, 22, 766, 4],
#  [459,
#   83,
#   750,
#   22,
#   767,
#   70,
#   768,
#   57,
#   229,
#   6,
#   99,
#   769,
#   569,
#   762,
#   229,
#   665,
#   770,
#   229,
#   22,
#   665,
#   771,
#   4,
#   16,
#   766,
#   6,
#   759,
#   22,
#   766,
#   4],
#  [260,
#   11,
#   174,
#   121,
#   66,
#   459,
#   7,
#   91,
#   11,
#   76,
#   733,
#   41,
#   121,
#   57,
#   56,
#   26,
#   27,
#   352,
#   11,
#   57,
#   26,
#   58,
#   59,
#   76,
#   733,
#   41,
#   121,
#   4],
#  [11, 101, 8, 772, 773, 57, 7, 22, 521, 540, 46, 68, 4],
#  [26, 113, 58, 59, 85, 32, 4, 60, 11, 774, 775, 488, 10],
#  [20,
#   38,
#   58,
#   11,
#   76,
#   285,
#   22,
#   102,
#   41,
#   294,
#   11,
#   10,
#   173,
#   285,
#   776,
#   16,
#   777,
#   206,
#   83,
#   750,
#   44,
#   4],
#  [16, 477, 6, 11, 58, 59, 85, 321, 778, 4, 11, 779, 12, 4],
#  [32, 44, 25, 60, 41, 138, 775, 10],
#  [245, 68, 22, 8, 342, 780, 4, 25, 22, 106, 780, 15, 324, 4],
#  [11,
#   60,
#   59,
#   781,
#   552,
#   782,
#   11,
#   551,
#   783,
#   41,
#   208,
#   57,
#   25,
#   22,
#   73,
#   784,
#   785,
#   4],
#  [26, 58, 59, 134, 8, 786, 4],
#  [229, 770, 229, 22, 787, 140, 762, 4],
#  [11, 294, 68, 766, 57, 11, 92, 788, 344, 769, 118],
#  [118,
#   18,
#   170,
#   21,
#   22,
#   68,
#   102,
#   41,
#   58,
#   41,
#   83,
#   750,
#   10,
#   58,
#   11,
#   76,
#   10,
#   26,
#   58,
#   59,
#   4],
#  [113, 450, 25, 333, 151, 248, 4],
#  [21, 16, 53, 6, 31, 10],
#  [92, 11, 789, 10],
#  [11, 60, 8, 761, 33, 4, 21, 16, 53, 6, 31, 10],
#  [245, 4, 790, 11, 138, 791, 10],
#  [11, 298, 41, 90, 3, 68, 11, 80, 201, 16, 761, 154, 31, 10],
#  [20, 11, 58, 59, 134, 41, 198, 49, 68, 4],
#  [324,
#   139,
#   4,
#   56,
#   11,
#   58,
#   59,
#   134,
#   41,
#   198,
#   49,
#   68,
#   165,
#   21,
#   16,
#   53,
#   92,
#   123,
#   74,
#   100,
#   57,
#   762,
#   10,
#   25,
#   22,
#   324,
#   100,
#   11,
#   4,
#   31,
#   429,
#   792,
#   793,
#   6,
#   100,
#   11,
#   4],
#  [113, 58, 59, 198, 49, 68, 4],
#  [26, 58, 59, 126, 11, 57, 58, 26, 10],
#  [26, 174, 85, 68, 4],
#  [229, 142, 25, 4],
#  [229, 36, 69, 33, 130, 25, 794, 4],
#  [424,
#   740,
#   741,
#   31,
#   742,
#   4,
#   26,
#   291,
#   8,
#   795,
#   18,
#   26,
#   796,
#   164,
#   18,
#   797,
#   69,
#   4,
#   229,
#   36,
#   14,
#   139,
#   154,
#   7,
#   130,
#   25,
#   798,
#   4],
#  [26, 58, 59, 76, 4],
#  [26, 146, 229, 6, 4],
#  [26,
#   58,
#   59,
#   76,
#   16,
#   746,
#   70,
#   25,
#   4,
#   56,
#   26,
#   76,
#   116,
#   169,
#   57,
#   637,
#   57,
#   11,
#   180,
#   199,
#   8,
#   799,
#   800,
#   156,
#   750,
#   4],
#  [734,
#   747,
#   156,
#   344,
#   57,
#   11,
#   76,
#   4,
#   31,
#   337,
#   70,
#   169,
#   317,
#   801,
#   639,
#   18,
#   25,
#   22,
#   802,
#   639,
#   4],
#  [11,
#   76,
#   759,
#   6,
#   99,
#   787,
#   140,
#   18,
#   26,
#   76,
#   25,
#   4,
#   32,
#   58,
#   123,
#   803,
#   344,
#   41,
#   121,
#   66,
#   679,
#   68,
#   123,
#   804,
#   156,
#   344,
#   10],
#  [26,
#   58,
#   59,
#   134,
#   41,
#   748,
#   56,
#   25,
#   22,
#   305,
#   229,
#   233,
#   68,
#   377,
#   805,
#   759,
#   6,
#   771,
#   4],
#  [11,
#   76,
#   10,
#   32,
#   389,
#   59,
#   229,
#   806,
#   16,
#   807,
#   679,
#   70,
#   344,
#   57,
#   743,
#   70,
#   344,
#   10,
#   58,
#   123,
#   808,
#   344,
#   10,
#   58,
#   123,
#   407,
#   57,
#   123,
#   58,
#   59,
#   60,
#   62,
#   574,
#   809,
#   10,
#   68,
#   123,
#   60,
#   59,
#   246,
#   62,
#   574,
#   100,
#   785,
#   260,
#   10],
#  [123, 180, 181, 41, 407, 25, 41, 344, 4],
#  [100,
#   644,
#   22,
#   810,
#   57,
#   422,
#   785,
#   10,
#   377,
#   537,
#   140,
#   745,
#   422,
#   785,
#   120,
#   68,
#   22,
#   811,
#   4],
#  [390, 186, 57, 637, 4, 26, 134, 41, 751, 41, 11, 4],
#  [324,
#   139,
#   57,
#   324,
#   139,
#   57,
#   324,
#   139,
#   4,
#   11,
#   76,
#   32,
#   26,
#   774,
#   775,
#   33,
#   57,
#   139,
#   10],
#  [11, 76, 4],
#  [26, 27, 102, 41, 812, 552, 41, 294, 3, 4],
#  [11, 76, 25, 22, 99, 113, 34, 761, 4],
#  [127, 324, 139, 170, 57, 26, 137, 113, 121, 813, 156, 25, 10],
#  [170, 25, 22, 99, 113, 34, 761, 4],
#  [11,
#   76,
#   399,
#   11,
#   814,
#   3,
#   4,
#   11,
#   76,
#   68,
#   10,
#   6,
#   59,
#   25,
#   83,
#   761,
#   91,
#   26,
#   90,
#   750,
#   18,
#   229,
#   815,
#   8,
#   816,
#   159,
#   25,
#   10,
#   644,
#   57,
#   11,
#   60,
#   517,
#   8,
#   817,
#   100,
#   818,
#   65,
#   4],
#  [285, 22, 99, 759, 22, 766, 4],
#  [26,
#   58,
#   59,
#   76,
#   32,
#   25,
#   6,
#   57,
#   56,
#   535,
#   305,
#   26,
#   819,
#   69,
#   100,
#   79,
#   26,
#   60,
#   41,
#   820,
#   140,
#   165,
#   26,
#   39,
#   821,
#   567,
#   129,
#   822,
#   823,
#   4,
#   34,
#   429,
#   824,
#   825,
#   57,
#   305,
#   745,
#   305,
#   4],
#  [41, 53, 156, 68, 4],
#  [26, 826, 41, 42, 31, 827, 47, 4],
#  [20,
#   91,
#   285,
#   44,
#   57,
#   170,
#   68,
#   22,
#   25,
#   4,
#   68,
#   22,
#   16,
#   318,
#   70,
#   25,
#   4,
#   459,
#   552,
#   192,
#   57,
#   152,
#   57,
#   26,
#   198,
#   285,
#   22,
#   828,
#   197,
#   829,
#   344,
#   4],
#  [18, 170, 123, 137, 830, 25, 69, 156, 750, 4, 89, 637, 10, 58, 59, 831, 3, 4],
#  [127, 21, 4, 26, 27, 99, 832, 156, 778, 4],
#  [165, 25, 6, 4],
#  [26, 58, 59, 76, 4],
#  [26,
#   97,
#   59,
#   492,
#   25,
#   57,
#   26,
#   76,
#   552,
#   544,
#   4,
#   26,
#   36,
#   576,
#   164,
#   242,
#   833,
#   41,
#   552,
#   57,
#   11,
#   76,
#   10,
#   605,
#   785,
#   130,
#   26,
#   198,
#   70,
#   834,
#   100,
#   34,
#   835,
#   57,
#   26,
#   198,
#   70,
#   775,
#   4],
#  [637, 57, 21, 58, 11, 134, 10, 8, 786, 10],
#  [324, 139, 57, 170, 57, 637, 4, 220, 836, 222],
#  [26,
#   180,
#   150,
#   25,
#   422,
#   785,
#   70,
#   248,
#   4,
#   18,
#   26,
#   670,
#   574,
#   68,
#   91,
#   26,
#   426,
#   57,
#   750,
#   80,
#   837,
#   159,
#   759,
#   18,
#   170,
#   123,
#   487,
#   113,
#   60,
#   8,
#   380,
#   838,
#   18,
#   839,
#   80,
#   138,
#   708,
#   4],
#  [56, 91, 26, 97, 59, 58, 68, 33, 57, 26, 840, 60, 41, 121, 841, 842, 4],
#  [26,
#   137,
#   42,
#   69,
#   4,
#   26,
#   137,
#   42,
#   215,
#   18,
#   26,
#   137,
#   308,
#   841,
#   842,
#   57,
#   173,
#   202,
#   843,
#   4],
#  [26, 180, 73, 8, 348, 844, 100, 133, 72, 57, 8, 348, 845, 4],
#  [16, 761, 10, 16, 761, 44, 59, 846, 3, 4],
#  [55,
#   4,
#   26,
#   49,
#   25,
#   100,
#   29,
#   847,
#   8,
#   184,
#   4,
#   26,
#   58,
#   59,
#   185,
#   91,
#   26,
#   60,
#   41,
#   848,
#   100,
#   166,
#   324,
#   184,
#   72,
#   57,
#   130,
#   26,
#   849,
#   850,
#   26,
#   134,
#   25,
#   708,
#   4],
#  [26,
#   134,
#   333,
#   851,
#   57,
#   26,
#   134,
#   8,
#   852,
#   57,
#   26,
#   134,
#   466,
#   68,
#   26,
#   174,
#   450,
#   162,
#   41,
#   18,
#   775,
#   6,
#   46,
#   16,
#   853,
#   70,
#   68,
#   4,
#   260,
#   25,
#   22,
#   113,
#   733,
#   41,
#   178,
#   25,
#   4],
#  [66, 31, 57, 26, 80, 4],
#  [170, 492, 3, 649, 33, 4],
#  [26, 76, 68, 4, 170, 113, 492, 3, 649, 33, 4],
#  [20, 26, 39, 679, 49, 68, 4],
#  [106, 4, 11, 58, 59, 4, 26, 27, 8, 828, 854, 855, 4],
#  [32, 12, 229, 856, 552, 33, 10],
#  [285,
#   22,
#   73,
#   46,
#   202,
#   843,
#   422,
#   18,
#   29,
#   857,
#   785,
#   57,
#   32,
#   324,
#   70,
#   8,
#   858,
#   10],
#  [377, 537, 264, 265, 859, 113, 41, 85, 4],
#  [229, 22, 99, 102, 41, 294, 552, 4],
#  [25, 22, 181, 68, 159, 25, 4],
#  [21, 6, 102, 66, 33, 57, 860, 10],
#  [285, 6, 99, 237, 766, 4, 285, 861, 285, 22, 99, 4],
#  [170,
#   32,
#   6,
#   285,
#   665,
#   862,
#   10,
#   202,
#   843,
#   6,
#   863,
#   70,
#   864,
#   57,
#   32,
#   6,
#   285,
#   665,
#   862,
#   10,
#   482,
#   8,
#   265,
#   129,
#   87,
#   552,
#   285,
#   22,
#   865,
#   57,
#   56,
#   285,
#   426,
#   4],
#  [165,
#   285,
#   861,
#   21,
#   26,
#   76,
#   57,
#   68,
#   22,
#   32,
#   4,
#   285,
#   22,
#   866,
#   236,
#   8,
#   867,
#   4,
#   46,
#   34,
#   868,
#   869,
#   57,
#   26,
#   198,
#   70,
#   552,
#   491,
#   18,
#   26,
#   76,
#   68,
#   26,
#   27,
#   139,
#   4],
#  [377,
#   46,
#   31,
#   386,
#   870,
#   411,
#   783,
#   552,
#   871,
#   57,
#   860,
#   4,
#   11,
#   76,
#   872,
#   547,
#   57,
#   56,
#   99,
#   237,
#   750,
#   57,
#   99,
#   237,
#   873,
#   4],
#  [26,
#   134,
#   11,
#   41,
#   98,
#   26,
#   134,
#   11,
#   41,
#   874,
#   49,
#   229,
#   6,
#   787,
#   140,
#   57,
#   875,
#   70,
#   11,
#   4,
#   58,
#   59,
#   198,
#   26,
#   60,
#   59,
#   876,
#   11,
#   782,
#   762,
#   877,
#   552,
#   33,
#   4],
#  [26, 402, 59, 611, 100, 62, 878, 4],
#  [165,
#   91,
#   229,
#   22,
#   99,
#   787,
#   140,
#   57,
#   26,
#   137,
#   879,
#   162,
#   4,
#   245,
#   880,
#   57,
#   880,
#   324,
#   11,
#   49,
#   56,
#   32,
#   44,
#   31,
#   881,
#   16,
#   224,
#   882,
#   229,
#   537,
#   140,
#   4,
#   285,
#   883,
#   41,
#   884,
#   46,
#   237,
#   640,
#   18,
#   237,
#   608,
#   885,
#   46,
#   886,
#   4,
#   887,
#   15,
#   25,
#   57,
#   860,
#   57,
#   887,
#   4],
#  [113,
#   804,
#   156,
#   3,
#   57,
#   860,
#   4,
#   234,
#   176,
#   554,
#   8,
#   888,
#   571,
#   140,
#   46,
#   889,
#   890,
#   891,
#   332,
#   759,
#   4,
#   804,
#   156,
#   3,
#   4,
#   11,
#   57,
#   892,
#   324,
#   57,
#   60,
#   181,
#   41,
#   804,
#   4,
#   113,
#   804,
#   4],
#  [26, 97, 59, 492, 25, 4],
#  [32, 44, 68, 893, 11, 10],
#  [20, 173, 118, 173, 229, 113, 826, 41, 85, 552, 4],
#  [21,
#   58,
#   11,
#   298,
#   10,
#   11,
#   76,
#   229,
#   894,
#   242,
#   833,
#   41,
#   16,
#   766,
#   237,
#   429,
#   825,
#   57,
#   32,
#   80,
#   59,
#   229,
#   134,
#   41,
#   85,
#   552,
#   10],
#  [220,
#   836,
#   222,
#   11,
#   58,
#   59,
#   887,
#   15,
#   3,
#   49,
#   68,
#   4,
#   229,
#   12,
#   59,
#   90,
#   3,
#   61,
#   151,
#   332,
#   229,
#   87,
#   11,
#   4],
#  [38, 58, 11, 76, 229, 22, 247, 679, 159, 25, 10],
#  [245, 4, 127, 21, 4],
#  [260, 895, 4],
#  [11, 97, 59, 896, 552, 764, 4],
#  [38, 58, 11, 76, 32, 285, 426, 10],
#  [239, 887, 57, 25, 22, 8, 721, 184, 57, 135, 10, 32, 92, 123, 897, 10],
#  [21, 58, 11, 134, 3, 41, 58, 10, 21, 58, 11, 134, 10],
#  [898, 4],
#  [220, 836, 222],
#  [899, 752, 4],
#  [89, 4, 899, 752, 4],
#  [26,
#   76,
#   4,
#   324,
#   139,
#   57,
#   324,
#   139,
#   4,
#   324,
#   139,
#   4,
#   89,
#   4,
#   899,
#   752,
#   4,
#   21,
#   44,
#   68,
#   298,
#   57,
#   3,
#   892,
#   324,
#   10],
#  [887, 15, 11, 57, 11, 101, 900, 4],
#  [21, 60, 26, 181, 41, 901, 10, 21, 16, 53, 6, 16, 902, 156, 11, 57, 898, 10],
#  [11, 101, 16, 234, 116, 52, 665, 311, 237, 903, 4],
#  [25, 22, 99, 127, 541, 120, 25, 22, 8, 348, 169, 4],
#  [220, 836, 222, 11, 76, 57, 25, 22, 904, 33, 4, 16, 905, 6, 549, 4],
#  [26, 27, 99, 493, 57, 106, 4, 56, 26, 27, 118, 26, 97, 59, 649, 4],
#  [100, 116, 169, 57, 83, 188, 197, 236, 87, 3, 41, 121, 4],
#  [18, 170, 57, 11, 4, 11, 180, 73, 337, 70, 118],
#  [906, 70, 907, 908, 782, 26, 181, 33, 4],
#  [26, 909, 131, 80, 4],
#  [20, 688, 57, 459, 83, 188, 22, 767, 70, 768, 4, 32, 842, 80, 26, 849, 10],
#  [26, 57, 609, 4, 26, 146, 57, 26, 146, 68, 22, 337, 70, 32, 26, 571, 4],
#  [220, 836, 222],
#  [220, 221, 222],
#  [220, 221, 222],
#  [106, 4, 106],
#  [762, 57, 26, 180, 73, 910, 8, 72, 57, 72, 57, 305, 4],
#  [26, 911, 181, 215, 256, 785, 387, 4],
#  [11, 912, 41, 392, 3, 4],
#  [535, 184, 782, 4],
#  [26,
#   36,
#   491,
#   100,
#   11,
#   57,
#   762,
#   4,
#   11,
#   688,
#   174,
#   138,
#   913,
#   57,
#   11,
#   76,
#   4,
#   18,
#   130,
#   11,
#   12,
#   914,
#   392,
#   3,
#   57],
#  [915, 357, 16, 916, 4],
#  [26,
#   822,
#   779,
#   917,
#   11,
#   4,
#   324,
#   26,
#   670,
#   196,
#   36,
#   390,
#   357,
#   918,
#   91,
#   26,
#   36,
#   789,
#   491,
#   127,
#   72,
#   57,
#   918,
#   91,
#   11,
#   13,
#   679,
#   159,
#   3,
#   4],
#  [99, 49, 68, 11, 101, 99, 4],
#  [49, 759, 22, 873, 4, 58, 25, 49, 11, 57, 762, 4],
#  [762, 57, 21, 6, 25, 10],
#  [106, 4, 21, 6, 25, 10, 6, 25, 83, 188, 10],
#  [170, 21, 10, 762, 4, 247, 46, 83, 192, 57, 7, 36, 79, 919, 4],
#  [11, 180, 181, 41, 90, 3, 4],
#  [25, 80, 59, 920, 49, 31, 4],
#  [5, 57, 688, 4],
#  [38, 921, 10],
#  [922, 57, 923, 4],
#  [278, 4],
#  [58, 11, 665, 543, 68, 206, 10],
#  [165,
#   11,
#   790,
#   59,
#   543,
#   68,
#   206,
#   4,
#   172,
#   11,
#   60,
#   57,
#   11,
#   180,
#   924,
#   81,
#   172,
#   4,
#   11,
#   126,
#   3,
#   10],
#  [247,
#   3,
#   4,
#   18,
#   83,
#   166,
#   10,
#   762,
#   57,
#   7,
#   22,
#   521,
#   540,
#   46,
#   83,
#   166,
#   4,
#   83,
#   750,
#   144,
#   925,
#   70,
#   434,
#   290,
#   16,
#   905,
#   57,
#   11,
#   389,
#   138,
#   631,
#   70,
#   68,
#   4,
#   8,
#   888,
#   389,
#   138,
#   926,
#   100,
#   68,
#   4],
#  [21, 80, 26, 58, 156, 8, 273, 10],
#  [26, 76, 4, 25, 337, 70, 551, 69, 70, 927, 57, 12, 59, 25, 10],
#  [11, 101, 99, 493, 11, 571, 4],
#  [32, 99, 10],
#  [20, 4],
#  [21, 10],
#  [20,
#   26,
#   36,
#   337,
#   70,
#   928,
#   70,
#   929,
#   164,
#   66,
#   11,
#   154,
#   16,
#   732,
#   70,
#   8,
#   554,
#   78,
#   127,
#   4,
#   131,
#   113,
#   411,
#   25,
#   100,
#   930,
#   68,
#   123,
#   101,
#   324,
#   108,
#   4],
#  [11, 12, 10],
#  [127,
#   80,
#   11,
#   134,
#   41,
#   10,
#   26,
#   298,
#   57,
#   26,
#   146,
#   11,
#   60,
#   41,
#   76,
#   68,
#   22,
#   337,
#   70,
#   32,
#   26,
#   774,
#   11,
#   41,
#   849,
#   10],
#  [26, 931, 11, 4, 775, 57, 26, 931, 11, 4],
#  [26, 58, 59, 297, 60, 62, 932, 57, 68, 22, 324, 26, 76, 38, 41, 407, 4],
#  [39,
#   26,
#   933,
#   11,
#   10,
#   92,
#   11,
#   81,
#   85,
#   57,
#   26,
#   12,
#   59,
#   134,
#   41,
#   58,
#   25,
#   33,
#   156,
#   31,
#   934,
#   57,
#   66,
#   31,
#   935,
#   4,
#   26,
#   826,
#   25,
#   41,
#   138,
#   841,
#   202,
#   57,
#   333,
#   48,
#   936,
#   100,
#   875,
#   70,
#   514,
#   4],
#  [11,
#   543,
#   937,
#   33,
#   57,
#   11,
#   543,
#   68,
#   25,
#   22,
#   540,
#   33,
#   938,
#   4,
#   26,
#   113,
#   118,
#   26,
#   58,
#   59,
#   118,
#   26,
#   12,
#   59,
#   134,
#   118,
#   26,
#   12,
#   59,
#   134,
#   41,
#   411,
#   11,
#   783,
#   459,
#   61,
#   4],
#  [18, 229, 22, 520, 565, 10, 92, 11, 688, 10],
#  [32, 12, 59, 11, 10],
#  [11, 558, 79, 68, 939, 140, 10],
#  [32, 12, 59, 11, 23, 3, 76, 10],
#  [450, 3, 8, 118],
#  [450, 3, 8, 940, 4],
#  [644, 4, 26, 941, 11, 775, 4],
#  [245,
#   775,
#   57,
#   123,
#   92,
#   102,
#   41,
#   942,
#   260,
#   4,
#   26,
#   39,
#   102,
#   41,
#   148,
#   11,
#   127,
#   708,
#   4],
#  [26, 941, 11, 4],
#  [239, 57, 23, 22, 943, 333, 48, 4, 135, 10, 23, 22, 42, 69, 70, 33, 4],
#  [106, 25, 22, 521, 49, 68, 4, 944],
#  [5, 4, 26, 945, 26, 60, 73, 4, 56, 25, 22, 102, 459, 3, 4],
#  [26, 58, 59, 247, 76, 38, 41, 494, 4],
#  [25,
#   22,
#   113,
#   324,
#   946,
#   164,
#   156,
#   127,
#   921,
#   567,
#   65,
#   57,
#   11,
#   76,
#   10,
#   11,
#   76,
#   947,
#   26,
#   36,
#   46,
#   948,
#   70,
#   8,
#   949,
#   10],
#  [20, 26, 496, 86, 4],
#  [828, 197, 324, 4],
#  [11,
#   97,
#   59,
#   113,
#   950,
#   639,
#   8,
#   169,
#   49,
#   68,
#   165,
#   131,
#   13,
#   59,
#   113,
#   864,
#   4,
#   11,
#   76,
#   10],
#  [49,
#   100,
#   951,
#   57,
#   7,
#   36,
#   31,
#   116,
#   305,
#   25,
#   246,
#   73,
#   952,
#   100,
#   953,
#   651,
#   18,
#   31,
#   204,
#   229,
#   113,
#   571,
#   164,
#   41,
#   3,
#   18,
#   229,
#   635,
#   3,
#   237,
#   176,
#   954,
#   70,
#   955,
#   956,
#   4,
#   229,
#   113,
#   144,
#   86,
#   46,
#   34,
#   957,
#   4,
#   68,
#   22,
#   8,
#   405,
#   169,
#   57,
#   11,
#   76,
#   57,
#   56,
#   68,
#   22,
#   21,
#   337,
#   70,
#   209,
#   26,
#   246,
#   4],
#  [131,
#   12,
#   59,
#   958,
#   57,
#   131,
#   959,
#   960,
#   100,
#   288,
#   567,
#   4,
#   26,
#   298,
#   68,
#   57,
#   704,
#   4,
#   113,
#   8,
#   405,
#   151,
#   961,
#   18,
#   131,
#   80,
#   324,
#   138,
#   33,
#   962,
#   4],
#  [18,
#   26,
#   246,
#   31,
#   451,
#   236,
#   26,
#   36,
#   963,
#   86,
#   121,
#   186,
#   4,
#   172,
#   36,
#   734,
#   964,
#   57,
#   11,
#   76,
#   57,
#   56,
#   31,
#   116,
#   169,
#   36,
#   734,
#   199,
#   4,
#   25,
#   36,
#   337,
#   70,
#   8,
#   965,
#   57,
#   25,
#   22,
#   337,
#   70,
#   966,
#   57,
#   888,
#   100,
#   888,
#   4],
#  [41,
#   394,
#   68,
#   66,
#   41,
#   16,
#   967,
#   516,
#   57,
#   11,
#   76,
#   57,
#   6,
#   49,
#   333,
#   337,
#   70,
#   965,
#   18,
#   26,
#   248,
#   26,
#   80,
#   113,
#   148,
#   8,
#   968,
#   41,
#   86,
#   4],
#  [56,
#   170,
#   26,
#   571,
#   850,
#   18,
#   25,
#   36,
#   969,
#   57,
#   11,
#   76,
#   10,
#   16,
#   429,
#   169,
#   36,
#   113,
#   337,
#   70,
#   31,
#   334,
#   368,
#   970,
#   4,
#   11,
#   76,
#   57,
#   26,
#   551,
#   140,
#   41,
#   16,
#   971,
#   972,
#   516,
#   57,
#   26,
#   551,
#   41,
#   920,
#   4],
#  [973, 34, 202, 366, 18, 974, 8, 202, 975, 4],
#  [26,
#   298,
#   118,
#   11,
#   97,
#   59,
#   411,
#   309,
#   65,
#   69,
#   70,
#   8,
#   208,
#   4,
#   130,
#   11,
#   943,
#   68,
#   366,
#   18,
#   11,
#   85,
#   68,
#   202,
#   975,
#   57,
#   11,
#   60,
#   41,
#   76,
#   68,
#   25,
#   571,
#   69,
#   70,
#   16,
#   931,
#   68,
#   8,
#   888,
#   174,
#   60,
#   100,
#   107,
#   888,
#   4],
#  [18, 26, 12, 59, 134, 62, 70, 25, 4, 26, 146, 68, 976, 11, 4],
#  [26, 113, 134, 11, 41, 76, 775, 4],
#  [775, 57, 775, 4, 26, 39, 102, 41, 148, 8, 273, 100, 11, 4],
#  [136, 4],
#  [220, 836, 222],
#  [21, 10],
#  [21, 977, 10],
#  [68, 22, 99, 83, 977, 4],
#  [25, 22, 978, 120, 25, 22, 34, 977, 133, 4],
#  [11, 124, 382, 34, 977, 49, 25, 22, 113, 979, 4],
#  [38, 22, 68, 40, 41, 148, 3, 543, 10],
#  [5, 4],
#  [220, 221, 222],
#  [26, 27, 980, 4],
#  [25, 22, 745, 981, 57, 23, 22, 121, 4],
#  [7, 6, 106, 767, 4],
#  [68, 22, 34, 767, 4],
#  [20, 57, 170, 23, 22, 121, 4],
#  [99, 982, 4],
#  [26, 113, 58, 59, 4, 25, 22, 207, 4],
#  [111,
#   21,
#   164,
#   10,
#   26,
#   298,
#   605,
#   983,
#   984,
#   69,
#   70,
#   16,
#   985,
#   57,
#   131,
#   986,
#   357,
#   66,
#   16,
#   987,
#   57,
#   131,
#   984,
#   783,
#   18,
#   170,
#   131,
#   958,
#   4],
#  [26,
#   58,
#   59,
#   85,
#   32,
#   11,
#   101,
#   127,
#   658,
#   120,
#   31,
#   6,
#   59,
#   8,
#   463,
#   988,
#   989,
#   123,
#   92,
#   990,
#   159,
#   4,
#   25,
#   22,
#   983,
#   4,
#   25,
#   22,
#   8,
#   983,
#   377,
#   247,
#   991,
#   4],
#  [245, 992],
#  [26, 27, 113, 99, 4],
#  [5, 4],
#  [176,
#   305,
#   57,
#   11,
#   137,
#   993,
#   610,
#   57,
#   123,
#   181,
#   994,
#   995,
#   996,
#   57,
#   26,
#   181,
#   997,
#   46,
#   34,
#   998,
#   57,
#   11,
#   181,
#   8,
#   999,
#   1000,
#   18,
#   123,
#   181,
#   290,
#   8,
#   231,
#   1001,
#   18,
#   123,
#   12,
#   99,
#   85,
#   16,
#   1002,
#   4],
#  [258, 4, 123, 12, 59, 85, 86, 16, 1003, 358, 1004, 4],
#  [68, 22, 16, 1005, 4],
#  [159, 21, 10],
#  [21,
#   305,
#   6,
#   25,
#   10,
#   26,
#   198,
#   25,
#   22,
#   40,
#   41,
#   1006,
#   357,
#   1007,
#   57,
#   139,
#   10,
#   644,
#   57,
#   31,
#   6,
#   342,
#   57,
#   6,
#   59,
#   25,
#   57,
#   1008,
#   10,
#   887,
#   15,
#   31,
#   882,
#   123,
#   181,
#   33,
#   57,
#   135,
#   4],
#  [110,
#   26,
#   134,
#   41,
#   42,
#   8,
#   405,
#   1009,
#   164,
#   16,
#   1010,
#   57,
#   42,
#   783,
#   459,
#   324,
#   49,
#   16,
#   1011,
#   18,
#   16,
#   129,
#   57,
#   56,
#   118,
#   38,
#   92,
#   11,
#   168,
#   10],
#  [89, 4, 6, 68, 57, 6, 68, 98],
#  [106, 4, 68, 22, 113, 1012, 4, 26, 58, 59, 76, 4, 26, 97, 59, 90, 4],
#  [26,
#   58,
#   59,
#   76,
#   57,
#   482,
#   91,
#   11,
#   97,
#   59,
#   90,
#   57,
#   152,
#   57,
#   25,
#   22,
#   482,
#   99,
#   86,
#   57,
#   139,
#   10,
#   25,
#   22,
#   482,
#   102,
#   41,
#   138,
#   49,
#   31,
#   1013,
#   169,
#   57,
#   139,
#   10],
#  [245, 106, 4, 11, 76, 21, 26, 1014, 10],
#  [34,
#   977,
#   4,
#   644,
#   57,
#   38,
#   487,
#   26,
#   138,
#   127,
#   207,
#   10,
#   26,
#   97,
#   59,
#   804,
#   26,
#   1014,
#   34,
#   977,
#   4],
#  [16, 977, 57, 16, 1015, 116, 4, 7, 22, 234, 116, 57, 6, 59, 7, 10],
#  [1016, 6, 25, 10],
#  [245, 118, 20, 4, 5, 57, 70, 732, 4],
#  [106, 4],
#  [70,
#   732,
#   57,
#   994,
#   977,
#   4,
#   21,
#   22,
#   979,
#   6,
#   1017,
#   4,
#   3,
#   977,
#   1018,
#   1019,
#   977,
#   4],
#  [1020,
#   4,
#   644,
#   57,
#   38,
#   487,
#   123,
#   99,
#   198,
#   41,
#   394,
#   25,
#   10,
#   26,
#   574,
#   16,
#   988,
#   1021,
#   69,
#   57,
#   152,
#   4],
#  [58,
#   131,
#   317,
#   1006,
#   1022,
#   8,
#   863,
#   988,
#   10,
#   26,
#   58,
#   59,
#   610,
#   4,
#   36,
#   25,
#   863,
#   176,
#   1003,
#   10],
#  [135,
#   4,
#   92,
#   11,
#   980,
#   10,
#   58,
#   11,
#   134,
#   34,
#   1023,
#   10,
#   106,
#   10,
#   11,
#   76,
#   57,
#   123,
#   389,
#   60,
#   576,
#   16,
#   1024,
#   10,
#   994,
#   1024,
#   4],
#  [922,
#   4,
#   58,
#   11,
#   76,
#   57,
#   26,
#   389,
#   60,
#   576,
#   8,
#   1025,
#   680,
#   57,
#   133,
#   4,
#   8,
#   1025,
#   680,
#   57,
#   68,
#   80,
#   138,
#   113,
#   16,
#   1026,
#   139,
#   159,
#   260,
#   4,
#   135,
#   10],
#  [644,
#   57,
#   26,
#   27,
#   127,
#   658,
#   57,
#   26,
#   27,
#   49,
#   8,
#   204,
#   4,
#   26,
#   97,
#   59,
#   804,
#   26,
#   181,
#   69,
#   70,
#   16,
#   386,
#   156,
#   34,
#   1027,
#   1028,
#   164,
#   4],
#  [26,
#   1029,
#   91,
#   131,
#   174,
#   666,
#   3,
#   751,
#   78,
#   49,
#   543,
#   16,
#   1030,
#   46,
#   16,
#   997,
#   130,
#   123,
#   308,
#   357,
#   4],
#  [58, 11, 134, 34, 1023, 10],
#  [21,
#   10,
#   123,
#   113,
#   181,
#   33,
#   4,
#   21,
#   22,
#   16,
#   767,
#   70,
#   787,
#   324,
#   16,
#   206,
#   186,
#   33,
#   91,
#   123,
#   113,
#   1031,
#   357,
#   18,
#   121,
#   850,
#   10],
#  [139, 4],
#  [307, 57, 68, 22, 34, 767, 57, 133, 4],
#  [106,
#   57,
#   106,
#   4,
#   89,
#   4,
#   68,
#   22,
#   99,
#   34,
#   767,
#   4,
#   34,
#   767,
#   6,
#   7,
#   6,
#   106,
#   767,
#   46,
#   787,
#   186,
#   33,
#   91,
#   123,
#   113,
#   1031,
#   357,
#   18,
#   121,
#   850,
#   4,
#   58,
#   59,
#   11,
#   134,
#   41,
#   85,
#   25,
#   10],
#  [32, 99, 10],
#  [1032,
#   57,
#   31,
#   6,
#   49,
#   8,
#   1033,
#   1034,
#   4,
#   26,
#   298,
#   118,
#   129,
#   46,
#   1035,
#   80,
#   60,
#   41,
#   42,
#   1036,
#   1037,
#   18,
#   42,
#   1038,
#   1039,
#   41,
#   85,
#   31,
#   4,
#   25,
#   22,
#   113,
#   1040,
#   1041,
#   783,
#   100,
#   514,
#   120,
#   25,
#   22,
#   133,
#   348,
#   41,
#   111,
#   164,
#   4],
#  [5,
#   4,
#   56,
#   1042,
#   1043,
#   66,
#   16,
#   987,
#   6,
#   49,
#   16,
#   1044,
#   70,
#   1045,
#   405,
#   1046,
#   4,
#   324,
#   68,
#   1047,
#   357,
#   6,
#   1048,
#   1049,
#   78,
#   21,
#   41,
#   58,
#   81,
#   1050,
#   78,
#   1051,
#   78,
#   302,
#   4],
#  [31,
#   6,
#   8,
#   231,
#   882,
#   100,
#   605,
#   405,
#   209,
#   4,
#   25,
#   22,
#   49,
#   825,
#   22,
#   176,
#   1052,
#   4],
#  [5, 131, 58, 4],
#  [89,
#   118,
#   20,
#   57,
#   302,
#   4,
#   56,
#   25,
#   22,
#   8,
#   983,
#   52,
#   58,
#   79,
#   106,
#   567,
#   983,
#   58,
#   4,
#   25,
#   22,
#   49,
#   309,
#   1053,
#   1054,
#   41,
#   1055,
#   78,
#   49,
#   309,
#   1056,
#   68,
#   671,
#   960,
#   639,
#   16,
#   1057,
#   4],
#  [7,
#   22,
#   49,
#   1058,
#   33,
#   57,
#   7,
#   22,
#   1059,
#   4,
#   25,
#   22,
#   49,
#   8,
#   405,
#   1060,
#   70,
#   16,
#   1061,
#   4,
#   26,
#   113,
#   97,
#   59,
#   85,
#   38,
#   11,
#   101,
#   99,
#   1062,
#   4],
#  [100, 518, 10],
#  [644,
#   57,
#   26,
#   58,
#   59,
#   42,
#   25,
#   4,
#   11,
#   76,
#   16,
#   47,
#   305,
#   123,
#   571,
#   33,
#   57,
#   11,
#   240,
#   25,
#   36,
#   16,
#   544,
#   882,
#   70,
#   83,
#   825,
#   10],
#  [18,
#   176,
#   1003,
#   57,
#   26,
#   610,
#   1063,
#   11,
#   240,
#   57,
#   11,
#   13,
#   127,
#   658,
#   41,
#   42,
#   33,
#   68,
#   11,
#   58,
#   59,
#   610,
#   11,
#   1064,
#   83,
#   1065,
#   753,
#   123,
#   13,
#   46,
#   16,
#   366,
#   4],
#  [1066, 118, 123, 13, 59, 46, 8, 348, 1067, 4],
#  [123,
#   113,
#   13,
#   59,
#   46,
#   8,
#   348,
#   1067,
#   4,
#   26,
#   27,
#   352,
#   11,
#   57,
#   31,
#   6,
#   8,
#   197,
#   235,
#   1067,
#   4,
#   26,
#   60,
#   1068,
#   100,
#   605,
#   65,
#   4],
#  [887,
#   7,
#   57,
#   85,
#   10,
#   21,
#   22,
#   68,
#   10,
#   106,
#   57,
#   68,
#   22,
#   81,
#   68,
#   22,
#   113,
#   1069,
#   4],
#  [644,
#   57,
#   31,
#   6,
#   342,
#   4,
#   198,
#   159,
#   31,
#   4,
#   26,
#   76,
#   11,
#   92,
#   99,
#   1062,
#   57,
#   56,
#   113,
#   198,
#   159,
#   31,
#   4],
#  [139,
#   260,
#   69,
#   7,
#   57,
#   7,
#   6,
#   31,
#   1070,
#   70,
#   1015,
#   983,
#   18,
#   25,
#   22,
#   1071,
#   31,
#   206,
#   4,
#   106,
#   116,
#   1072,
#   86,
#   29,
#   1073,
#   57,
#   106,
#   116,
#   87,
#   86,
#   57,
#   106,
#   116,
#   247,
#   635,
#   86,
#   8,
#   1074,
#   4],
#  [113,
#   324,
#   15,
#   515,
#   57,
#   131,
#   296,
#   18,
#   131,
#   1075,
#   31,
#   88,
#   236,
#   72,
#   236,
#   16,
#   1076,
#   1010,
#   4,
#   18,
#   333,
#   1077,
#   405,
#   1078,
#   551,
#   639,
#   46,
#   1045,
#   1079,
#   18,
#   131,
#   324,
#   113,
#   296,
#   236,
#   116,
#   18,
#   912,
#   1080,
#   4],
#  [131,
#   92,
#   1080,
#   139,
#   260,
#   4,
#   131,
#   92,
#   1080,
#   236,
#   91,
#   68,
# ...
#   812,
#   162,
#   46,
#   34,
#   1247,
#   100,
#   1248,
#   1249,
#   4,
#   1210,
#   644,
#   57,
#   21,
#   44,
#   25,
#   324,
#   298,
#   10],
#  [245, 1216, 57, 11, 790, 59, 138, 1206, 4, 25, 22, 113, 21, 131, 134, 4],
#  [324,
#   70,
#   309,
#   1250,
#   1251,
#   52,
#   148,
#   825,
#   1252,
#   4,
#   11,
#   60,
#   41,
#   880,
#   15,
#   86,
#   57,
#   138,
#   1253,
#   4],
#  [11, 76, 57, 1254, 1255, 69, 16, 1256, 46, 1045, 1257, 57, 1258, 18, 1259, 4],
#  [245, 70, 732, 4, 123, 92, 1260, 70, 731, 4, 324, 139, 4],
#  [52, 861, 10],
#  [245, 106, 4, 68, 1261, 822, 1262, 112, 156, 994, 1263, 4],
#  [20, 25, 1264, 66, 38, 20, 123, 180, 271, 4],
#  [55, 4, 55, 156, 324, 70, 237, 547, 4],
#  [106,
#   57,
#   106,
#   57,
#   106,
#   57,
#   106,
#   4,
#   106,
#   4,
#   630,
#   6,
#   8,
#   224,
#   1265,
#   169,
#   4,
#   25,
#   22,
#   8,
#   1266,
#   405,
#   1058,
#   57,
#   25,
#   22,
#   324,
#   196,
#   156,
#   1267,
#   4],
#  [245, 4, 127, 6, 839, 57, 46, 16, 72, 1006, 4],
#  [23,
#   22,
#   138,
#   1268,
#   57,
#   18,
#   113,
#   1203,
#   309,
#   1269,
#   1270,
#   57,
#   135,
#   10,
#   23,
#   22,
#   1271,
#   1272,
#   18,
#   1273,
#   18,
#   575,
#   16,
#   672,
#   100,
#   236,
#   72,
#   236,
#   123,
#   174,
#   57,
#   11,
#   76,
#   57,
#   49,
#   1274,
#   57,
#   1275,
#   122,
#   280,
#   4],
#  [245,
#   849,
#   18,
#   940,
#   3,
#   1216,
#   358,
#   83,
#   756,
#   1276,
#   18,
#   1214,
#   1215,
#   69,
#   70,
#   83,
#   1277,
#   1278,
#   4],
#  [245,
#   85,
#   57,
#   26,
#   58,
#   59,
#   185,
#   21,
#   11,
#   58,
#   57,
#   85,
#   4,
#   11,
#   174,
#   1279,
#   752,
#   561,
#   18,
#   1006,
#   1280,
#   433,
#   16,
#   48,
#   1281,
#   18,
#   1006,
#   639,
#   156,
#   324,
#   70,
#   16,
#   864,
#   70,
#   16,
#   1282,
#   4,
#   26,
#   1283,
#   59,
#   407,
#   8,
#   1284,
#   57,
#   113,
#   236,
#   72,
#   236,
#   11,
#   931,
#   3,
#   544,
#   4],
#  [58, 11, 610, 68, 1285, 1286, 123, 246, 46, 1287, 10],
#  [16, 116, 733, 11, 144, 68, 1288, 1289, 1290, 1291, 46, 34, 739, 4],
#  [220, 675, 222],
#  [25, 36, 8, 799, 169, 4, 26, 1292, 25, 4],
#  [38, 72, 12, 68, 1293, 176, 10],
#  [263, 135, 4],
#  [56,
#   16,
#   1156,
#   116,
#   36,
#   46,
#   1294,
#   130,
#   83,
#   1295,
#   1296,
#   1226,
#   8,
#   1297,
#   46,
#   34,
#   202,
#   1298,
#   1299,
#   4],
#  [68, 36, 8, 1300, 57, 36, 59, 25, 10],
#  [26, 12, 99, 1230, 11, 224, 1301, 4],
#  [220, 221, 222, 26, 137, 779, 837, 237, 754, 4, 220, 221, 222],
#  [220, 221, 222, 123, 13, 224, 197, 1302, 170, 4],
#  [1303, 26, 804, 16, 518, 1304, 70, 68, 1293, 36, 1305, 1306, 4],
#  [18, 224, 197, 1237, 4],
#  [245, 4, 11, 909, 7, 36, 521, 46, 68, 4],
#  [1307, 10, 25, 36, 234, 8, 1308, 57, 405, 1309, 4],
#  [25,
#   36,
#   99,
#   4,
#   26,
#   665,
#   60,
#   25,
#   57,
#   18,
#   26,
#   1310,
#   25,
#   1311,
#   4,
#   25,
#   6,
#   224,
#   828,
#   4],
#  [26, 12, 99, 4, 11, 1312, 68, 429, 169, 164, 46, 83, 1313, 932, 4],
#  [20, 57, 21, 70, 25, 10],
#  [25, 635, 344, 8, 330, 70, 1314, 18, 25, 12, 59, 417, 3, 4],
#  [91,
#   11,
#   246,
#   59,
#   73,
#   127,
#   1315,
#   18,
#   1316,
#   57,
#   11,
#   779,
#   80,
#   60,
#   1317,
#   8,
#   169,
#   159,
#   25,
#   4],
#  [245, 1210, 4, 26, 27, 1318, 156, 31, 1319, 4],
#  [106, 4, 550, 11, 4],
#  [26, 58, 59, 76, 32, 11, 670, 134, 62, 57, 11, 180, 195, 246, 422, 1120, 4],
#  [26,
#   113,
#   198,
#   25,
#   22,
#   1320,
#   41,
#   121,
#   66,
#   18,
#   66,
#   18,
#   66,
#   159,
#   517,
#   8,
#   169,
#   4],
#  [25, 22, 1321, 8, 1322, 156, 11, 4],
#  [58, 59, 138, 207, 4],
#  [21, 10],
#  [106, 4, 26, 39, 113, 1323, 162, 1324, 100, 11, 4],
#  [245, 4, 25, 22, 8, 570, 22, 1325, 41, 1326, 16, 888, 4],
#  [106, 25, 6, 59, 4],
#  [11, 292, 164, 4],
#  [25, 22, 1327, 25, 54, 59, 1312, 517, 1328, 100, 11, 4],
#  [1329, 58, 59, 1330, 57, 131, 1331, 4],
#  [131,
#   1331,
#   4,
#   26,
#   58,
#   59,
#   185,
#   4,
#   58,
#   11,
#   126,
#   10,
#   26,
#   58,
#   59,
#   185,
#   91,
#   131,
#   1332,
#   18,
#   131,
#   1333,
#   159,
#   49,
#   1334,
#   4],
#  [55, 26, 12, 57, 1335, 8, 330, 4],
#  [764, 83, 763, 761, 4],
#  [11, 101, 1335, 1336, 57, 26, 441, 25, 22, 165, 11, 92, 1337, 4],
#  [11, 180, 317, 246, 8, 1338, 625, 4],
#  [66,
#   16,
#   1339,
#   57,
#   8,
#   1340,
#   70,
#   256,
#   174,
#   42,
#   1341,
#   1337,
#   66,
#   234,
#   116,
#   1342,
#   70,
#   1343,
#   4],
#  [245, 292, 164, 4],
#  [292, 164, 4],
#  [99, 224, 1327, 57, 1216, 4, 32, 58, 59, 11, 60, 333, 151, 1343, 4],
#  [32, 10],
#  [7, 92, 106, 129, 1344, 120, 25, 22, 8, 1345, 22, 1346, 4],
#  [131, 92, 783, 46, 1347, 4],
#  [1031, 25, 66, 516, 57, 365, 4],
#  [136, 91, 11, 1348, 66, 734, 1349, 18, 1275, 4],
#  [11, 92, 939, 133, 1350, 57, 404, 41, 71, 752, 4],
#  [26,
#   402,
#   59,
#   4,
#   23,
#   121,
#   57,
#   23,
#   121,
#   70,
#   3,
#   4,
#   895,
#   57,
#   895,
#   10,
#   26,
#   27,
#   1351,
#   18,
#   1352,
#   70,
#   1353,
#   41,
#   11,
#   57,
#   11,
#   1354,
#   1355,
#   4],
#  [245,
#   292,
#   164,
#   4,
#   23,
#   121,
#   4,
#   26,
#   1101,
#   11,
#   57,
#   26,
#   1101,
#   11,
#   4,
#   58,
#   11,
#   666,
#   10,
#   11,
#   92,
#   8,
#   1356,
#   18,
#   1208,
#   18,
#   1236,
#   1357,
#   4],
#  [31, 6, 16, 318, 4, 58, 11, 666, 3, 10, 914, 18, 565, 4],
#  [245, 4, 55, 26, 39, 4],
#  [55,
#   26,
#   39,
#   4,
#   1358,
#   25,
#   4,
#   1358,
#   25,
#   4,
#   23,
#   121,
#   70,
#   3,
#   4,
#   245,
#   4,
#   11,
#   101,
#   8,
#   1205,
#   1359,
#   4,
#   26,
#   1360,
#   18,
#   26,
#   1101,
#   11,
#   4,
#   294,
#   11,
#   516,
#   10,
#   779,
#   57,
#   779,
#   57,
#   779,
#   4,
#   26,
#   574,
#   11,
#   958,
#   46,
#   1361,
#   57,
#   11,
#   1362,
#   1363,
#   1364,
#   4],
#  [123, 13, 224, 197, 1302, 170, 4],
#  [1303, 26, 804, 16, 518, 1304, 70, 68, 1293, 36, 1305, 1306, 4],
#  [26, 909, 521, 70, 16, 906, 4, 11, 1121, 1307, 459, 344, 4],
#  [25, 36, 1365, 156, 1366, 4, 46, 16, 1156, 1367, 1368, 57, 133, 4],
#  [11, 551, 69, 70, 83, 206, 41, 1369, 3, 154, 1305, 1306, 4],
#  [20, 57, 11, 23, 344, 940, 11, 57, 135, 10, 11, 240, 11, 12, 4],
#  [21, 70, 25, 10],
#  [21, 159, 3, 10],
#  [68, 22, 8, 721, 767, 70, 768, 57, 26, 790, 407, 4],
#  [127,
#   39,
#   1370,
#   26,
#   27,
#   1318,
#   1371,
#   4,
#   220,
#   675,
#   222,
#   58,
#   11,
#   134,
#   333,
#   1343,
#   10],
#  [26, 137, 60, 8, 405, 57, 26, 198, 4],
#  [106, 94, 780, 4, 1372, 57, 131, 92, 224, 1274, 653, 4],
#  [11,
#   174,
#   642,
#   347,
#   422,
#   1120,
#   70,
#   1168,
#   8,
#   429,
#   1373,
#   72,
#   57,
#   102,
#   66,
#   18,
#   66,
#   18,
#   66,
#   4],
#  [245,
#   4,
#   58,
#   59,
#   138,
#   127,
#   1181,
#   4,
#   113,
#   165,
#   11,
#   58,
#   59,
#   881,
#   41,
#   134,
#   116,
#   15,
#   16,
#   1043,
#   4],
#  [297, 57, 1374, 4],
#  [521, 4],
#  [11, 102, 69, 841, 57, 1210, 10],
#  [68, 1375, 54, 1376, 34, 1377, 4],
#  [20, 236, 8, 902, 70, 1147, 57, 55, 57, 68, 22, 1378, 1204, 4],
#  [55, 25, 6, 4],
#  [245,
#   297,
#   4,
#   25,
#   22,
#   8,
#   1203,
#   11,
#   12,
#   59,
#   60,
#   62,
#   1343,
#   57,
#   25,
#   80,
#   60,
#   199,
#   11,
#   8,
#   405,
#   410,
#   1379,
#   4],
#  [1330, 57, 1330, 57, 1330, 4, 11, 76, 11, 92, 49, 8, 405, 1380, 4],
#  [878,
#   4,
#   131,
#   60,
#   8,
#   420,
#   70,
#   1381,
#   526,
#   1045,
#   1382,
#   18,
#   131,
#   1330,
#   4,
#   131,
#   1330,
#   4],
#  [12, 11, 85, 197, 70, 1305, 1306, 745, 994, 1171, 10],
#  [18,
#   26,
#   945,
#   11,
#   23,
#   344,
#   940,
#   11,
#   8,
#   348,
#   1383,
#   151,
#   332,
#   57,
#   133,
#   4,
#   55,
#   4,
#   26,
#   945,
#   11,
#   209,
#   246,
#   8,
#   1384,
#   305,
#   57,
#   135,
#   10,
#   324,
#   69,
#   57,
#   106,
#   1385,
#   15,
#   324,
#   4,
#   20,
#   57,
#   11,
#   779,
#   297,
#   246,
#   197,
#   1372,
#   4],
#  [26, 198, 26, 39, 99, 46, 16, 1386, 1060, 1337, 4],
#  [26,
#   198,
#   26,
#   1387,
#   515,
#   358,
#   68,
#   26,
#   180,
#   246,
#   422,
#   320,
#   1168,
#   1120,
#   16,
#   429,
#   1373,
#   72,
#   4,
#   8,
#   1340,
#   70,
#   256,
#   174,
#   99,
#   42,
#   1337,
#   66,
#   68,
#   4],
#  [68,
#   22,
#   224,
#   371,
#   1374,
#   4,
#   38,
#   159,
#   8,
#   1340,
#   70,
#   424,
#   10,
#   78,
#   8,
#   1340,
#   70,
#   1025,
#   10,
#   78,
#   8,
#   1340,
#   70,
#   1388,
#   10,
#   123,
#   174,
#   42,
#   8,
#   348,
#   405,
#   1319,
#   102,
#   66,
#   159,
#   31,
#   57,
#   11,
#   76,
#   57,
#   1389,
#   1390,
#   4],
#  [220, 221, 222, 68, 22, 8, 224, 348, 451, 4, 26, 198, 26, 822, 4],
#  [887,
#   57,
#   11,
#   235,
#   1031,
#   68,
#   639,
#   4,
#   26,
#   58,
#   59,
#   134,
#   41,
#   1391,
#   164,
#   16,
#   129,
#   1344,
#   4],
#  [20, 170, 11, 137, 1391, 164, 16, 129, 1392, 4],
#  [31, 6, 106, 305, 70, 1003, 100, 1347, 4],
#  [26, 822, 58, 106, 517, 169, 4],
#  [822, 11, 1031, 68, 639, 57, 25, 22, 973, 3, 1393, 4],
#  [1031, 25, 639, 4],
#  [1374, 57, 895, 57, 895, 4],
#  [245, 4, 68, 22, 224, 1394, 1395, 4],
#  [11,
#   92,
#   8,
#   1396,
#   57,
#   1397,
#   57,
#   1398,
#   712,
#   57,
#   1399,
#   405,
#   1363,
#   18,
#   26,
#   779,
#   134,
#   41,
#   85,
#   11,
#   516,
#   236,
#   72,
#   236,
#   26,
#   942,
#   4],
#  [11, 101, 99, 102, 49, 31, 4],
#  [11, 101, 99, 4],
#  [292,
#   164,
#   4,
#   292,
#   164,
#   4,
#   644,
#   57,
#   26,
#   80,
#   59,
#   294,
#   11,
#   516,
#   91,
#   11,
#   571,
#   1400,
#   140,
#   41,
#   3,
#   66,
#   8,
#   1401,
#   1402,
#   4,
#   11,
#   92,
#   8,
#   1396,
#   57,
#   1397,
#   57,
#   298,
#   405,
#   1403,
#   18,
#   26,
#   779,
#   134,
#   41,
#   85,
#   11,
#   516,
#   236,
#   72,
#   236,
#   26,
#   942,
#   4],
#  [242, 4],
#  [34, 1223, 6, 1113, 4],
#  [31, 6, 118, 83, 1404, 83, 47, 287, 6, 1405, 10],
#  [68, 22, 113, 1242, 26, 328, 11, 1406, 46, 540, 1407, 4],
#  [21, 92, 11, 118, 21, 22, 118, 21, 92, 11, 1408, 100, 10],
#  [107, 30, 10],
#  [136, 4, 127, 26, 104, 30, 4],
#  [106, 57, 26, 104, 83, 30, 41, 450, 11, 8, 1409, 30, 4],
#  [25, 22, 297, 132, 91, 11, 60, 8, 9, 156, 25, 118, 173, 11, 389, 98],
#  [20, 57, 58, 11, 60, 83, 117, 10],
#  [11, 60, 8, 50, 51, 10],
#  [21, 58, 11, 441, 3, 41, 58, 10],
#  [482, 4],
#  [647, 4],
#  [418, 4, 11, 76, 118],
#  [26,
#   1410,
#   1411,
#   58,
#   59,
#   126,
#   21,
#   11,
#   134,
#   4,
#   8,
#   1412,
#   22,
#   1413,
#   78,
#   8,
#   1076,
#   30,
#   4],
#  [89, 4],
#  [21, 118, 20, 57, 58, 11, 60, 8, 1412, 22, 1413, 10],
#  [170, 38, 39, 26, 40, 41, 450, 11, 8, 1076, 30, 10],
#  [58, 59, 211, 83, 1414, 156, 3, 4],
#  [58, 59, 751, 41, 3, 49, 26, 27, 8, 1340, 4],
#  [58,
#   11,
#   76,
#   38,
#   72,
#   26,
#   180,
#   73,
#   74,
#   33,
#   10,
#   38,
#   72,
#   60,
#   11,
#   894,
#   46,
#   1076,
#   10],
#  [173,
#   11,
#   779,
#   73,
#   41,
#   16,
#   1415,
#   4,
#   358,
#   57,
#   173,
#   11,
#   389,
#   42,
#   140,
#   46,
#   88,
#   4,
#   11,
#   76,
#   21,
#   10,
#   390,
#   46,
#   88,
#   516,
#   18,
#   91,
#   11,
#   42,
#   34,
#   486,
#   812,
#   100,
#   105,
#   116,
#   4],
#  [26, 27, 1378, 899, 4],
#  [263, 135, 4, 26, 12, 59, 849, 33, 42, 46, 1416, 793, 1004, 4],
#  [131, 58, 59, 659, 3, 321, 41, 1383, 129, 49, 11, 4],
#  [32, 10],
#  [5, 4],
#  [127,
#   11,
#   101,
#   99,
#   102,
#   41,
#   114,
#   3,
#   8,
#   550,
#   11,
#   509,
#   57,
#   6,
#   68,
#   8,
#   9,
#   10,
#   6,
#   83,
#   92,
#   99,
#   102,
#   118],
#  [245, 57, 1210, 4, 245, 57, 1417, 57, 1418, 4],
#  [390, 140, 186, 4],
#  [55, 57, 3, 4, 89, 57, 89, 33, 123, 121, 4],
#  [89, 57, 127, 1406, 69, 324, 605, 84, 98],
#  [18, 26, 60, 31, 95, 70, 30, 33, 127, 118],
#  [55, 57, 1405, 4],
#  [20, 118],
#  [26, 27, 113, 1408, 100, 107, 30, 4],
#  [55,
#   4,
#   26,
#   27,
#   40,
#   41,
#   60,
#   422,
#   84,
#   70,
#   30,
#   100,
#   31,
#   4,
#   25,
#   22,
#   8,
#   72,
#   760,
#   57,
#   26,
#   27,
#   40,
#   41,
#   60,
#   422,
#   84,
#   70,
#   30,
#   100,
#   31,
#   567,
#   338,
#   26,
#   297,
#   58,
#   59,
#   42,
#   290,
#   56,
#   26,
#   104,
#   107,
#   118],
#  [26, 60, 25, 139, 33, 57, 55, 4],
#  [56, 68, 22, 118],
#  [68,
#   22,
#   32,
#   26,
#   27,
#   33,
#   57,
#   68,
#   22,
#   32,
#   26,
#   36,
#   491,
#   46,
#   31,
#   88,
#   4,
#   26,
#   104,
#   41,
#   42,
#   107,
#   95,
#   70,
#   30,
#   4],
#  [106, 57, 26, 58, 59, 60, 8, 117, 4],
#  [26,
#   58,
#   59,
#   733,
#   25,
#   6,
#   152,
#   57,
#   26,
#   58,
#   59,
#   60,
#   156,
#   3,
#   4,
#   174,
#   26,
#   42,
#   25,
#   459,
#   841,
#   10,
#   26,
#   298,
#   118],
#  [26, 482, 60, 41, 121, 307, 107, 88, 41, 42, 34, 50, 51, 58, 59, 26, 10],
#  [11, 101, 224, 388, 4, 21, 22, 83, 287, 10],
#  [418, 57, 647, 4],
#  [127, 174, 11, 492, 3, 78, 99, 10],
#  [89, 4, 220, 836, 222],
#  [26, 104, 1076, 30, 4],
#  [66, 1419, 70, 605, 567, 256, 84, 70, 30, 510, 26, 195, 60, 4],
#  [106, 57, 26, 58, 59, 60, 1412, 22, 1413, 4],
#  [12, 11, 247, 887, 15, 16, 95, 10, 26, 1406, 25, 69, 324, 605, 1420, 98],
#  [12, 11, 247, 887, 15, 16, 95, 10, 26, 180, 195, 1421, 605, 725, 4],
#  [89, 4],
#  [91, 25, 1422, 11, 1358, 1423, 49, 8, 1340, 4],
#  [26, 60, 73, 41, 1076, 34, 429, 98],
#  [26, 39, 99, 118, 26, 27, 99, 28, 41, 140, 68, 88, 4],
#  [89,
#   57,
#   89,
#   23,
#   22,
#   124,
#   994,
#   1424,
#   186,
#   57,
#   89,
#   10,
#   26,
#   12,
#   59,
#   849,
#   33,
#   41,
#   42,
#   46,
#   1416,
#   793,
#   4],
#  [26,
#   12,
#   99,
#   849,
#   46,
#   33,
#   41,
#   42,
#   46,
#   8,
#   1416,
#   793,
#   156,
#   11,
#   57,
#   324,
#   139,
#   10],
#  [113, 404, 18, 492, 3, 4],
#  [129,
#   49,
#   3,
#   57,
#   21,
#   6,
#   68,
#   40,
#   41,
#   298,
#   10,
#   11,
#   76,
#   57,
#   31,
#   6,
#   1092,
#   4,
#   6,
#   7,
#   49,
#   8,
#   385,
#   33,
#   57,
#   6,
#   7,
#   834,
#   842,
#   68,
#   26,
#   174,
#   751,
#   41,
#   10],
#  [32, 10],
#  [32, 57, 165, 26, 27, 1351, 70, 990, 41, 11, 4],
#  [1425,
#   11,
#   101,
#   1426,
#   99,
#   990,
#   41,
#   3,
#   57,
#   11,
#   101,
#   113,
#   1416,
#   15,
#   3,
#   57,
#   1427,
#   3,
#   18,
#   352,
#   3,
#   26,
#   97,
#   59,
#   103,
#   69,
#   84,
#   139,
#   4],
#  [245,
#   57,
#   106,
#   1032,
#   4,
#   18,
#   11,
#   101,
#   102,
#   41,
#   1428,
#   16,
#   1429,
#   509,
#   133,
#   4,
#   25,
#   22,
#   8,
#   1430,
#   4,
#   25,
#   22,
#   102,
#   41,
#   138,
#   8,
#   348,
#   57,
#   721,
#   1431,
#   4],
#  [21, 22, 1432, 10],
#  [130, 10],
#  [92, 11, 442, 3, 10],
#  [38, 118],
#  [38, 174, 131, 58, 68, 10],
#  [131, 240, 11, 101, 850, 100, 15, 1386, 424, 785, 4],
#  [220, 836, 222],
#  [68, 22, 99, 194, 4],
#  [220, 836, 222],
#  [26, 58, 59, 247, 76, 21, 41, 90, 11, 4],
#  [21, 159, 16, 1433, 672, 10],
#  [3, 10, 26, 27, 99, 1434, 159, 3, 4],
#  [38, 58, 11, 76, 10],
#  [11, 101, 102, 156, 16, 777, 653, 10],
#  [317, 57, 26, 317, 58, 4],
#  [25, 22, 99, 16, 777, 152, 4],
#  [123, 487, 901, 783, 4],
#  [1435, 258, 4, 123, 137, 1436, 8, 1437, 18, 779, 849, 69, 4],
#  [220, 221, 222, 1438, 4],
#  [58, 59, 407, 68, 4],
#  [26, 137, 114, 11, 8, 143, 535, 862, 184, 4],
#  [26, 931, 11, 133, 4],
#  [239, 57, 647, 849, 46, 33, 4],
#  [26, 60, 41, 121, 140, 4],
#  [26, 113, 181, 8, 143, 26, 60, 41, 121, 140, 4],
#  [47, 169, 1439, 742, 4],
#  [26, 58, 59, 126, 57, 26, 58, 59, 1440, 98],
#  [131, 174, 58, 25, 4],
#  [26, 146, 131, 174, 58, 25, 57],
#  [16,
#   1441,
#   1442,
#   6,
#   26,
#   146,
#   297,
#   1443,
#   1444,
#   18,
#   170,
#   839,
#   54,
#   41,
#   121,
#   4,
#   123,
#   324,
#   60,
#   41,
#   121,
#   140,
#   57,
#   34,
#   429,
#   1445,
#   102,
#   140,
#   4],
#  [26, 97, 59, 804, 25, 4, 26, 113, 181, 140, 4],
#  [127, 5, 57, 123, 201, 1439, 118],
#  [118, 123, 101, 324, 1446, 69, 4],
#  [26, 113, 181, 26, 543, 49, 26, 27, 46, 1447, 110, 4],
#  [26, 58, 59, 76, 4],
#  [26, 146, 11, 101, 113, 102, 41, 60, 41, 60, 25, 43, 3, 4],
#  [239, 895, 57, 25, 22, 102, 41, 138, 89, 152, 57, 324, 139, 10],
#  [11, 101, 102, 41, 138, 136, 4],
#  [26, 27, 102, 41, 138, 136, 133, 57, 89, 10],
#  [26, 76, 26, 60, 8, 348, 118, 26, 60, 8, 297, 348, 1448, 70, 209, 156, 3, 4],
#  [123, 101, 102, 41, 138, 89, 4],
#  [58, 1449, 3, 11, 101, 102, 41, 411, 8, 330, 70, 193, 4],
#  [26, 76, 4],
#  [26, 113, 1450, 7, 36, 79, 26, 487, 58, 4],
#  [1006, 783, 10],
#  [26, 297, 58, 59, 134, 41, 121, 57, 26, 58, 59, 134, 41, 121, 118],
#  [26, 27, 1451, 4],
#  [26, 931, 11, 4],
#  [21, 10],
#  [220, 836, 222],
#  [32, 10],
#  [6, 285, 66, 16, 1006, 10],
#  [245, 57, 285, 113, 286, 41, 294, 11, 4],
#  [68,
#   22,
#   969,
#   4,
#   68,
#   22,
#   213,
#   4,
#   733,
#   22,
#   285,
#   459,
#   10,
#   173,
#   11,
#   174,
#   42,
#   8,
#   1452,
#   299,
#   4],
#  [68, 22, 127, 626, 4, 263, 135, 4],
#  [220, 221, 222, 32, 12, 285, 343, 11, 10, 733, 13, 11, 10],
#  [11,
#   13,
#   15,
#   8,
#   672,
#   10,
#   18,
#   285,
#   22,
#   49,
#   239,
#   4,
#   11,
#   167,
#   1453,
#   285,
#   22,
#   49,
#   4],
#  [68, 22, 1454, 118, 5, 4],
#  [20,
#   26,
#   180,
#   1317,
#   129,
#   52,
#   60,
#   196,
#   31,
#   358,
#   4,
#   5,
#   4,
#   11,
#   346,
#   25,
#   22,
#   297,
#   731,
#   110,
#   1425,
#   11,
#   60,
#   49,
#   8,
#   1455,
#   1456,
#   672,
#   18,
#   324,
#   83,
#   182,
#   849,
#   154,
#   18,
#   49,
#   118],
#  [5,
#   4,
#   5,
#   4,
#   18,
#   170,
#   5,
#   57,
#   18,
#   170,
#   11,
#   76,
#   49,
#   11,
#   487,
#   49,
#   11,
#   487,
#   58,
#   49,
#   49,
#   1457,
#   552,
#   100,
#   8,
#   330,
#   70,
#   166],
#  [49,
#   148,
#   552,
#   1458,
#   16,
#   1459,
#   68,
#   11,
#   256,
#   60,
#   41,
#   942,
#   593,
#   46,
#   57,
#   11,
#   76,
#   4,
#   18,
#   11,
#   402,
#   59,
#   659,
#   62,
#   1458,
#   78,
#   11,
#   659,
#   49,
#   57,
#   8,
#   265,
#   277,
#   8,
#   177,
#   78,
#   79,
#   4],
#  [5, 4],
#  [1460, 57, 11, 1461, 69, 4],
#  [5, 4, 34, 1462, 92, 1463, 18, 1464, 21, 6, 25, 57, 58, 11, 76, 10],
#  [245, 26, 58, 59, 76, 4, 220, 221, 222],
#  [26, 58, 59, 76, 42, 25, 46, 1465, 4],
#  [5, 4],
#  [38, 1466, 4, 11, 389, 60, 8, 838, 66, 16, 987, 4],
#  [5, 57, 15, 882, 4],
#  [245, 5, 57, 1467, 57, 1467, 4],
#  [38, 1466, 4, 11, 389, 148, 552, 394, 324, 83, 182, 133, 4],
#  [220,
#   675,
#   222,
#   285,
#   22,
#   181,
#   41,
#   138,
#   1468,
#   4,
#   266,
#   1469,
#   267,
#   4,
#   68,
#   22,
#   969,
#   4],
#  [969, 4],
#  [11, 101, 8, 1470, 57, 1470, 57, 1470, 888, 4],
#  ...]

# %% [markdown]
# ## 03 save as numpy
# - max length = 128 (100% coverage)

# %%
np_trans = np.zeros( [10039, 128], dtype=np.int)
np.shape(np_trans)
# Out:
# (10039, 128)

# %%
for i in range( len(index_lines) ):
    
    if len( index_lines[i] ) > 127:
        np_trans[i][:] = index_lines[i][:128]
    else:
        np_trans[i][:len(index_lines[i])] = index_lines[i][:]

# %%
np.save('../data/processed/IEMOCAP/processed_trans.npy', np_trans)

# %%
np.shape(np_trans)
# Out:
# (10039, 128)

# %% [markdown]
# ## 03 save as numpy - G case - ues it when ready
# - max length = 128 (100% coverage)

# %%
# len(index_lines)

# %%
# np_trans = np.zeros( [5531, 128], dtype=np.int)
# np.shape(np_trans)

# %%
# for i in xrange( len(index_lines) ):
    
#     if len( index_lines[i] ) > 127:
#         np_trans[i][:] = index_lines[i][:128]
#     else:
#         np_trans[i][:len(index_lines[i])] = index_lines[i][:]

# %%
# np.save('../data/processed/IEMOCAP/processed_trans_G.npy', np_trans)
# np.shape(np_trans)
