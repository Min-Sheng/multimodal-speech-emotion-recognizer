# %% [markdown]
# # IEMOCAP

# %% [markdown]
# ## 01  extract transcript

# %%
import csv
import os
from file_util import *

# %%
create_folder('../data/processed/IEMOCAP')

# %%
out_file = '../data/processed/IEMOCAP/processed_tran.csv'
os.system('rm ' + out_file)
# Out:
# 256

# %%
def extract_trans( list_in_file, out_file ) :
    
    lines = []
    
    for in_file in list_in_file:
        cnt = 0
        
        with open(in_file, 'r') as f:
            lines = f.readlines()
            
        with open(out_file, 'a') as f:

            csv_writer = csv.writer( f )
            lines = sorted(lines)                  # sort based on first element
            
            for line in lines:

                name = line.split(':')[0].split(' ')[0].strip()
                
                # unwanted case 
                if name[:3] != 'Ses':             # noise transcription such as reply  M: sorry
                    continue
                elif name[-3:-1] == 'XX':        # we don't have matching pair in label
                    continue
                trans = line.split(':')[1].strip()
                
                cnt += 1
                csv_writer.writerow([name, trans])

# %%
# [schema] ID, transcriptions [csv]

list_files = []

for x in range(5):
    sess_name = 'Session' + str(x+1)

    path = '/media/vincentwu-cmlab/7C5650545650116E/IEMOCAP_full_release/' + sess_name + '/dialog/transcriptions/'
    file_search(path, list_files)
    list_files = sorted(list_files)

    print(sess_name + ", #sum files: " + str(len(list_files)))

extract_trans(list_files, out_file)
# Out:
# Session1, #sum files: 28
# Session2, #sum files: 58
# Session3, #sum files: 90
# Session4, #sum files: 120
# Session5, #sum files: 151

# %% [markdown]
# ## 02 extract label

# %%
import csv
import os
import sys
import numpy as np
from file_util import *

# %%
out_file = '../data/processed/IEMOCAP/label.csv'
os.system('rm ' + out_file)
# Out:
# 256

# %%
list_category = [
                'ang',
                'hap',
                'sad',
                'neu',
                'fru',
                'exc',
                'fea',
                'sur',
                'dis',
                'oth',
                'xxx'
                ]

category = {}
for c_type in list_category:
    if c_type in category:
        pass
    else:
        category[c_type] = len(category)

# %%
def find_category(lines):
    is_target = True
    
    id = ''
    c_label = ''
    list_ret = []
    
    for line in lines:
        if is_target == True:
            
            try:
                id          = line.split('\t')[1].strip()  #  extract ID
                print(line, line.split('\t')[2].strip())
                c_label  = line.split('\t')[2].strip()  #  extract category
                if c_label not in category:
                    print("ERROR nokey" + c_label)
                    sys.exit()
                
                list_ret.append( [id, c_label] )
                is_target = False

            except:
                print("ERROR " + line)
                sys.exit()
        
        else:
            if line == '\n':
                is_target = True
        
    return list_ret

# %%
def extract_labels( list_in_file, out_file ) :
    id = ''
    lines = []
    list_ret = []
    
    for in_file in list_in_file:
        print(in_file)
        with open(in_file, 'r') as f:
            lines = f.readlines()
            lines = lines[2:]                           # remove head
            list_ret = find_category(lines)

        list_ret = sorted(list_ret)                   # sort based on first element

        with open(out_file, 'a') as f:
            csv_writer = csv.writer( f )
            csv_writer.writerows( list_ret )

# %%
# [schema] ID, label [csv]

list_files = []
list_avoid_dir = ['Attribute', 'Categorical', 'Self-evaluation']

for x in range(5):
    sess_name = 'Session' + str(x+1)

    path = '/media/vincentwu-cmlab/7C5650545650116E/IEMOCAP_full_release/' + sess_name + '/dialog/EmoEvaluation/'
    file_search(path, list_files, list_avoid_dir)
    list_files = sorted(list_files)
    #print(list_files)
    print(sess_name + ", #sum files: " + str(len(list_files)))

extract_labels(list_files, out_file)
# Out:
# Session1, #sum files: 28
# Session2, #sum files: 58
# Session3, #sum files: 90
# Session4, #sum files: 120
# Session5, #sum files: 151
# /media/vincentwu-cmlab/7C5650545650116E/IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_impro01.txt
# [6.2901 - 8.2357]	Ses01F_impro01_F000	neu	[2.5000, 2.5000, 2.5000]
#  neu
# [10.0100 - 11.3925]	Ses01F_impro01_F001	neu	[2.5000, 2.5000, 2.5000]
#  neu
# [14.8872 - 18.0175]	Ses01F_impro01_F002	neu	[2.5000, 2.5000, 2.5000]
#  neu
# [19.2900 - 20.7875]	Ses01F_impro01_F003	xxx	[2.5000, 3.0000, 3.0000]
#  xxx
# [21.3257 - 24.7400]	Ses01F_impro01_F004	xxx	[2.5000, 3.0000, 2.5000]
#  xxx
# [27.4600 - 31.4900]	Ses01F_impro01_F005	neu	[2.5000, 3.5000, 2.0000]
#  neu
# [38.9650 - 43.5900]	Ses01F_impro01_F006	fru	[2.0000, 3.5000, 3.5000]
#  fru
# [46.5800 - 52.1900]	Ses01F_impro01_F007	fru	[2.5000, 3.5000, 3.5000]
#  fru
# [56.1600 - 58.8225]	Ses01F_impro01_F008	fru	[2.0000, 3.5000, 3.5000]
#  fru
# [61.8700 - 65.9700]	Ses01F_impro01_F009	fru	[2.0000, 3.5000, 3.0000]
#  fru
# [66.4200 - 69.3400]	Ses01F_impro01_F010	xxx	[1.5000, 3.5000, 3.5000]
#  xxx
# [72.4500 - 82.2600]	Ses01F_impro01_F011	fru	[2.0000, 3.5000, 3.5000]
#  fru
# [85.2700 - 88.0200]	Ses01F_impro01_F012	ang	[2.0000, 3.5000, 3.5000]
#  ang
# [93.6700 - 97.0218]	Ses01F_impro01_F013	fru	[2.0000, 4.0000, 3.5000]
#  fru
# [97.8900 - 102.9600]	Ses01F_impro01_F014	neu	[2.5000, 3.5000, 3.5000]
#  neu
# [103.9700 - 106.7100]	Ses01F_impro01_F015	fru	[2.0000, 3.5000, 3.0000]
#  fru
# [7.5712 - 10.4750]	Ses01F_impro01_M000	fru	[2.5000, 2.0000, 2.5000]
#  fru
# [10.9266 - 14.6649]	Ses01F_impro01_M001	fru	[2.5000, 2.0000, 2.5000]
#  fru
# [16.8352 - 19.7175]	Ses01F_impro01_M002	fru	[2.0000, 3.5000, 3.5000]
#  fru
# [23.4700 - 28.0300]	Ses01F_impro01_M003	fru	[2.5000, 3.5000, 3.5000]
#  fru
# [28.3950 - 31.2117]	Ses01F_impro01_M004	fru	[2.0000, 4.0000, 3.5000]
#  fru
# [31.2660 - 39.3875]	Ses01F_impro01_M005	fru	[2.0000, 3.5000, 3.5000]
#  fru
# [41.2300 - 46.9800]	Ses01F_impro01_M006	fru	[2.0000, 3.5000, 3.5000]
#  fru
# [51.4000 - 57.6400]	Ses01F_impro01_M007	fru	[2.5000, 3.5000, 3.0000]
#  fru
# [58.1800 - 62.5900]	Ses01F_impro01_M008	fru	[2.0000, 3.5000, 3.5000]
#  fru
# [65.5100 - 73.0000]	Ses01F_impro01_M009	fru	[2.5000, 3.5000, 4.0000]
#  fru
# [81.5900 - 86.0300]	Ses01F_impro01_M010	fru	[2.0000, 4.5000, 4.0000]
#  fru
# [87.1500 - 94.3900]	Ses01F_impro01_M011	ang	[2.0000, 4.0000, 4.0000]
#  ang
# [95.8600 - 98.6800]	Ses01F_impro01_M012	xxx	[3.0000, 1.5000, 2.0000]
#  xxx
# [101.8400 - 107.8700]	Ses01F_impro01_M013	ang	[2.0000, 4.5000, 4.5000]
#  ang
# /media/vincentwu-cmlab/7C5650545650116E/IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_impro02.txt
# [7.2688 - 16.6000]	Ses01F_impro02_F000	sad	[2.5000, 2.0000, 1.5000]
#  sad
# [19.8500 - 22.7800]	Ses01F_impro02_F001	sad	[2.0000, 1.5000, 1.5000]
#  sad
# [26.5659 - 32.2895]	Ses01F_impro02_F002	sad	[2.0000, 1.5000, 1.5000]
#  sad
# [32.3075 - 37.9600]	Ses01F_impro02_F003	neu	[2.0000, 2.0000, 2.0000]
#  neu
# [47.3400 - 53.1100]	Ses01F_impro02_F004	sad	[2.5000, 2.0000, 2.5000]
#  sad
# [58.7500 - 61.3100]	Ses01F_impro02_F005	sad	[2.0000, 2.0000, 2.5000]
#  sad
# [64.2550 - 68.4700]	Ses01F_impro02_F006	neu	[2.5000, 2.5000, 2.5000]
#  neu
# [72.3900 - 78.5700]	Ses01F_impro02_F007	xxx	[2.0000, 3.5000, 3.0000]
#  xxx
# [87.2031 - 91.0900]	Ses01F_impro02_F008	sad	[1.5000, 2.0000, 1.5000]
#  sad
# [91.5500 - 95.8800]	Ses01F_impro02_F009	xxx	[1.5000, 1.5000, 2.0000]
#  xxx
# [97.9400 - 102.1900]	Ses01F_impro02_F010	sad	[2.0000, 1.5000, 2.0000]
#  sad
# [107.6800 - 111.0153]	Ses01F_impro02_F011	xxx	[2.5000, 2.5000, 2.5000]
#  xxx
# [117.8300 - 120.8605]	Ses01F_impro02_F012	sad	[3.5000, 2.0000, 1.5000]
#  sad
# [127.8200 - 133.9455]	Ses01F_impro02_F013	sad	[1.5000, 2.0000, 2.0000]
#  sad
# [139.0300 - 146.4300]	Ses01F_impro02_F014	sad	[1.5000, 2.0000, 2.0000]
#  sad
# [151.4221 - 155.0100]	Ses01F_impro02_F015	sad	[2.0000, 2.5000, 2.5000]
#  sad
# [163.5400 - 165.7300]	Ses01F_impro02_F016	neu	[2.0000, 1.0000, 2.5000]
#  neu
# [169.3600 - 176.0150]	Ses01F_impro02_F017	sad	[3.5000, 3.0000, 2.5000]
#  sad
# [176.0800 - 179.1300]	Ses01F_impro02_F018	neu	[2.5000, 2.5000, 2.5000]
#  neu
# [182.8300 - 185.8894]	Ses01F_impro02_F019	sad	[2.5000, 1.5000, 2.0000]
#  sad
# [186.5800 - 191.1100]	Ses01F_impro02_F020	sad	[4.0000, 2.0000, 2.5000]
#  sad
# [17.6000 - 20.6264]	Ses01F_impro02_M000	xxx	[2.0000, 2.5000, 2.5000]
#  xxx
# [21.7600 - 27.5558]	Ses01F_impro02_M001	sad	[2.0000, 2.5000, 2.5000]
#  sad
# [38.8500 - 45.0900]	Ses01F_impro02_M002	xxx	[2.5000, 3.0000, 2.5000]
#  xxx
# [52.7100 - 59.0534]	Ses01F_impro02_M003	fru	[2.0000, 3.0000, 3.0000]
#  fru
# [61.7500 - 65.0550]	Ses01F_impro02_M004	xxx	[2.0000, 3.0000, 2.0000]
#  xxx
# [69.3400 - 74.2900]	Ses01F_impro02_M005	sad	[2.0000, 3.0000, 1.5000]
#  sad
# [80.0300 - 86.9900]	Ses01F_impro02_M006	xxx	[2.0000, 3.0000, 1.5000]
#  xxx
# [103.2700 - 107.1000]	Ses01F_impro02_M007	xxx	[2.0000, 3.0000, 2.5000]
#  xxx
# [110.5653 - 113.2000]	Ses01F_impro02_M008	fru	[2.5000, 1.5000, 2.0000]
#  fru
# [114.1775 - 117.8500]	Ses01F_impro02_M009	sad	[2.0000, 1.5000, 2.5000]
#  sad
# [120.4105 - 124.6300]	Ses01F_impro02_M010	sad	[2.0000, 2.0000, 1.5000]
#  sad
# [133.8800 - 137.1000]	Ses01F_impro02_M011	sad	[2.5000, 1.5000, 2.5000]
#  sad
# [147.0300 - 151.7101]	Ses01F_impro02_M012	neu	[2.5000, 2.0000, 2.0000]
#  neu
# [157.9800 - 162.7100]	Ses01F_impro02_M013	sad	[1.5000, 2.0000, 2.0000]
#  sad
# [164.8850 - 169.5000]	Ses01F_impro02_M014	sad	[1.5000, 3.0000, 1.5000]
#  sad
# [175.4700 - 176.7200]	Ses01F_impro02_M015	neu	[3.0000, 3.0000, 1.5000]
#  neu
# [195.1047 - 199.5200]	Ses01F_impro02_M016	fru	[2.0000, 1.5000, 2.5000]
#  fru
# /media/vincentwu-cmlab/7C5650545650116E/IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_impro03.txt
# [4.8800 - 7.7400]	Ses01F_impro03_F000	hap	[4.3333, 2.6667, 2.6667]
#  hap
# [7.9300 - 11.3700]	Ses01F_impro03_F001	hap	[4.0000, 2.6667, 2.6667]
#  hap
# [12.8000 - 15.3700]	Ses01F_impro03_F002	hap	[4.3333, 3.0000, 2.3333]
#  hap
# [15.8700 - 20.4867]	Ses01F_impro03_F003	xxx	[5.0000, 4.0000, 3.0000]
#  xxx
# [21.7500 - 25.5200]	Ses01F_impro03_F004	hap	[4.6667, 3.6667, 2.3333]
#  hap
# [25.5584 - 28.1400]	Ses01F_impro03_F005	hap	[4.3333, 4.0000, 2.3333]
#  hap
# [28.3700 - 34.7100]	Ses01F_impro03_F006	hap	[4.0000, 3.3333, 2.6667]
#  hap
# [35.6349 - 40.1000]	Ses01F_impro03_F007	xxx	[4.0000, 3.3333, 2.3333]
#  xxx
# [40.1200 - 42.7900]	Ses01F_impro03_F008	hap	[4.0000, 3.3333, 2.3333]
#  hap
# [42.8400 - 44.5400]	Ses01F_impro03_F009	hap	[4.0000, 2.6667, 2.3333]
#  hap
# [47.8700 - 51.0750]	Ses01F_impro03_F010	hap	[4.0000, 3.3333, 3.0000]
#  hap
# [51.3600 - 53.4925]	Ses01F_impro03_F011	xxx	[4.0000, 3.0000, 2.3333]
#  xxx
# [55.8650 - 58.1500]	Ses01F_impro03_F012	hap	[4.0000, 3.6667, 2.6667]
#  hap
# [60.7300 - 65.8600]	Ses01F_impro03_F013	hap	[5.0000, 4.0000, 3.3333]
#  hap
# [68.0100 - 73.7500]	Ses01F_impro03_F014	xxx	[4.0000, 3.3333, 2.3333]
#  xxx
# [74.2675 - 78.8425]	Ses01F_impro03_F015	exc	[4.6667, 3.6667, 3.0000]
#  exc
# [79.0350 - 81.0875]	Ses01F_impro03_F016	hap	[4.0000, 3.0000, 2.3333]
#  hap
# [82.0975 - 85.0800]	Ses01F_impro03_F017	neu	[3.6667, 2.6667, 2.3333]
#  neu
# [85.1000 - 88.0225]	Ses01F_impro03_F018	neu	[3.6667, 3.0000, 2.0000]
#  neu
# [88.0800 - 89.5000]	Ses01F_impro03_F019	neu	[3.6667, 2.3333, 2.0000]
#  neu
# [91.2350 - 92.6150]	Ses01F_impro03_F020	xxx	[3.6667, 3.0000, 2.3333]
#  xxx
# [92.7500 - 98.2100]	Ses01F_impro03_F021	hap	[3.3333, 3.6667, 2.6667]
#  hap
# [99.7775 - 102.0300]	Ses01F_impro03_F022	neu	[3.3333, 2.6667, 2.0000]
#  neu
# [102.6200 - 103.4625]	Ses01F_impro03_F023	neu	[3.0000, 2.3333, 2.0000]
#  neu
# [103.7800 - 108.1825]	Ses01F_impro03_F024	hap	[4.3333, 3.0000, 2.6667]
#  hap
# [110.2300 - 114.1600]	Ses01F_impro03_F025	hap	[4.3333, 3.3333, 3.3333]
#  hap
# [114.1900 - 120.2000]	Ses01F_impro03_F026	hap	[4.6667, 4.0000, 3.0000]
#  hap
# [3.2400 - 5.4600]	Ses01F_impro03_M000	neu	[4.0000, 3.0000, 2.6667]
#  neu
# [6.6000 - 8.6600]	Ses01F_impro03_M001	neu	[4.3333, 2.6667, 2.3333]
#  neu
# [10.5300 - 13.8400]	Ses01F_impro03_M002	sur	[4.3333, 3.3333, 2.6667]
#  sur
# [14.9300 - 18.9075]	Ses01F_impro03_M003	exc	[5.0000, 4.6667, 3.0000]
#  exc
# [20.2532 - 22.8300]	Ses01F_impro03_M004	xxx	[4.6667, 4.0000, 2.3333]
#  xxx
# [27.2800 - 29.6500]	Ses01F_impro03_M005	xxx	[4.0000, 3.3333, 2.3333]
#  xxx
# [34.2500 - 36.3400]	Ses01F_impro03_M006	neu	[4.0000, 2.6667, 2.3333]
#  neu
# [37.7175 - 40.4700]	Ses01F_impro03_M007	hap	[4.0000, 3.0000, 2.3333]
#  hap
# [42.0900 - 43.4100]	Ses01F_impro03_M008	neu	[4.0000, 2.6667, 2.0000]
#  neu
# [44.1600 - 49.0700]	Ses01F_impro03_M009	neu	[3.6667, 2.3333, 2.3333]
#  neu
# [49.6100 - 52.4300]	Ses01F_impro03_M010	xxx	[4.0000, 3.3333, 3.0000]
#  xxx
# [52.9200 - 56.8500]	Ses01F_impro03_M011	neu	[3.6667, 3.6667, 2.6667]
#  neu
# [57.4600 - 61.3750]	Ses01F_impro03_M012	xxx	[4.3333, 3.6667, 2.6667]
#  xxx
# [65.6425 - 68.4400]	Ses01F_impro03_M013	hap	[4.6667, 4.0000, 3.0000]
#  hap
# [73.4100 - 76.9975]	Ses01F_impro03_M014	hap	[4.3333, 3.6667, 2.6667]
#  hap
# [78.3200 - 80.5000]	Ses01F_impro03_M015	hap	[4.0000, 3.0000, 2.6667]
#  hap
# [80.7175 - 82.5225]	Ses01F_impro03_M016	neu	[3.6667, 2.6667, 2.6667]
#  neu
# [84.6925 - 87.3600]	Ses01F_impro03_M017	sur	[3.6667, 3.6667, 2.3333]
#  sur
# [87.6425 - 89.0800]	Ses01F_impro03_M018	sur	[3.0000, 2.6667, 2.6667]
#  sur
# [89.1200 - 93.9100]	Ses01F_impro03_M019	neu	[3.0000, 3.0000, 2.3333]
#  neu
# [97.0300 - 101.6500]	Ses01F_impro03_M020	neu	[3.3333, 3.0000, 2.6667]
#  neu
# [101.6700 - 104.3500]	Ses01F_impro03_M021	neu	[3.0000, 3.3333, 2.6667]
#  neu
# [105.2900 - 106.9500]	Ses01F_impro03_M022	exc	[4.0000, 3.3333, 2.6667]
#  exc
# [107.7100 - 111.4000]	Ses01F_impro03_M023	hap	[4.6667, 4.3333, 3.6667]
#  hap
# [117.3600 - 119.5800]	Ses01F_impro03_M024	neu	[3.6667, 2.6667, 2.3333]
#  neu
# /media/vincentwu-cmlab/7C5650545650116E/IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_impro04.txt
# [7.2455 - 11.6400]	Ses01F_impro04_F000	neu	[3.0000, 3.0000, 3.0000]
#  neu
# [11.7448 - 16.1500]	Ses01F_impro04_F001	neu	[2.5000, 2.5000, 3.0000]
#  neu
# [18.6000 - 30.8976]	Ses01F_impro04_F002	fru	[2.5000, 3.5000, 3.0000]
#  fru
# [35.0090 - 37.8000]	Ses01F_impro04_F003	xxx	[2.5000, 3.0000, 2.5000]
#  xxx
# [40.2300 - 41.9500]	Ses01F_impro04_F004	xxx	[2.5000, 2.5000, 2.0000]
#  xxx
# [43.3500 - 45.7596]	Ses01F_impro04_F005	neu	[3.0000, 2.0000, 2.5000]
#  neu
# [46.2735 - 49.8300]	Ses01F_impro04_F006	neu	[3.0000, 3.5000, 3.5000]
#  neu
# [50.1100 - 54.3100]	Ses01F_impro04_F007	fru	[3.0000, 3.5000, 4.0000]
#  fru
# [54.3700 - 55.6700]	Ses01F_impro04_F008	xxx	[2.0000, 3.5000, 3.5000]
#  xxx
# [58.7100 - 60.0937]	Ses01F_impro04_F009	neu	[2.5000, 2.5000, 2.5000]
#  neu
# [60.6771 - 66.5275]	Ses01F_impro04_F010	xxx	[2.0000, 3.5000, 3.0000]
#  xxx
# [69.4300 - 70.9400]	Ses01F_impro04_F011	xxx	[2.5000, 3.0000, 3.0000]
#  xxx
# [72.1300 - 74.7300]	Ses01F_impro04_F012	xxx	[2.5000, 2.5000, 4.0000]
#  xxx
# [76.4900 - 80.7269]	Ses01F_impro04_F013	neu	[3.0000, 3.5000, 3.5000]
#  neu
# [85.4900 - 86.9800]	Ses01F_impro04_F014	neu	[2.5000, 3.0000, 2.5000]
#  neu
# [87.2203 - 93.3300]	Ses01F_impro04_F015	xxx	[2.0000, 4.0000, 3.5000]
#  xxx
# [97.4100 - 101.0475]	Ses01F_impro04_F016	fru	[2.0000, 4.0000, 3.5000]
#  fru
# [102.7800 - 105.4150]	Ses01F_impro04_F017	fru	[2.0000, 4.5000, 4.0000]
#  fru
# [106.1700 - 111.8600]	Ses01F_impro04_F018	fru	[2.0000, 4.5000, 3.5000]
#  fru
# [114.9200 - 122.3100]	Ses01F_impro04_F019	fru	[3.0000, 3.5000, 3.0000]
#  fru
# [122.4000 - 129.9300]	Ses01F_impro04_F020	xxx	[2.0000, 3.0000, 3.5000]
#  xxx
# [133.7400 - 137.4400]	Ses01F_impro04_F021	fru	[2.0000, 2.0000, 3.0000]
#  fru
# [138.1300 - 139.8900]	Ses01F_impro04_F022	fru	[2.0000, 2.0000, 2.5000]
#  fru
# [148.5500 - 152.8500]	Ses01F_impro04_F023	fru	[2.0000, 2.5000, 3.0000]
#  fru
# [153.1800 - 155.2925]	Ses01F_impro04_F024	fru	[2.5000, 2.5000, 3.5000]
#  fru
# [157.1625 - 159.7000]	Ses01F_impro04_F025	fru	[2.5000, 2.5000, 3.0000]
#  fru
# [161.0787 - 163.7800]	Ses01F_impro04_F026	fru	[2.5000, 2.0000, 3.5000]
#  fru
# [164.3925 - 167.5650]	Ses01F_impro04_F027	fru	[2.5000, 2.0000, 3.0000]
#  fru
# [170.8300 - 172.8400]	Ses01F_impro04_F028	ang	[2.0000, 3.5000, 3.5000]
#  ang
# [175.2700 - 178.4300]	Ses01F_impro04_F029	ang	[1.5000, 4.0000, 4.0000]
#  ang
# [180.3025 - 183.4875]	Ses01F_impro04_F030	ang	[1.5000, 3.5000, 4.0000]
#  ang
# [184.4700 - 188.8700]	Ses01F_impro04_F031	ang	[1.5000, 3.0000, 3.5000]
#  ang
# [189.1200 - 192.0200]	Ses01F_impro04_F032	ang	[2.0000, 3.5000, 3.5000]
#  ang
# [193.5875 - 199.4325]	Ses01F_impro04_F033	ang	[1.5000, 3.5000, 4.5000]
#  ang
# [2.7418 - 6.6575]	Ses01F_impro04_M000	neu	[3.0000, 2.5000, 2.5000]
#  neu
# [10.4600 - 12.1300]	Ses01F_impro04_M001	neu	[3.0000, 2.5000, 2.0000]
#  neu
# [15.6400 - 18.9000]	Ses01F_impro04_M002	neu	[3.0000, 2.5000, 3.0000]
#  neu
# [26.9100 - 28.7100]	Ses01F_impro04_M003	neu	[3.0000, 2.5000, 2.5000]
#  neu
# [30.8800 - 35.5225]	Ses01F_impro04_M004	neu	[3.0000, 3.0000, 3.0000]
#  neu
# [37.1900 - 40.5300]	Ses01F_impro04_M005	neu	[3.0000, 3.0000, 3.0000]
#  neu
# [40.5400 - 43.5760]	Ses01F_impro04_M006	neu	[3.0000, 3.5000, 2.5000]
#  neu
# [49.3900 - 50.5800]	Ses01F_impro04_M007	neu	[3.5000, 3.0000, 2.5000]
#  neu
# [55.2100 - 56.3300]	Ses01F_impro04_M008	neu	[3.0000, 3.0000, 2.5000]
#  neu
# [56.3500 - 59.0245]	Ses01F_impro04_M009	neu	[3.0000, 3.0000, 3.0000]
#  neu
# [59.8000 - 61.5500]	Ses01F_impro04_M010	neu	[3.0000, 2.5000, 2.0000]
#  neu
# [65.9700 - 69.7700]	Ses01F_impro04_M011	neu	[3.0000, 3.0000, 2.5000]
#  neu
# [70.3800 - 72.7264]	Ses01F_impro04_M012	neu	[3.0000, 3.0000, 2.5000]
#  neu
# [73.7473 - 77.1500]	Ses01F_impro04_M013	neu	[3.0000, 2.0000, 3.0000]
#  neu
# [80.1435 - 87.8100]	Ses01F_impro04_M014	neu	[3.5000, 3.5000, 3.5000]
#  neu
# [92.3700 - 99.2700]	Ses01F_impro04_M015	neu	[2.5000, 3.5000, 3.0000]
#  neu
# [100.4850 - 103.4700]	Ses01F_impro04_M016	neu	[3.0000, 2.5000, 2.5000]
#  neu
# [104.9700 - 107.7800]	Ses01F_impro04_M017	neu	[3.0000, 3.5000, 3.0000]
#  neu
# [111.6600 - 117.7250]	Ses01F_impro04_M018	neu	[3.0000, 3.5000, 3.0000]
#  neu
# [118.4600 - 119.7700]	Ses01F_impro04_M019	neu	[3.0000, 2.5000, 2.5000]
#  neu
# [121.5000 - 123.4200]	Ses01F_impro04_M020	neu	[3.0000, 2.5000, 2.5000]
#  neu
# [129.4300 - 139.1600]	Ses01F_impro04_M021	neu	[3.5000, 3.5000, 3.0000]
#  neu
# [139.5219 - 141.8225]	Ses01F_impro04_M022	neu	[3.0000, 2.5000, 2.5000]
#  neu
# [144.9125 - 149.5100]	Ses01F_impro04_M023	neu	[2.5000, 2.5000, 2.0000]
#  neu
# [151.8400 - 154.0300]	Ses01F_impro04_M024	neu	[3.0000, 2.5000, 3.0000]
#  neu
# [154.6000 - 157.8000]	Ses01F_impro04_M025	neu	[3.0000, 3.5000, 3.5000]
#  neu
# [158.9500 - 161.3500]	Ses01F_impro04_M026	neu	[3.5000, 3.0000, 3.0000]
#  neu
# [162.1200 - 164.7825]	Ses01F_impro04_M027	neu	[3.5000, 3.5000, 3.5000]
#  neu
# [165.4700 - 166.7100]	Ses01F_impro04_M028	neu	[3.0000, 2.5000, 2.0000]
#  neu
# [167.0500 - 171.4300]	Ses01F_impro04_M029	fru	[2.5000, 3.5000, 3.5000]
#  fru
# [171.7500 - 175.2600]	Ses01F_impro04_M030	fru	[2.5000, 2.5000, 3.0000]
#  fru
# [178.0033 - 180.8650]	Ses01F_impro04_M031	neu	[3.0000, 2.5000, 2.5000]
#  neu
# [182.8200 - 185.5400]	Ses01F_impro04_M032	neu	[2.5000, 2.0000, 1.5000]
#  neu
# [186.1200 - 187.4625]	Ses01F_impro04_M033	xxx	[2.5000, 3.5000, 2.0000]
#  xxx
# [188.0100 - 190.7100]	Ses01F_impro04_M034	fru	[2.5000, 2.0000, 2.0000]
#  fru
# [191.2800 - 195.1300]	Ses01F_impro04_M035	fru	[2.0000, 3.5000, 3.0000]
#  fru
# [200.2150 - 202.0825]	Ses01F_impro04_M036	xxx	[2.5000, 3.0000, 3.5000]
#  xxx
# /media/vincentwu-cmlab/7C5650545650116E/IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_impro05.txt
# [4.2400 - 5.2300]	Ses01F_impro05_F000	fru	[4.0000, 2.0000, 1.5000]
#  fru
# [5.2600 - 7.1600]	Ses01F_impro05_F001	fru	[2.0000, 2.5000, 2.5000]
#  fru
# [7.3500 - 8.8500]	Ses01F_impro05_F002	fru	[2.5000, 2.5000, 3.5000]
#  fru
# [9.2000 - 13.0200]	Ses01F_impro05_F003	fru	[2.0000, 3.0000, 3.5000]
#  fru
# [13.0400 - 22.7400]	Ses01F_impro05_F004	fru	[2.0000, 3.5000, 3.5000]
#  fru
# [25.3500 - 26.7600]	Ses01F_impro05_F005	fru	[2.5000, 3.0000, 3.0000]
#  fru
# [28.2400 - 29.9100]	Ses01F_impro05_F006	xxx	[2.5000, 2.5000, 2.5000]
#  xxx
# [32.1900 - 33.5000]	Ses01F_impro05_F007	fru	[2.5000, 3.0000, 3.5000]
#  fru
# [33.7800 - 35.9000]	Ses01F_impro05_F008	ang	[2.5000, 2.5000, 3.5000]
#  ang
# [36.7100 - 44.0300]	Ses01F_impro05_F009	ang	[2.5000, 2.5000, 3.5000]
#  ang
# [69.5500 - 73.7600]	Ses01F_impro05_F010	xxx	[2.0000, 4.0000, 3.5000]
#  xxx
# [73.8700 - 75.5375]	Ses01F_impro05_F011	ang	[2.0000, 4.5000, 3.5000]
#  ang
# [75.6100 - 80.7300]	Ses01F_impro05_F012	ang	[2.5000, 3.5000, 3.0000]
#  ang
# [82.7500 - 86.0600]	Ses01F_impro05_F013	xxx	[2.0000, 2.5000, 3.0000]
#  xxx
# [99.5200 - 102.9000]	Ses01F_impro05_F014	ang	[1.5000, 4.0000, 4.0000]
#  ang
# [103.0050 - 118.5000]	Ses01F_impro05_F015	ang	[1.5000, 4.5000, 4.5000]
#  ang
# [118.5300 - 122.4400]	Ses01F_impro05_F016	ang	[1.5000, 4.5000, 4.0000]
#  ang
# [127.4850 - 136.8500]	Ses01F_impro05_F017	ang	[1.5000, 5.0000, 4.5000]
#  ang
# [137.7150 - 140.1100]	Ses01F_impro05_F018	ang	[1.5000, 4.0000, 4.0000]
#  ang
# [140.2250 - 145.6000]	Ses01F_impro05_F019	ang	[1.5000, 4.0000, 4.5000]
#  ang
# [149.3650 - 153.8000]	Ses01F_impro05_F020	ang	[1.5000, 4.5000, 4.5000]
#  ang
# [155.6000 - 160.3600]	Ses01F_impro05_F021	ang	[1.5000, 4.5000, 4.5000]
#  ang
# [160.4100 - 163.7975]	Ses01F_impro05_F022	ang	[1.5000, 4.5000, 4.0000]
#  ang
# [163.8800 - 165.8000]	Ses01F_impro05_F023	ang	[2.0000, 3.0000, 4.0000]
#  ang
# [166.3300 - 167.7100]	Ses01F_impro05_F024	ang	[2.0000, 3.0000, 4.0000]
#  ang
# [171.0900 - 174.2000]	Ses01F_impro05_F025	ang	[1.5000, 4.5000, 4.5000]
#  ang
# [177.6025 - 179.0900]	Ses01F_impro05_F026	ang	[2.0000, 3.5000, 3.5000]
#  ang
# [179.2200 - 183.8450]	Ses01F_impro05_F027	xxx	[2.0000, 2.5000, 4.0000]
#  xxx
# [188.7800 - 190.8975]	Ses01F_impro05_F028	ang	[2.0000, 3.0000, 4.0000]
#  ang
# [195.3800 - 199.3300]	Ses01F_impro05_F029	ang	[1.5000, 3.0000, 3.5000]
#  ang
# [202.8600 - 206.1700]	Ses01F_impro05_F030	ang	[2.0000, 3.0000, 3.5000]
#  ang
# [3.6100 - 5.1900]	Ses01F_impro05_M000	neu	[4.0000, 2.5000, 2.0000]
#  neu
# [5.2100 - 6.4400]	Ses01F_impro05_M001	hap	[4.0000, 2.5000, 2.0000]
#  hap
# [6.6000 - 7.7100]	Ses01F_impro05_M002	hap	[4.0000, 2.5000, 2.0000]
#  hap
# [8.3200 - 9.8000]	Ses01F_impro05_M003	neu	[4.0000, 2.5000, 2.0000]
#  neu
# [12.2600 - 13.7800]	Ses01F_impro05_M004	neu	[3.5000, 1.5000, 2.0000]
#  neu
# [21.8400 - 25.9000]	Ses01F_impro05_M005	neu	[3.5000, 2.5000, 2.0000]
#  neu
# [25.9900 - 27.7272]	Ses01F_impro05_M006	neu	[3.5000, 2.5000, 2.0000]
#  neu
# [28.2900 - 34.1425]	Ses01F_impro05_M007	neu	[3.5000, 2.5000, 2.0000]
#  neu
# [34.7000 - 36.5200]	Ses01F_impro05_M008	neu	[3.0000, 2.5000, 2.0000]
#  neu
# [36.9100 - 42.7600]	Ses01F_impro05_M009	neu	[2.5000, 2.5000, 2.0000]
#  neu
# [43.8600 - 49.9700]	Ses01F_impro05_M010	neu	[2.5000, 2.5000, 2.0000]
#  neu
# [49.9700 - 70.2600]	Ses01F_impro05_M011	neu	[2.5000, 2.5000, 2.0000]
#  neu
# [70.3800 - 73.1400]	Ses01F_impro05_M012	neu	[2.5000, 2.0000, 1.5000]
#  neu
# [73.5500 - 74.9900]	Ses01F_impro05_M013	neu	[2.5000, 2.0000, 1.5000]
#  neu
# [75.0300 - 76.4800]	Ses01F_impro05_M014	neu	[2.5000, 2.5000, 1.5000]
#  neu
# [80.2200 - 83.2425]	Ses01F_impro05_M015	neu	[2.5000, 2.0000, 1.5000]
#  neu
# [85.7200 - 93.9575]	Ses01F_impro05_M016	neu	[2.5000, 2.5000, 2.0000]
#  neu
# [94.0050 - 100.4000]	Ses01F_impro05_M017	neu	[2.5000, 2.5000, 2.5000]
#  neu
# [100.5500 - 103.6800]	Ses01F_impro05_M018	xxx	[3.0000, 3.5000, 2.5000]
#  xxx
# [111.2800 - 112.8100]	Ses01F_impro05_M019	neu	[2.5000, 2.0000, 2.0000]
#  neu
# [118.0400 - 119.3700]	Ses01F_impro05_M020	neu	[2.5000, 2.0000, 2.0000]
#  neu
# [121.1900 - 129.2300]	Ses01F_impro05_M021	xxx	[2.5000, 2.5000, 1.5000]
#  xxx
# [131.0200 - 133.2500]	Ses01F_impro05_M022	neu	[2.5000, 2.0000, 2.0000]
#  neu
# [136.1900 - 143.5000]	Ses01F_impro05_M023	neu	[2.5000, 3.5000, 2.5000]
#  neu
# [144.8500 - 151.1600]	Ses01F_impro05_M024	neu	[2.5000, 3.0000, 2.5000]
#  neu
# [151.3350 - 152.7100]	Ses01F_impro05_M025	neu	[2.5000, 2.5000, 2.0000]
#  neu
# [152.8325 - 158.5800]	Ses01F_impro05_M026	neu	[2.5000, 2.5000, 2.5000]
#  neu
# [159.6600 - 161.3700]	Ses01F_impro05_M027	neu	[2.5000, 2.5000, 2.0000]
#  neu
# [163.2500 - 166.9900]	Ses01F_impro05_M028	neu	[2.5000, 2.5000, 2.0000]
#  neu
# [167.1500 - 173.6300]	Ses01F_impro05_M029	neu	[2.5000, 2.5000, 2.5000]
#  neu
# [173.7325 - 178.2625]	Ses01F_impro05_M030	neu	[3.0000, 2.5000, 2.0000]
#  neu
# [178.5900 - 180.8700]	Ses01F_impro05_M031	neu	[3.0000, 2.5000, 2.5000]
#  neu
# [183.1400 - 189.3875]	Ses01F_impro05_M032	sur	[3.0000, 2.5000, 2.0000]
#  sur
# [190.2300 - 196.9000]	Ses01F_impro05_M033	sur	[2.5000, 3.0000, 2.0000]
#  sur
# [198.6600 - 205.1700]	Ses01F_impro05_M034	neu	[2.5000, 2.5000, 2.5000]
#  neu
# [205.6300 - 211.9400]	Ses01F_impro05_M035	neu	[2.5000, 2.0000, 1.5000]
#  neu
# /media/vincentwu-cmlab/7C5650545650116E/IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_impro06.txt
# [14.7939 - 18.1700]	Ses01F_impro06_F000	xxx	[3.5000, 2.0000, 3.0000]
#  xxx
# [24.0200 - 25.6900]	Ses01F_impro06_F001	xxx	[2.0000, 2.0000, 2.0000]
#  xxx
# [26.0700 - 27.6500]	Ses01F_impro06_F002	sad	[2.0000, 1.5000, 2.5000]
#  sad
# [34.4500 - 35.7800]	Ses01F_impro06_F003	neu	[3.0000, 2.0000, 2.5000]
#  neu
# [36.0700 - 38.0400]	Ses01F_impro06_F004	neu	[3.5000, 2.0000, 3.0000]
#  neu
# [39.6025 - 46.2900]	Ses01F_impro06_F005	sad	[2.0000, 2.0000, 4.0000]
#  sad
# [47.3400 - 59.3800]	Ses01F_impro06_F006	sad	[3.5000, 3.0000, 4.0000]
#  sad
# [59.4525 - 67.4525]	Ses01F_impro06_F007	sad	[3.5000, 3.0000, 4.0000]
#  sad
# [70.2200 - 80.1300]	Ses01F_impro06_F008	sad	[2.5000, 3.5000, 3.5000]
#  sad
# [80.1600 - 87.7400]	Ses01F_impro06_F009	neu	[2.5000, 3.0000, 3.5000]
#  neu
# [87.8300 - 93.6700]	Ses01F_impro06_F010	sad	[2.0000, 2.5000, 3.5000]
#  sad
# [101.8300 - 116.9100]	Ses01F_impro06_F011	sad	[2.0000, 3.0000, 4.0000]
#  sad
# [117.0700 - 126.0400]	Ses01F_impro06_F012	sad	[2.0000, 3.5000, 4.5000]
#  sad
# [132.9575 - 134.4900]	Ses01F_impro06_F013	sad	[2.0000, 2.0000, 2.0000]
#  sad
# [135.9600 - 137.9500]	Ses01F_impro06_F014	sad	[3.0000, 3.0000, 2.5000]
#  sad
# [138.0685 - 141.0500]	Ses01F_impro06_F015	sad	[2.0000, 2.0000, 2.5000]
#  sad
# [141.8400 - 149.4375]	Ses01F_impro06_F016	neu	[4.0000, 3.0000, 3.5000]
#  neu
# [158.0800 - 163.3500]	Ses01F_impro06_F017	xxx	[4.0000, 3.0000, 3.5000]
#  xxx
# [167.6400 - 174.8400]	Ses01F_impro06_F018	neu	[4.0000, 3.0000, 3.5000]
#  neu
# [176.3500 - 178.0100]	Ses01F_impro06_F019	neu	[2.5000, 2.0000, 2.5000]
#  neu
# [182.5600 - 197.7300]	Ses01F_impro06_F020	sad	[2.5000, 3.0000, 4.0000]
#  sad
# [197.7550 - 214.3400]	Ses01F_impro06_F021	sad	[2.0000, 3.0000, 4.0000]
#  sad
# [217.5000 - 222.4100]	Ses01F_impro06_F022	sad	[4.0000, 3.0000, 3.5000]
#  sad
# [223.5200 - 227.5500]	Ses01F_impro06_F023	sad	[2.5000, 2.0000, 2.5000]
#  sad
# [229.0800 - 235.9800]	Ses01F_impro06_F024	sad	[1.5000, 2.0000, 3.0000]
#  sad
# [237.5300 - 256.4800]	Ses01F_impro06_F025	sad	[3.0000, 3.5000, 4.5000]
#  sad
# [266.5500 - 275.3100]	Ses01F_impro06_F026	sad	[3.0000, 3.0000, 3.5000]
#  sad
# [275.3800 - 281.6000]	Ses01F_impro06_F027	neu	[2.0000, 2.0000, 3.5000]
#  neu
# [282.0100 - 311.1400]	Ses01F_impro06_F028	sad	[3.0000, 3.5000, 4.0000]
#  sad
# [11.4600 - 14.7400]	Ses01F_impro06_M000	sad	[2.5000, 2.0000, 3.0000]
#  sad
# [18.4900 - 24.9100]	Ses01F_impro06_M001	neu	[2.5000, 3.0000, 3.5000]
#  neu
# [25.1200 - 26.5600]	Ses01F_impro06_M002	neu	[2.5000, 2.0000, 3.0000]
#  neu
# [28.9700 - 35.0200]	Ses01F_impro06_M003	sad	[2.5000, 2.0000, 3.5000]
#  sad
# [56.1700 - 57.4900]	Ses01F_impro06_M004	neu	[3.0000, 3.0000, 2.5000]
#  neu
# [86.9600 - 88.6300]	Ses01F_impro06_M005	neu	[3.0000, 2.0000, 2.5000]
#  neu
# [107.7800 - 109.2700]	Ses01F_impro06_M006	neu	[3.0000, 2.0000, 2.5000]
#  neu
# [125.4700 - 127.1900]	Ses01F_impro06_M007	sad	[3.0000, 2.0000, 2.5000]
#  sad
# [134.4000 - 136.4900]	Ses01F_impro06_M008	neu	[3.0000, 2.5000, 2.5000]
#  neu
# [137.0900 - 138.4400]	Ses01F_impro06_M009	neu	[3.0000, 2.5000, 2.5000]
#  neu
# [144.0900 - 145.6800]	Ses01F_impro06_M010	neu	[3.0000, 2.5000, 3.0000]
#  neu
# [155.0700 - 158.3800]	Ses01F_impro06_M011	neu	[3.0000, 2.0000, 3.0000]
#  neu
# [165.6100 - 168.1000]	Ses01F_impro06_M012	neu	[2.5000, 2.5000, 2.5000]
#  neu
# [174.3900 - 177.1500]	Ses01F_impro06_M013	neu	[3.0000, 2.5000, 2.5000]
#  neu
# [219.7300 - 221.0300]	Ses01F_impro06_M014	neu	[3.0000, 2.5000, 2.0000]
#  neu
# [255.3500 - 257.3100]	Ses01F_impro06_M015	neu	[3.0000, 3.0000, 2.5000]
#  neu
# [262.9900 - 266.1750]	Ses01F_impro06_M016	neu	[3.0000, 2.5000, 2.5000]
#  neu
# [308.2400 - 310.0100]	Ses01F_impro06_M017	xxx	[4.0000, 3.0000, 2.5000]
#  xxx
# /media/vincentwu-cmlab/7C5650545650116E/IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_impro07.txt
# [3.9500 - 10.5900]	Ses01F_impro07_F000	exc	[5.0000, 5.0000, 4.5000]
#  exc
# [11.3600 - 16.5575]	Ses01F_impro07_F001	xxx	[4.0000, 4.5000, 3.5000]
#  xxx
# [19.6100 - 31.6500]	Ses01F_impro07_F002	exc	[4.0000, 4.0000, 3.0000]
#  exc
# [32.5200 - 34.9000]	Ses01F_impro07_F003	exc	[4.5000, 4.5000, 4.5000]
#  exc
# [37.1625 - 42.4900]	Ses01F_impro07_F004	exc	[3.0000, 3.5000, 3.0000]
#  exc
# [42.9550 - 45.8850]	Ses01F_impro07_F005	exc	[5.0000, 4.5000, 4.5000]
#  exc
# [46.2800 - 55.4100]	Ses01F_impro07_F006	xxx	[4.5000, 4.0000, 3.5000]
#  xxx
# [63.0200 - 72.7500]	Ses01F_impro07_F007	xxx	[4.0000, 4.0000, 3.5000]
#  xxx
# [73.5050 - 80.7800]	Ses01F_impro07_F008	xxx	[4.0000, 3.0000, 3.0000]
#  xxx
# [81.0275 - 83.3050]	Ses01F_impro07_F009	exc	[4.0000, 3.0000, 2.5000]
#  exc
# [84.5100 - 88.3100]	Ses01F_impro07_F010	exc	[5.0000, 4.5000, 4.0000]
#  exc
# [89.5600 - 94.8150]	Ses01F_impro07_F011	xxx	[4.0000, 3.5000, 3.0000]
#  xxx
# [94.8600 - 100.7400]	Ses01F_impro07_F012	exc	[4.5000, 4.0000, 3.5000]
#  exc
# [103.2600 - 110.4600]	Ses01F_impro07_F013	exc	[4.5000, 4.0000, 4.0000]
#  exc
# [115.6800 - 126.4100]	Ses01F_impro07_F014	xxx	[4.0000, 3.5000, 3.5000]
#  xxx
# [127.4300 - 130.3175]	Ses01F_impro07_F015	xxx	[4.5000, 4.0000, 3.0000]
#  xxx
# [133.3125 - 142.3625]	Ses01F_impro07_F016	exc	[4.5000, 3.5000, 3.0000]
#  exc
# [2.9700 - 4.7800]	Ses01F_impro07_M000	exc	[3.5000, 3.0000, 2.0000]
#  exc
# [7.5325 - 11.9600]	Ses01F_impro07_M001	exc	[4.5000, 4.5000, 4.0000]
#  exc
# [13.9200 - 19.0900]	Ses01F_impro07_M002	exc	[4.5000, 4.0000, 4.0000]
#  exc
# [20.6800 - 28.0600]	Ses01F_impro07_M003	exc	[4.5000, 3.5000, 2.5000]
#  exc
# [30.9150 - 38.8100]	Ses01F_impro07_M004	exc	[4.0000, 4.0000, 3.0000]
#  exc
# [41.1700 - 46.9975]	Ses01F_impro07_M005	exc	[4.5000, 4.5000, 3.5000]
#  exc
# [47.1100 - 52.8125]	Ses01F_impro07_M006	exc	[4.5000, 4.5000, 3.5000]
#  exc
# [54.1600 - 63.2800]	Ses01F_impro07_M007	exc	[4.5000, 4.5000, 4.5000]
#  exc
# [64.6275 - 67.2400]	Ses01F_impro07_M008	exc	[4.0000, 3.0000, 3.0000]
#  exc
# [67.7250 - 74.0325]	Ses01F_impro07_M009	exc	[3.5000, 4.0000, 3.5000]
#  exc
# [76.6200 - 78.1700]	Ses01F_impro07_M010	xxx	[3.5000, 3.5000, 2.5000]
#  xxx
# [78.8400 - 81.3600]	Ses01F_impro07_M011	xxx	[3.0000, 2.5000, 2.5000]
#  xxx
# [82.6575 - 87.1025]	Ses01F_impro07_M012	neu	[3.0000, 2.5000, 3.0000]
#  neu
# [87.5875 - 90.6500]	Ses01F_impro07_M013	neu	[4.0000, 2.5000, 2.5000]
#  neu
# [94.2900 - 99.3700]	Ses01F_impro07_M014	exc	[4.0000, 4.5000, 3.0000]
#  exc
# [99.9875 - 110.5400]	Ses01F_impro07_M015	exc	[4.5000, 4.0000, 3.5000]
#  exc
# [110.5400 - 116.2800]	Ses01F_impro07_M016	xxx	[4.5000, 4.0000, 3.0000]
#  xxx
# [116.2800 - 119.8507]	Ses01F_impro07_M017	exc	[4.0000, 3.5000, 2.5000]
#  exc
# [123.2575 - 128.0400]	Ses01F_impro07_M018	neu	[4.0000, 3.0000, 3.0000]
#  neu
# [128.5400 - 141.6850]	Ses01F_impro07_M019	hap	[4.5000, 4.0000, 3.0000]
#  hap
# /media/vincentwu-cmlab/7C5650545650116E/IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_script01_1.txt
# [6.2100 - 9.3200]	Ses01F_script01_1_F000	fru	[2.0000, 2.3333, 2.3333]
#  fru
# [9.3500 - 12.8955]	Ses01F_script01_1_F001	xxx	[2.0000, 2.3333, 1.6667]
#  xxx
# [14.3063 - 19.5526]	Ses01F_script01_1_F002	sur	[2.3333, 2.3333, 2.6667]
#  sur
# [22.3200 - 24.6667]	Ses01F_script01_1_F003	xxx	[3.0000, 3.0000, 2.6667]
#  xxx
# [35.3799 - 39.0900]	Ses01F_script01_1_F004	xxx	[2.0000, 2.0000, 2.0000]
#  xxx
# [40.0200 - 44.9688]	Ses01F_script01_1_F005	neu	[2.0000, 1.6667, 2.0000]
#  neu
# [46.9500 - 52.3200]	Ses01F_script01_1_F006	xxx	[1.6667, 2.3333, 3.3333]
#  xxx
# [58.9500 - 60.8800]	Ses01F_script01_1_F007	xxx	[2.6667, 3.6667, 3.6667]
#  xxx
# [67.6000 - 70.6700]	Ses01F_script01_1_F008	xxx	[2.0000, 2.3333, 2.6667]
#  xxx
# [78.3648 - 81.5611]	Ses01F_script01_1_F009	fru	[2.6667, 2.6667, 3.6667]
#  fru
# [100.1400 - 102.3482]	Ses01F_script01_1_F010	fru	[2.6667, 2.6667, 3.0000]
#  fru
# [104.2900 - 108.7408]	Ses01F_script01_1_F011	fru	[2.3333, 3.3333, 3.6667]
#  fru
# [117.8228 - 129.5100]	Ses01F_script01_1_F012	fru	[2.3333, 3.0000, 4.0000]
#  fru
# [134.0100 - 141.9500]	Ses01F_script01_1_F013	xxx	[2.3333, 4.3333, 3.6667]
#  xxx
# [150.2700 - 152.6736]	Ses01F_script01_1_F014	fru	[2.6667, 1.6667, 2.3333]
#  fru
# [156.1786 - 160.6700]	Ses01F_script01_1_F015	neu	[3.0000, 2.3333, 3.0000]
#  neu
# [165.6573 - 169.5590]	Ses01F_script01_1_F016	xxx	[2.6667, 2.6667, 3.0000]
#  xxx
# [171.6300 - 175.4900]	Ses01F_script01_1_F017	xxx	[2.0000, 3.0000, 3.6667]
#  xxx
# [176.9600 - 179.7500]	Ses01F_script01_1_F018	xxx	[2.6667, 2.6667, 2.3333]
#  xxx
# [183.9800 - 186.0500]	Ses01F_script01_1_F019	xxx	[3.0000, 2.6667, 2.3333]
#  xxx
# [194.0600 - 198.9100]	Ses01F_script01_1_F020	xxx	[2.3333, 4.0000, 4.3333]
#  xxx
# [205.1600 - 215.1700]	Ses01F_script01_1_F021	fru	[2.3333, 4.0000, 4.0000]
#  fru
# [219.0400 - 223.8200]	Ses01F_script01_1_F022	fru	[2.3333, 3.3333, 2.3333]
#  fru
# [235.2000 - 238.5600]	Ses01F_script01_1_F023	fru	[3.3333, 2.6667, 2.3333]
#  fru
# [241.3769 - 245.1904]	Ses01F_script01_1_F024	fru	[2.6667, 2.6667, 2.6667]
#  fru
# [246.8000 - 251.4508]	Ses01F_script01_1_F025	fru	[2.6667, 3.3333, 3.6667]
#  fru
# [266.8300 - 270.7300]	Ses01F_script01_1_F026	fru	[2.6667, 2.6667, 3.0000]
#  fru
# [274.1997 - 277.2100]	Ses01F_script01_1_F027	fru	[2.3333, 2.3333, 2.3333]
#  fru
# [278.1500 - 282.5900]	Ses01F_script01_1_F028	fru	[2.3333, 2.0000, 2.3333]
#  fru
# [282.7300 - 286.9200]	Ses01F_script01_1_F029	fru	[2.3333, 3.6667, 3.6667]
#  fru
# [299.3100 - 302.1950]	Ses01F_script01_1_F030	fru	[2.6667, 2.0000, 1.6667]
#  fru
# [304.2300 - 308.9800]	Ses01F_script01_1_F031	fru	[2.3333, 2.3333, 1.6667]
#  fru
# [309.0400 - 312.7098]	Ses01F_script01_1_F032	fru	[2.0000, 2.0000, 2.6667]
#  fru
# [312.7400 - 318.2648]	Ses01F_script01_1_F033	fru	[2.6667, 2.6667, 3.3333]
#  fru
# [323.3348 - 326.0750]	Ses01F_script01_1_F034	neu	[2.3333, 2.6667, 2.3333]
#  neu
# [341.9700 - 344.8052]	Ses01F_script01_1_F035	ang	[1.6667, 3.6667, 4.0000]
#  ang
# [349.6300 - 352.5866]	Ses01F_script01_1_F036	xxx	[3.0000, 4.0000, 3.6667]
#  xxx
# [356.4000 - 359.8700]	Ses01F_script01_1_F037	ang	[1.3333, 4.3333, 4.3333]
#  ang
# [361.8100 - 364.6100]	Ses01F_script01_1_F038	ang	[2.0000, 3.6667, 3.6667]
#  ang
# [382.6000 - 387.9700]	Ses01F_script01_1_F039	fru	[2.3333, 3.0000, 3.6667]
#  fru
# [389.5400 - 392.9042]	Ses01F_script01_1_F040	fru	[2.3333, 2.6667, 4.0000]
#  fru
# [394.9100 - 404.6900]	Ses01F_script01_1_F041	ang	[1.6667, 4.6667, 4.3333]
#  ang
# [406.3900 - 409.4600]	Ses01F_script01_1_F042	ang	[2.0000, 4.0000, 3.6667]
#  ang
# [412.7875 - 416.2484]	Ses01F_script01_1_F043	fru	[2.3333, 2.3333, 2.0000]
#  fru
# [420.3500 - 423.2141]	Ses01F_script01_1_F044	fru	[2.3333, 1.3333, 1.3333]
#  fru
# [11.9892 - 15.1219]	Ses01F_script01_1_M000	neu	[3.0000, 1.6667, 2.3333]
#  neu
# [19.0456 - 22.3962]	Ses01F_script01_1_M001	neu	[3.0000, 2.0000, 2.3333]
#  neu
# [24.8000 - 35.9971]	Ses01F_script01_1_M002	neu	[2.6667, 3.0000, 2.3333]
#  neu
# [38.6600 - 40.5300]	Ses01F_script01_1_M003	neu	[3.0000, 2.0000, 2.0000]
#  neu
# [44.5500 - 47.2300]	Ses01F_script01_1_M004	neu	[3.0000, 2.0000, 2.0000]
#  neu
# [51.4300 - 59.5500]	Ses01F_script01_1_M005	fru	[2.6667, 2.6667, 2.3333]
#  fru
# [62.1628 - 68.2500]	Ses01F_script01_1_M006	xxx	[2.6667, 2.6667, 2.6667]
#  xxx
# [70.0764 - 78.8718]	Ses01F_script01_1_M007	neu	[2.6667, 3.0000, 3.0000]
#  neu
# [81.4068 - 89.4307]	Ses01F_script01_1_M008	fru	[2.3333, 2.6667, 3.0000]
#  fru
# [89.7172 - 101.3800]	Ses01F_script01_1_M009	fru	[2.3333, 3.6667, 3.6667]
#  fru
# [102.1000 - 104.7200]	Ses01F_script01_1_M010	neu	[3.0000, 3.3333, 3.6667]
#  neu
# [108.1897 - 118.4700]	Ses01F_script01_1_M011	fru	[2.3333, 2.3333, 3.3333]
#  fru
# [130.7600 - 134.5900]	Ses01F_script01_1_M012	neu	[3.0000, 1.3333, 2.0000]
#  neu
# [141.0500 - 149.7500]	Ses01F_script01_1_M013	fru	[3.0000, 2.3333, 2.3333]
#  fru
# [153.8860 - 155.8699]	Ses01F_script01_1_M014	neu	[3.0000, 1.6667, 2.3333]
#  neu
# [161.9980 - 165.3487]	Ses01F_script01_1_M015	neu	[3.0000, 1.6667, 2.6667]
#  neu
# [169.7574 - 172.1800]	Ses01F_script01_1_M016	neu	[3.6667, 2.6667, 2.3333]
#  neu
# [174.7833 - 177.7200]	Ses01F_script01_1_M017	neu	[3.0000, 2.6667, 2.6667]
#  neu
# [179.2800 - 181.9475]	Ses01F_script01_1_M018	fru	[3.0000, 3.3333, 3.6667]
#  fru
# [185.0300 - 195.2800]	Ses01F_script01_1_M019	ang	[2.0000, 4.3333, 4.0000]
#  ang
# [197.6000 - 199.7475]	Ses01F_script01_1_M020	fru	[2.6667, 4.0000, 3.6667]
#  fru
# [224.7000 - 236.0500]	Ses01F_script01_1_M021	fru	[2.0000, 3.0000, 2.3333]
#  fru
# [237.8000 - 240.4290]	Ses01F_script01_1_M022	fru	[2.0000, 3.3333, 3.3333]
#  fru
# [245.2786 - 247.5700]	Ses01F_script01_1_M023	neu	[3.0000, 2.0000, 2.3333]
#  neu
# [251.2965 - 261.0500]	Ses01F_script01_1_M024	neu	[2.6667, 1.6667, 2.0000]
#  neu
# [262.6500 - 267.2119]	Ses01F_script01_1_M025	neu	[2.6667, 2.0000, 3.0000]
#  neu
# [269.7300 - 274.6626]	Ses01F_script01_1_M026	fru	[2.0000, 3.3333, 3.0000]
#  fru
# [276.2400 - 278.3659]	Ses01F_script01_1_M027	fru	[3.0000, 2.6667, 2.6667]
#  fru
# [281.5700 - 283.8900]	Ses01F_script01_1_M028	fru	[2.0000, 3.0000, 1.6667]
#  fru
# [285.9600 - 296.0300]	Ses01F_script01_1_M029	fru	[2.6667, 3.0000, 3.3333]
#  fru
# [297.0000 - 300.0700]	Ses01F_script01_1_M030	fru	[1.6667, 4.3333, 4.6667]
#  fru
# [318.2868 - 321.9800]	Ses01F_script01_1_M031	fru	[2.0000, 2.0000, 1.3333]
#  fru
# [325.7300 - 336.5389]	Ses01F_script01_1_M032	fru	[2.6667, 3.6667, 3.3333]
#  fru
# [336.7373 - 342.3143]	Ses01F_script01_1_M033	fru	[2.0000, 2.0000, 3.0000]
#  fru
# [344.4966 - 350.1500]	Ses01F_script01_1_M034	neu	[3.0000, 2.6667, 3.3333]
#  neu
# [352.1016 - 356.8800]	Ses01F_script01_1_M035	fru	[2.3333, 2.3333, 2.3333]
#  fru
# [359.0300 - 362.8200]	Ses01F_script01_1_M036	fru	[3.0000, 3.3333, 3.0000]
#  fru
# [363.8700 - 373.5675]	Ses01F_script01_1_M037	fru	[3.0000, 4.0000, 4.0000]
#  fru
# [373.5975 - 383.1500]	Ses01F_script01_1_M038	fru	[2.6667, 3.6667, 3.6667]
#  fru
# [387.5000 - 390.1100]	Ses01F_script01_1_M039	neu	[3.0000, 1.6667, 2.0000]
#  neu
# [392.3100 - 395.6900]	Ses01F_script01_1_M040	neu	[3.0000, 1.6667, 2.0000]
#  neu
# [403.4300 - 407.0400]	Ses01F_script01_1_M041	fru	[2.6667, 2.6667, 2.3333]
#  fru
# [408.9600 - 412.8536]	Ses01F_script01_1_M042	fru	[3.0000, 2.6667, 3.6667]
#  fru
# [415.9200 - 420.4807]	Ses01F_script01_1_M043	fru	[3.0000, 2.3333, 3.3333]
#  fru
# /media/vincentwu-cmlab/7C5650545650116E/IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_script01_2.txt
# [6.7800 - 10.5900]	Ses01F_script01_2_F000	xxx	[2.5000, 2.5000, 3.0000]
#  xxx
# [12.7100 - 17.2300]	Ses01F_script01_2_F001	xxx	[2.5000, 2.0000, 3.5000]
#  xxx
# [21.2500 - 26.4100]	Ses01F_script01_2_F002	xxx	[2.5000, 2.5000, 4.5000]
#  xxx
# [39.9300 - 42.9600]	Ses01F_script01_2_F003	ang	[2.0000, 2.5000, 4.0000]
#  ang
# [44.3500 - 46.3000]	Ses01F_script01_2_F004	ang	[2.5000, 2.5000, 3.5000]
#  ang
# [47.1000 - 50.8500]	Ses01F_script01_2_F005	ang	[1.5000, 3.5000, 4.5000]
#  ang
# [52.0300 - 56.4200]	Ses01F_script01_2_F006	ang	[1.5000, 4.0000, 4.5000]
#  ang
# [57.7600 - 66.6500]	Ses01F_script01_2_F007	ang	[1.5000, 4.5000, 4.5000]
#  ang
# [67.4800 - 78.2600]	Ses01F_script01_2_F008	ang	[1.5000, 4.5000, 4.5000]
#  ang
# [82.1200 - 91.2800]	Ses01F_script01_2_F009	ang	[1.5000, 2.0000, 4.5000]
#  ang
# [92.3600 - 102.1700]	Ses01F_script01_2_F010	ang	[1.5000, 3.5000, 4.5000]
#  ang
# [102.2600 - 105.7600]	Ses01F_script01_2_F011	ang	[1.5000, 3.5000, 4.5000]
#  ang
# [108.2000 - 122.3400]	Ses01F_script01_2_F012	ang	[1.5000, 4.5000, 5.0000]
#  ang
# [122.4100 - 132.6200]	Ses01F_script01_2_F013	ang	[1.0000, 4.5000, 5.0000]
#  ang
# [137.9800 - 140.6900]	Ses01F_script01_2_F014	fru	[2.0000, 3.0000, 2.5000]
#  fru
# [10.0840 - 13.4800]	Ses01F_script01_2_M000	xxx	[2.5000, 2.5000, 3.0000]
#  xxx
# [16.6300 - 21.6600]	Ses01F_script01_2_M001	neu	[3.0000, 3.0000, 2.5000]
#  neu
# [25.7300 - 33.0800]	Ses01F_script01_2_M002	xxx	[3.0000, 3.0000, 3.0000]
#  xxx
# [33.6200 - 40.5200]	Ses01F_script01_2_M003	fru	[2.0000, 3.5000, 4.0000]
#  fru
# [42.4400 - 45.2400]	Ses01F_script01_2_M004	neu	[2.5000, 3.0000, 2.5000]
#  neu
# [45.8000 - 47.5900]	Ses01F_script01_2_M005	xxx	[3.0000, 2.5000, 3.0000]
#  xxx
# [50.6000 - 52.5500]	Ses01F_script01_2_M006	fru	[2.5000, 3.5000, 3.0000]
#  fru
# [55.8700 - 58.2000]	Ses01F_script01_2_M007	fru	[2.5000, 3.5000, 3.5000]
#  fru
# [66.1000 - 68.3100]	Ses01F_script01_2_M008	neu	[2.0000, 3.5000, 3.0000]
#  neu
# [78.3800 - 82.6500]	Ses01F_script01_2_M009	fru	[2.5000, 3.0000, 2.5000]
#  fru
# [90.6500 - 94.8900]	Ses01F_script01_2_M010	fru	[1.5000, 2.5000, 3.5000]
#  fru
# [106.6100 - 108.1825]	Ses01F_script01_2_M011	fru	[2.5000, 2.0000, 3.0000]
#  fru
# [109.3800 - 111.6500]	Ses01F_script01_2_M012	fru	[2.0000, 2.0000, 3.0000]
#  fru
# [121.2900 - 123.2300]	Ses01F_script01_2_M013	fru	[2.5000, 2.5000, 4.0000]
#  fru
# [124.1625 - 126.3600]	Ses01F_script01_2_M014	fru	[2.0000, 3.0000, 4.0000]
#  fru
# [126.5800 - 133.7600]	Ses01F_script01_2_M015	fru	[1.5000, 4.0000, 4.5000]
#  fru
# [134.6100 - 138.0400]	Ses01F_script01_2_M016	xxx	[2.5000, 3.5000, 4.0000]
#  xxx
# [140.9200 - 147.5100]	Ses01F_script01_2_M017	ang	[1.5000, 4.0000, 4.5000]
#  ang
# /media/vincentwu-cmlab/7C5650545650116E/IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_script01_3.txt
# [4.8285 - 8.9243]	Ses01F_script01_3_F000	neu	[4.0000, 1.6667, 2.3333]
#  neu
# [12.3484 - 17.0473]	Ses01F_script01_3_F001	neu	[4.3333, 2.0000, 2.3333]
#  neu
# [17.1566 - 26.1173]	Ses01F_script01_3_F002	neu	[3.3333, 2.0000, 2.3333]
#  neu
# [28.3100 - 36.1344]	Ses01F_script01_3_F003	neu	[3.0000, 1.3333, 2.3333]
#  neu
# [38.3200 - 41.6000]	Ses01F_script01_3_F004	neu	[3.3333, 2.6667, 2.6667]
#  neu
# [42.8200 - 47.3300]	Ses01F_script01_3_F005	neu	[3.3333, 2.0000, 1.6667]
#  neu
# [49.1000 - 53.9831]	Ses01F_script01_3_F006	neu	[3.0000, 2.3333, 2.3333]
#  neu
# [63.0100 - 65.8944]	Ses01F_script01_3_F007	neu	[2.6667, 1.3333, 2.3333]
#  neu
# [69.6400 - 75.9100]	Ses01F_script01_3_F008	neu	[3.6667, 2.6667, 3.0000]
#  neu
# [87.6100 - 94.6700]	Ses01F_script01_3_F009	neu	[4.0000, 3.0000, 2.0000]
#  neu
# [97.0200 - 98.4227]	Ses01F_script01_3_F010	hap	[4.6667, 3.6667, 2.3333]
#  hap
# [98.9525 - 101.7250]	Ses01F_script01_3_F011	hap	[4.6667, 4.0000, 2.6667]
#  hap
# [108.9225 - 114.0700]	Ses01F_script01_3_F012	hap	[5.0000, 4.3333, 2.3333]
#  hap
# [117.0000 - 118.8000]	Ses01F_script01_3_F013	hap	[4.3333, 3.3333, 2.3333]
#  hap
# [137.2890 - 142.2065]	Ses01F_script01_3_F014	neu	[3.0000, 2.6667, 3.0000]
#  neu
# [146.9800 - 150.5845]	Ses01F_script01_3_F015	neu	[3.0000, 2.0000, 2.3333]
#  neu
# [153.3875 - 156.3762]	Ses01F_script01_3_F016	neu	[2.6667, 1.6667, 1.6667]
#  neu
# [159.0600 - 161.2300]	Ses01F_script01_3_F017	hap	[4.3333, 3.0000, 2.6667]
#  hap
# [162.8000 - 169.6600]	Ses01F_script01_3_F018	xxx	[4.3333, 4.3333, 4.3333]
#  xxx
# [169.6900 - 172.4600]	Ses01F_script01_3_F019	hap	[4.3333, 4.0000, 3.3333]
#  hap
# [186.2090 - 193.6800]	Ses01F_script01_3_F020	hap	[4.3333, 3.6667, 3.6667]
#  hap
# [196.1400 - 198.8950]	Ses01F_script01_3_F021	hap	[4.0000, 2.3333, 3.0000]
#  hap
# [200.9200 - 206.2900]	Ses01F_script01_3_F022	neu	[3.3333, 1.6667, 3.0000]
#  neu
# [212.5813 - 215.6700]	Ses01F_script01_3_F023	xxx	[2.0000, 2.3333, 2.3333]
#  xxx
# [218.5400 - 222.9675]	Ses01F_script01_3_F024	xxx	[2.0000, 2.3333, 3.0000]
#  xxx
# [225.0400 - 232.9798]	Ses01F_script01_3_F025	xxx	[2.3333, 1.6667, 2.6667]
#  xxx
# [240.6200 - 243.6500]	Ses01F_script01_3_F026	xxx	[2.6667, 1.6667, 2.6667]
#  xxx
# [247.4800 - 250.6200]	Ses01F_script01_3_F027	xxx	[2.3333, 2.3333, 2.3333]
#  xxx
# [259.1300 - 261.6600]	Ses01F_script01_3_F028	neu	[2.6667, 2.3333, 1.6667]
#  neu
# [266.3100 - 268.5425]	Ses01F_script01_3_F029	neu	[2.3333, 2.0000, 2.0000]
#  neu
# [270.6600 - 273.2600]	Ses01F_script01_3_F030	sad	[1.6667, 2.3333, 1.3333]
#  sad
# [344.1800 - 345.7400]	Ses01F_script01_3_F031	neu	[2.0000, 1.0000, 1.3333]
#  neu
# [415.8011 - 419.8444]	Ses01F_script01_3_F032	xxx	[2.3333, 1.3333, 1.6667]
#  xxx
# [422.4670 - 432.4477]	Ses01F_script01_3_F033	xxx	[2.0000, 2.3333, 3.6667]
#  xxx
# [432.5570 - 450.4700]	Ses01F_script01_3_F034	xxx	[2.6667, 2.6667, 4.0000]
#  xxx
# [459.5700 - 463.0600]	Ses01F_script01_3_F035	hap	[4.0000, 2.0000, 2.3333]
#  hap
# [8.5900 - 13.1700]	Ses01F_script01_3_M000	neu	[4.0000, 1.6667, 2.0000]
#  neu
# [26.0445 - 28.8493]	Ses01F_script01_3_M001	neu	[3.0000, 2.0000, 2.3333]
#  neu
# [36.1709 - 38.5386]	Ses01F_script01_3_M002	xxx	[2.6667, 1.6667, 2.0000]
#  xxx
# [41.0000 - 43.3200]	Ses01F_script01_3_M003	neu	[4.0000, 2.6667, 1.6667]
#  neu
# [47.2100 - 49.5100]	Ses01F_script01_3_M004	neu	[3.0000, 3.0000, 2.6667]
#  neu
# [54.6200 - 63.9000]	Ses01F_script01_3_M005	neu	[4.0000, 2.6667, 2.3333]
#  neu
# [67.6792 - 69.8648]	Ses01F_script01_3_M006	xxx	[3.3333, 1.6667, 1.6667]
#  xxx
# [78.0800 - 87.2500]	Ses01F_script01_3_M007	xxx	[3.0000, 3.0000, 2.0000]
#  xxx
# [98.0700 - 105.5800]	Ses01F_script01_3_M008	hap	[4.6667, 3.6667, 2.6667]
#  hap
# [106.5092 - 114.9575]	Ses01F_script01_3_M009	hap	[4.6667, 4.0000, 2.3333]
#  hap
# [115.2878 - 126.5450]	Ses01F_script01_3_M010	hap	[4.3333, 4.0000, 2.6667]
#  hap
# [126.6800 - 137.2162]	Ses01F_script01_3_M011	xxx	[3.0000, 3.3333, 3.0000]
#  xxx
# [142.9100 - 147.3790]	Ses01F_script01_3_M012	xxx	[2.6667, 2.6667, 3.0000]
#  xxx
# [151.0300 - 153.5714]	Ses01F_script01_3_M013	xxx	[2.0000, 2.3333, 2.0000]
#  xxx
# [156.3033 - 159.5400]	Ses01F_script01_3_M014	sur	[4.3333, 3.3333, 2.3333]
#  sur
# [160.7000 - 163.6600]	Ses01F_script01_3_M015	hap	[4.0000, 4.0000, 3.3333]
#  hap
# [171.7200 - 173.6000]	Ses01F_script01_3_M016	hap	[4.0000, 3.3333, 2.3333]
#  hap
# [173.6700 - 175.7325]	Ses01F_script01_3_M017	hap	[4.0000, 3.0000, 3.3333]
#  hap
# [180.2600 - 186.3491]	Ses01F_script01_3_M018	xxx	[5.0000, 4.3333, 3.6667]
#  xxx
# [191.1025 - 196.7400]	Ses01F_script01_3_M019	hap	[4.3333, 3.3333, 3.6667]
#  hap
# [199.1000 - 201.4000]	Ses01F_script01_3_M020	hap	[4.0000, 3.6667, 2.3333]
#  hap
# [216.4800 - 220.0400]	Ses01F_script01_3_M021	sad	[2.6667, 2.6667, 2.6667]
#  sad
# [222.6800 - 225.5000]	Ses01F_script01_3_M022	sad	[3.0000, 2.0000, 2.0000]
#  sad
# [232.7248 - 240.3000]	Ses01F_script01_3_M023	sad	[2.3333, 3.0000, 2.3333]
#  sad
# [243.8300 - 247.5200]	Ses01F_script01_3_M024	sad	[2.3333, 3.0000, 2.3333]
#  sad
# [251.5000 - 259.7300]	Ses01F_script01_3_M025	sad	[2.6667, 3.0000, 2.3333]
#  sad
# [261.7500 - 264.9617]	Ses01F_script01_3_M026	sad	[2.0000, 1.6667, 2.3333]
#  sad
# [268.5600 - 270.7875]	Ses01F_script01_3_M027	sad	[2.3333, 1.6667, 2.6667]
#  sad
# [272.4400 - 283.5024]	Ses01F_script01_3_M028	sad	[1.6667, 3.3333, 3.6667]
#  sad
# [283.7300 - 304.5800]	Ses01F_script01_3_M029	sad	[2.3333, 2.3333, 2.6667]
#  sad
# [304.7751 - 319.9900]	Ses01F_script01_3_M030	sad	[2.0000, 2.3333, 3.6667]
#  sad
# [320.9000 - 344.4800]	Ses01F_script01_3_M031	xxx	[2.0000, 2.6667, 3.6667]
#  xxx
# [345.9000 - 359.2200]	Ses01F_script01_3_M032	sad	[2.0000, 3.0000, 3.3333]
#  sad
# [360.2517 - 378.3500]	Ses01F_script01_3_M033	sad	[1.6667, 3.3333, 3.3333]
#  sad
# [378.4700 - 383.6500]	Ses01F_script01_3_M034	xxx	[1.6667, 3.0000, 3.3333]
#  xxx
# [384.5200 - 400.6480]	Ses01F_script01_3_M035	xxx	[2.3333, 3.6667, 3.6667]
#  xxx
# [401.9100 - 412.5900]	Ses01F_script01_3_M036	sad	[2.0000, 2.6667, 2.3333]
#  sad
# [419.4437 - 422.5035]	Ses01F_script01_3_M037	neu	[2.3333, 2.3333, 2.3333]
#  neu
# [451.0400 - 460.2800]	Ses01F_script01_3_M038	xxx	[4.0000, 3.0000, 3.0000]
#  xxx
# /media/vincentwu-cmlab/7C5650545650116E/IEMOCAP_full_release/Session1/dialog/EmoEvaluation/Ses01F_script02_1.txt
# [15.1400 - 17.2100]	Ses01F_script02_1_F000	neu	[2.5000, 2.0000, 2.0000]
#  neu
# [25.9100 - 27.4125]	Ses01F_script02_1_F001	fru	[2.5000, 2.0000, 2.5000]
#  fru
# [38.9900 - 40.0500]	Ses01F_script02_1_F002	xxx	[2.0000, 2.0000, 2.5000]
#  xxx
# [45.0600 - 47.0300]	Ses01F_script02_1_F003	sur	[2.5000, 3.0000, 3.0000]
#  sur
# [49.2200 - 51.4000]	Ses01F_script02_1_F004	neu	[2.0000, 3.0000, 3.0000]
#  neu
# [51.8700 - 54.2300]	Ses01F_script02_1_F005	xxx	[2.0000, 3.5000, 3.0000]
#  xxx
# [54.7200 - 57.6900]	Ses01F_script02_1_F006	ang	[2.0000, 3.5000, 3.0000]
#  ang
# [57.7500 - 59.5700]	Ses01F_script02_1_F007	ang	[2.0000, 3.5000, 2.5000]
#  ang
# [76.2700 - 77.6400]	Ses01F_script02_1_F008	neu	[2.5000, 1.5000, 3.0000]
#  neu
# [101.7200 - 103.5025]	Ses01F_script02_1_F009	hap	[4.0000, 2.5000, 2.0000]
#  hap
# [110.7700 - 112.6900]	Ses01F_script02_1_F010	sad	[2.0000, 2.0000, 2.5000]
#  sad
# [113.7900 - 115.9800]	Ses01F_script02_1_F011	xxx	[2.0000, 2.0000, 2.5000]
#  xxx
# [121.6500 - 123.2300]	Ses01F_script02_1_F012	xxx	[2.5000, 3.0000, 2.5000]
#  xxx
# [124.0500 - 126.0400]	Ses01F_script02_1_F013	xxx	[2.5000, 3.5000, 3.0000]
#  xxx
# [127.4400 - 129.3900]	Ses01F_script02_1_F014	fru	[2.5000, 2.5000, 2.5000]
#  fru
# [137.2900 - 139.6146]	Ses01F_script02_1_F015	neu	[2.5000, 1.5000, 2.5000]
#  neu
# [140.5000 - 143.0700]	Ses01F_script02_1_F016	xxx	[2.0000, 1.5000, 2.0000]
#  xxx
# [154.9000 - 163.9900]	Ses01F_script02_1_F017	fru	[2.0000, 3.5000, 3.5000]
#  fru
# [180.6769 - 189.4500]	Ses01F_script02_1_F018	xxx	[2.5000, 2.0000, 3.0000]
#  xxx
# [189.9300 - 191.5900]	Ses01F_script02_1_F019	fru	[2.0000, 2.0000, 3.0000]
#  fru
# [208.3800 - 210.2000]	Ses01F_script02_1_F020	xxx	[2.5000, 1.5000, 2.0000]
#  xxx
# [210.6400 - 211.9200]	Ses01F_script02_1_F021	fru	[2.5000, 2.0000, 3.0000]
#  fru
# [224.5800 - 237.0050]	Ses01F_script02_1_F022	xxx	[2.5000, 3.0000, 3.0000]
#  xxx
# [238.1400 - 240.7300]	Ses01F_script02_1_F023	fru	[2.5000, 2.5000, 3.5000]
#  fru
# [321.2100 - 323.8200]	Ses01F_script02_1_F024	neu	[2.5000, 1.5000, 2.5000]
#  neu
# [326.5600 - 329.0300]	Ses01F_script02_1_F025	neu	[2.5000, 1.5000, 2.0000]
#  neu
# [1.8151 - 9.0350]	Ses01F_script02_1_M000	xxx	[4.5000, 3.5000, 2.5000]
#  xxx
# [9.0925 - 15.6200]	Ses01F_script02_1_M001	xxx	[4.0000, 3.0000, 2.5000]
#  xxx
# [16.9600 - 20.0000]	Ses01F_script02_1_M002	exc	[3.5000, 4.5000, 2.5000]
#  exc
# [20.0500 - 26.6500]	Ses01F_script02_1_M003	xxx	[2.5000, 2.5000, 1.5000]
#  xxx
# [27.1300 - 35.7987]	Ses01F_script02_1_M004	xxx	[4.5000, 3.0000, 2.5000]
#  xxx
# [35.8990 - 39.4800]	Ses01F_script02_1_M005	xxx	[3.0000, 4.0000, 2.5000]
#  xxx
# [39.5000 - 45.4500]	Ses01F_script02_1_M006	xxx	[2.0000, 2.5000, 2.5000]
#  xxx
# [46.4200 - 49.9500]	Ses01F_script02_1_M007	neu	[3.0000, 2.5000, 2.5000]
#  neu
# [50.8500 - 52.4000]	Ses01F_script02_1_M008	neu	[3.0000, 2.0000, 2.0000]
#  neu
# [53.7600 - 55.4800]	Ses01F_script02_1_M009	neu	[2.5000, 2.0000, 2.0000]
#  neu
# [57.2900 - 58.4200]	Ses01F_script02_1_M010	neu	[3.0000, 3.5000, 1.5000]
#  neu
# [58.8800 - 65.6016]	Ses01F_script02_1_M011	neu	[2.5000, 2.0000, 2.0000]
#  neu
# [65.7270 - 73.0100]	Ses01F_script02_1_M012	fru	[3.5000, 3.0000, 2.5000]
#  fru
# [73.1527 - 77.1400]	Ses01F_script02_1_M013	neu	[3.0000, 3.0000, 2.0000]
#  neu
# [77.1900 - 87.6779]	Ses01F_script02_1_M014	neu	[3.5000, 3.0000, 2.0000]
#  neu
# [87.8250 - 94.5265]	Ses01F_script02_1_M015	neu	[3.5000, 3.0000, 2.5000]
#  neu
# [94.6400 - 100.4000]	Ses01F_script02_1_M016	exc	[4.0000, 4.0000, 2.5000]
#  exc
# [104.2500 - 111.2300]	Ses01F_script02_1_M017	xxx	[4.0000, 2.5000, 2.0000]
#  xxx
# [112.1900 - 114.3500]	Ses01F_script02_1_M018	fru	[3.5000, 3.0000, 2.5000]
#  fru
# [115.8753 - 121.9194]	Ses01F_script02_1_M019	xxx	[3.0000, 3.5000, 2.0000]
#  xxx
# [122.7000 - 124.5900]	Ses01F_script02_1_M020	neu	[4.0000, 3.0000, 2.5000]
#  neu
# [125.7500 - 127.9600]	Ses01F_script02_1_M021	neu	[3.0000, 2.0000, 2.5000]
#  neu
# [128.8000 - 137.7400]	Ses01F_script02_1_M022	fru	[3.0000, 3.0000, 3.0000]
#  fru
# [139.1100 - 141.0400]	Ses01F_script02_1_M023	neu	[2.5000, 2.0000, 1.5000]
#  neu
# [142.7800 - 155.6400]	Ses01F_script02_1_M024	neu	[3.0000, 3.0000, 2.5000]
#  neu
# [163.1900 - 176.2823]	Ses01F_script02_1_M025	neu	[3.0000, 3.0000, 2.5000]
#  neu
# [176.3975 - 181.5500]	Ses01F_script02_1_M026	neu	[3.5000, 3.0000, 3.0000]
#  neu
# [188.8800 - 190.4700]	Ses01F_script02_1_M027	fru	[3.0000, 3.0000, 2.5000]
#  fru
# [191.1300 - 201.9700]	Ses01F_script02_1_M028	xxx	[3.5000, 3.0000, 2.5000]
#  xxx
# [202.0250 - 209.4025]	Ses01F_script02_1_M029	neu	[3.5000, 3.0000, 2.5000]
#  neu
# [209.6300 - 211.1150]	Ses01F_script02_1_M030	sur	[3.0000, 3.5000, 2.0000]
#  sur
# [211.5500 - 218.5600]	Ses01F_script02_1_M031	neu	[3.5000, 3.0000, 2.0000]
#  neu
# [218.6125 - 225.2700]	Ses01F_script02_1_M032	neu	[3.0000, 2.5000, 2.0000]
#  neu
# [236.5000 - 238.7700]	Ses01F_script02_1_M033	neu	[3.5000, 2.5000, 3.0000]
#  neu
# [240.1700 - 245.7100]	Ses01F_script02_1_M034	neu	[3.0000, 2.5000, 3.0000]
#  neu
# [245.7900 - 253.1140]	Ses01F_script02_1_M035	exc	[3.0000, 4.0000, 2.5000]
#  exc
# [253.1700 - 261.4425]	Ses01F_script02_1_M036	hap	[3.5000, 3.5000, 2.5000]
#  hap
# [261.5675 - 276.6283]	Ses01F_script02_1_M037	xxx	[4.0000, 3.5000, 2.5000]
#  xxx
# [276.7775 - 291.4000]	Ses01F_script02_1_M038	exc	[3.5000, 3.5000, 2.5000]
#  exc
# [291.4700 - 298.1386]	Ses01F_script02_1_M039	xxx	[3.0000, 3.5000, 2.5000]
#  xxx
# [298.2452 - 305.6600]	Ses01F_script02_1_M040	exc	[3.0000, 3.5000, 2.5000]
#  exc
# [305.9850 - 316.0900]	Ses01F_script02_1_M041	xxx	[3.0000, 3.5000, 2.5000]
#  xxx
# [316.1527 - 321.7375]	Ses01F_script02_1_M042	xxx	[4.0000, 3.0000, 2.5000]
#  xxx
# [324.1500 - 327.0891]	Ses01F_script02_1_M043	hap	[4.0000, 3.0000, 2.0000]
#  hap
# [328.2400 - 331.9283]	Ses01F_script02_1_M044	hap	[4.0000, 2.0000, 1.5000]
#  hap
# ...
#  xxx
# [428.3000 - 441.7800]	Ses05M_script02_2_F037	hap	[3.6667, 2.6667, 2.3333]
#  hap
# [448.6800 - 450.6900]	Ses05M_script02_2_F038	hap	[3.6667, 2.6667, 2.3333]
#  hap
# [4.1500 - 8.3200]	Ses05M_script02_2_M000	exc	[4.0000, 3.0000, 2.6667]
#  exc
# [9.2900 - 11.5200]	Ses05M_script02_2_M001	exc	[3.3333, 3.6667, 2.3333]
#  exc
# [12.6300 - 17.9200]	Ses05M_script02_2_M002	fru	[2.6667, 3.6667, 3.0000]
#  fru
# [22.9600 - 25.4500]	Ses05M_script02_2_M003	xxx	[3.0000, 3.3333, 3.0000]
#  xxx
# [36.3400 - 38.5400]	Ses05M_script02_2_M004	xxx	[3.0000, 2.3333, 2.0000]
#  xxx
# [41.6000 - 50.7100]	Ses05M_script02_2_M005	neu	[3.0000, 3.0000, 2.0000]
#  neu
# [56.0900 - 58.1900]	Ses05M_script02_2_M006	fru	[2.3333, 3.3333, 2.6667]
#  fru
# [61.5600 - 71.6400]	Ses05M_script02_2_M007	fru	[2.6667, 4.0000, 3.3333]
#  fru
# [75.7300 - 77.2100]	Ses05M_script02_2_M008	xxx	[2.0000, 3.3333, 2.3333]
#  xxx
# [79.7700 - 82.9200]	Ses05M_script02_2_M009	fru	[2.0000, 3.0000, 3.0000]
#  fru
# [84.1500 - 85.9900]	Ses05M_script02_2_M010	xxx	[3.0000, 3.0000, 3.0000]
#  xxx
# [101.7300 - 105.6300]	Ses05M_script02_2_M011	fru	[1.6667, 3.3333, 3.3333]
#  fru
# [106.5200 - 109.0000]	Ses05M_script02_2_M012	fru	[2.0000, 3.6667, 3.0000]
#  fru
# [121.2400 - 130.2900]	Ses05M_script02_2_M013	fru	[2.6667, 3.0000, 2.3333]
#  fru
# [130.3158 - 152.0600]	Ses05M_script02_2_M014	fru	[3.0000, 3.3333, 2.3333]
#  fru
# [194.6400 - 198.9500]	Ses05M_script02_2_M015	xxx	[4.0000, 3.0000, 2.3333]
#  xxx
# [206.4500 - 217.6200]	Ses05M_script02_2_M016	neu	[3.3333, 4.0000, 3.0000]
#  neu
# [222.5000 - 230.0600]	Ses05M_script02_2_M017	xxx	[3.3333, 3.6667, 2.6667]
#  xxx
# [231.5100 - 233.8500]	Ses05M_script02_2_M018	xxx	[3.3333, 3.0000, 2.3333]
#  xxx
# [234.5700 - 236.1800]	Ses05M_script02_2_M019	xxx	[3.3333, 3.3333, 2.3333]
#  xxx
# [236.4400 - 239.7700]	Ses05M_script02_2_M020	fru	[3.3333, 3.3333, 2.3333]
#  fru
# [240.7000 - 246.8100]	Ses05M_script02_2_M021	fru	[2.3333, 3.0000, 3.0000]
#  fru
# [246.9500 - 248.1200]	Ses05M_script02_2_M022	fru	[2.6667, 3.3333, 3.0000]
#  fru
# [248.8600 - 254.5800]	Ses05M_script02_2_M023	fru	[1.6667, 4.0000, 3.6667]
#  fru
# [256.4200 - 270.4100]	Ses05M_script02_2_M024	ang	[2.0000, 4.3333, 3.3333]
#  ang
# [270.4270 - 297.2000]	Ses05M_script02_2_M025	ang	[2.0000, 4.3333, 3.3333]
#  ang
# [297.2600 - 302.6900]	Ses05M_script02_2_M026	ang	[1.6667, 3.6667, 4.3333]
#  ang
# [305.9800 - 307.3100]	Ses05M_script02_2_M027	xxx	[2.6667, 3.3333, 3.0000]
#  xxx
# [312.0300 - 313.7020]	Ses05M_script02_2_M028	fru	[2.6667, 3.0000, 2.6667]
#  fru
# [318.3400 - 321.9900]	Ses05M_script02_2_M029	sad	[2.6667, 2.0000, 2.0000]
#  sad
# [331.7400 - 334.0400]	Ses05M_script02_2_M030	sad	[2.3333, 2.0000, 2.0000]
#  sad
# [353.3600 - 356.9900]	Ses05M_script02_2_M031	sad	[2.3333, 2.0000, 2.0000]
#  sad
# [358.0900 - 362.3500]	Ses05M_script02_2_M032	sad	[2.0000, 2.6667, 2.0000]
#  sad
# [368.5200 - 370.1900]	Ses05M_script02_2_M033	sur	[3.3333, 2.6667, 1.6667]
#  sur
# [381.7787 - 389.3800]	Ses05M_script02_2_M034	hap	[3.3333, 2.6667, 2.3333]
#  hap
# [394.7600 - 400.7742]	Ses05M_script02_2_M035	hap	[4.0000, 3.0000, 2.3333]
#  hap
# [412.3500 - 416.0200]	Ses05M_script02_2_M036	hap	[4.3333, 3.0000, 2.6667]
#  hap
# [417.8700 - 420.0800]	Ses05M_script02_2_M037	hap	[4.0000, 3.3333, 2.3333]
#  hap
# [423.1700 - 427.8400]	Ses05M_script02_2_M038	xxx	[3.3333, 2.6667, 2.3333]
#  xxx
# [440.8400 - 447.4700]	Ses05M_script02_2_M039	xxx	[4.0000, 3.0000, 2.6667]
#  xxx
# [450.9519 - 453.2597]	Ses05M_script02_2_M040	hap	[4.0000, 2.3333, 2.0000]
#  hap
# /media/vincentwu-cmlab/7C5650545650116E/IEMOCAP_full_release/Session5/dialog/EmoEvaluation/Ses05M_script03_1.txt
# [5.1500 - 6.5000]	Ses05M_script03_1_F000	fea	[3.5000, 3.0000, 3.0000]
#  fea
# [7.7000 - 11.1200]	Ses05M_script03_1_F001	exc	[2.5000, 4.0000, 3.0000]
#  exc
# [12.3000 - 14.6700]	Ses05M_script03_1_F002	exc	[2.5000, 3.0000, 2.5000]
#  exc
# [16.6700 - 18.9500]	Ses05M_script03_1_F003	exc	[4.0000, 3.0000, 3.5000]
#  exc
# [20.1800 - 22.9600]	Ses05M_script03_1_F004	exc	[4.0000, 3.0000, 3.0000]
#  exc
# [30.4200 - 33.0800]	Ses05M_script03_1_F005	exc	[4.0000, 4.5000, 3.5000]
#  exc
# [34.4000 - 36.3400]	Ses05M_script03_1_F006	xxx	[4.0000, 3.0000, 3.0000]
#  xxx
# [37.5500 - 40.3200]	Ses05M_script03_1_F007	xxx	[4.0000, 3.0000, 3.0000]
#  xxx
# [50.8400 - 53.4900]	Ses05M_script03_1_F008	xxx	[2.5000, 3.0000, 3.5000]
#  xxx
# [54.6500 - 58.2700]	Ses05M_script03_1_F009	xxx	[2.5000, 3.5000, 3.0000]
#  xxx
# [60.6600 - 62.3500]	Ses05M_script03_1_F010	xxx	[3.5000, 3.0000, 3.0000]
#  xxx
# [71.0600 - 74.0200]	Ses05M_script03_1_F011	neu	[3.0000, 2.0000, 3.5000]
#  neu
# [77.2400 - 79.1900]	Ses05M_script03_1_F012	neu	[3.5000, 3.0000, 3.0000]
#  neu
# [96.8500 - 99.8200]	Ses05M_script03_1_F013	neu	[3.5000, 3.0000, 3.0000]
#  neu
# [102.4900 - 107.4800]	Ses05M_script03_1_F014	xxx	[3.5000, 3.5000, 4.0000]
#  xxx
# [109.2600 - 112.9600]	Ses05M_script03_1_F015	neu	[3.0000, 2.5000, 2.5000]
#  neu
# [115.4600 - 118.1900]	Ses05M_script03_1_F016	xxx	[2.0000, 3.0000, 3.0000]
#  xxx
# [120.3800 - 124.4200]	Ses05M_script03_1_F017	neu	[3.5000, 3.5000, 3.0000]
#  neu
# [126.3900 - 128.8200]	Ses05M_script03_1_F018	xxx	[2.5000, 2.0000, 2.5000]
#  xxx
# [134.0900 - 137.1300]	Ses05M_script03_1_F019	xxx	[4.0000, 3.0000, 3.5000]
#  xxx
# [159.9200 - 162.7600]	Ses05M_script03_1_F020	neu	[4.0000, 2.5000, 2.5000]
#  neu
# [174.6500 - 181.0200]	Ses05M_script03_1_F021	xxx	[4.0000, 3.5000, 4.5000]
#  xxx
# [185.8500 - 187.9700]	Ses05M_script03_1_F022	xxx	[4.0000, 2.5000, 3.0000]
#  xxx
# [191.1700 - 196.9600]	Ses05M_script03_1_F023	xxx	[4.5000, 3.5000, 4.0000]
#  xxx
# [197.5500 - 203.6500]	Ses05M_script03_1_F024	exc	[4.0000, 3.5000, 4.0000]
#  exc
# [205.1900 - 207.9700]	Ses05M_script03_1_F025	xxx	[4.0000, 3.0000, 3.0000]
#  xxx
# [211.2000 - 216.1300]	Ses05M_script03_1_F026	exc	[2.5000, 3.5000, 3.5000]
#  exc
# [219.8600 - 221.8100]	Ses05M_script03_1_F027	xxx	[3.0000, 2.5000, 2.5000]
#  xxx
# [223.8700 - 230.5500]	Ses05M_script03_1_F028	xxx	[4.5000, 4.5000, 4.0000]
#  xxx
# [231.6400 - 234.9700]	Ses05M_script03_1_F029	xxx	[4.5000, 3.5000, 3.5000]
#  xxx
# [235.9100 - 237.9000]	Ses05M_script03_1_F030	xxx	[4.0000, 3.5000, 3.0000]
#  xxx
# [245.0600 - 247.0439]	Ses05M_script03_1_F031	neu	[3.0000, 2.5000, 2.5000]
#  neu
# [3.1147 - 5.5100]	Ses05M_script03_1_M000	xxx	[3.5000, 3.5000, 3.5000]
#  xxx
# [6.0800 - 7.8745]	Ses05M_script03_1_M001	exc	[3.0000, 3.0000, 3.5000]
#  exc
# [10.6800 - 12.8100]	Ses05M_script03_1_M002	fea	[3.0000, 3.5000, 3.5000]
#  fea
# [14.0600 - 17.1100]	Ses05M_script03_1_M003	neu	[3.5000, 3.5000, 3.5000]
#  neu
# [18.4300 - 20.5800]	Ses05M_script03_1_M004	exc	[4.0000, 4.0000, 3.5000]
#  exc
# [22.3800 - 31.0100]	Ses05M_script03_1_M005	xxx	[4.0000, 4.5000, 4.0000]
#  xxx
# [32.3100 - 35.2500]	Ses05M_script03_1_M006	exc	[3.5000, 4.0000, 4.0000]
#  exc
# [35.5600 - 38.0200]	Ses05M_script03_1_M007	exc	[4.0000, 3.5000, 3.0000]
#  exc
# [39.4700 - 44.0700]	Ses05M_script03_1_M008	exc	[3.5000, 3.0000, 3.0000]
#  exc
# [47.5400 - 51.4600]	Ses05M_script03_1_M009	exc	[3.5000, 4.0000, 4.0000]
#  exc
# [53.1200 - 55.3300]	Ses05M_script03_1_M010	exc	[2.5000, 3.5000, 3.5000]
#  exc
# [57.7200 - 61.1900]	Ses05M_script03_1_M011	exc	[3.0000, 3.5000, 2.5000]
#  exc
# [61.6400 - 72.3000]	Ses05M_script03_1_M012	exc	[4.0000, 4.0000, 4.5000]
#  exc
# [73.5200 - 77.2800]	Ses05M_script03_1_M013	exc	[4.0000, 4.0000, 4.0000]
#  exc
# [78.4200 - 89.7222]	Ses05M_script03_1_M014	exc	[3.5000, 4.0000, 4.5000]
#  exc
# [89.7322 - 97.0000]	Ses05M_script03_1_M015	exc	[3.5000, 4.0000, 4.0000]
#  exc
# [99.5300 - 102.8200]	Ses05M_script03_1_M016	exc	[4.0000, 3.5000, 3.5000]
#  exc
# [106.0400 - 108.5200]	Ses05M_script03_1_M017	xxx	[3.5000, 3.0000, 2.5000]
#  xxx
# [112.2300 - 115.9200]	Ses05M_script03_1_M018	exc	[3.5000, 3.5000, 3.0000]
#  exc
# [117.3500 - 119.6100]	Ses05M_script03_1_M019	xxx	[3.0000, 3.5000, 3.5000]
#  xxx
# [123.8200 - 126.8200]	Ses05M_script03_1_M020	exc	[4.0000, 3.5000, 4.0000]
#  exc
# [128.0200 - 134.6200]	Ses05M_script03_1_M021	exc	[3.5000, 4.5000, 4.0000]
#  exc
# [136.2700 - 153.6584]	Ses05M_script03_1_M022	exc	[4.0000, 4.0000, 4.0000]
#  exc
# [153.6684 - 160.2300]	Ses05M_script03_1_M023	exc	[4.5000, 4.5000, 4.5000]
#  exc
# [162.4100 - 174.9900]	Ses05M_script03_1_M024	exc	[4.5000, 4.5000, 4.0000]
#  exc
# [180.8000 - 186.2300]	Ses05M_script03_1_M025	exc	[3.5000, 3.5000, 3.5000]
#  exc
# [187.7200 - 191.9800]	Ses05M_script03_1_M026	exc	[3.5000, 3.5000, 3.5000]
#  exc
# [195.9200 - 198.3500]	Ses05M_script03_1_M027	exc	[3.0000, 4.0000, 4.0000]
#  exc
# [203.2500 - 205.7200]	Ses05M_script03_1_M028	exc	[4.0000, 3.5000, 3.0000]
#  exc
# [206.9300 - 213.8300]	Ses05M_script03_1_M029	exc	[4.5000, 4.0000, 4.0000]
#  exc
# [215.4000 - 220.7500]	Ses05M_script03_1_M030	exc	[4.5000, 4.5000, 3.5000]
#  exc
# [221.1300 - 223.8300]	Ses05M_script03_1_M031	exc	[2.5000, 3.5000, 3.5000]
#  exc
# [229.8800 - 233.0600]	Ses05M_script03_1_M032	exc	[4.5000, 4.5000, 4.5000]
#  exc
# [234.1400 - 236.6600]	Ses05M_script03_1_M033	exc	[4.0000, 3.0000, 3.5000]
#  exc
# [238.7300 - 245.3800]	Ses05M_script03_1_M034	xxx	[3.0000, 4.0000, 4.0000]
#  xxx
# /media/vincentwu-cmlab/7C5650545650116E/IEMOCAP_full_release/Session5/dialog/EmoEvaluation/Ses05M_script03_2.txt
# [8.8100 - 10.9600]	Ses05M_script03_2_F000	xxx	[2.5000, 3.0000, 3.0000]
#  xxx
# [13.1300 - 15.5200]	Ses05M_script03_2_F001	neu	[2.0000, 3.0000, 3.5000]
#  neu
# [17.7900 - 21.4300]	Ses05M_script03_2_F002	neu	[2.5000, 3.0000, 3.0000]
#  neu
# [24.9496 - 30.4600]	Ses05M_script03_2_F003	fru	[2.5000, 2.5000, 3.5000]
#  fru
# [32.1200 - 35.5500]	Ses05M_script03_2_F004	neu	[3.5000, 3.0000, 3.0000]
#  neu
# [37.1200 - 38.5800]	Ses05M_script03_2_F005	neu	[2.0000, 2.5000, 3.0000]
#  neu
# [39.2300 - 42.4900]	Ses05M_script03_2_F006	neu	[2.0000, 3.5000, 4.0000]
#  neu
# [43.2400 - 47.3100]	Ses05M_script03_2_F007	xxx	[2.5000, 3.5000, 4.0000]
#  xxx
# [48.6300 - 51.5000]	Ses05M_script03_2_F008	fru	[2.0000, 2.5000, 3.0000]
#  fru
# [55.6400 - 57.2800]	Ses05M_script03_2_F009	neu	[3.0000, 2.0000, 2.5000]
#  neu
# [58.9800 - 62.8400]	Ses05M_script03_2_F010	xxx	[2.0000, 2.0000, 3.5000]
#  xxx
# [65.4000 - 68.9800]	Ses05M_script03_2_F011	xxx	[2.5000, 2.5000, 3.0000]
#  xxx
# [77.0000 - 79.5900]	Ses05M_script03_2_F012	neu	[2.5000, 2.0000, 3.0000]
#  neu
# [82.2600 - 84.4600]	Ses05M_script03_2_F013	fru	[1.5000, 2.5000, 3.5000]
#  fru
# [85.0300 - 86.0700]	Ses05M_script03_2_F014	xxx	[1.5000, 3.5000, 3.5000]
#  xxx
# [92.1900 - 94.9900]	Ses05M_script03_2_F015	neu	[2.5000, 3.0000, 3.0000]
#  neu
# [98.5400 - 102.7200]	Ses05M_script03_2_F016	xxx	[2.5000, 3.5000, 3.0000]
#  xxx
# [103.3200 - 104.7400]	Ses05M_script03_2_F017	ang	[2.0000, 3.0000, 3.5000]
#  ang
# [104.8700 - 107.7200]	Ses05M_script03_2_F018	ang	[1.5000, 3.0000, 4.0000]
#  ang
# [112.6000 - 116.1000]	Ses05M_script03_2_F019	xxx	[2.0000, 3.0000, 4.0000]
#  xxx
# [117.2700 - 119.5000]	Ses05M_script03_2_F020	xxx	[3.5000, 3.0000, 4.0000]
#  xxx
# [121.8400 - 123.0985]	Ses05M_script03_2_F021	fru	[2.0000, 3.5000, 4.0000]
#  fru
# [123.1085 - 127.6600]	Ses05M_script03_2_F022	xxx	[1.5000, 4.5000, 5.0000]
#  xxx
# [135.4000 - 137.2600]	Ses05M_script03_2_F023	neu	[3.5000, 3.0000, 3.5000]
#  neu
# [139.7100 - 142.3200]	Ses05M_script03_2_F024	xxx	[4.0000, 2.5000, 3.0000]
#  xxx
# [147.6300 - 151.3600]	Ses05M_script03_2_F025	fru	[2.0000, 4.0000, 4.0000]
#  fru
# [153.0200 - 154.8600]	Ses05M_script03_2_F026	neu	[2.5000, 3.0000, 3.0000]
#  neu
# [161.7500 - 166.2900]	Ses05M_script03_2_F027	xxx	[2.0000, 3.0000, 4.5000]
#  xxx
# [169.4400 - 172.3200]	Ses05M_script03_2_F028	ang	[2.5000, 2.5000, 3.5000]
#  ang
# [177.1200 - 180.3500]	Ses05M_script03_2_F029	fru	[2.5000, 2.5000, 3.5000]
#  fru
# [188.5200 - 190.4000]	Ses05M_script03_2_F030	xxx	[3.0000, 2.0000, 2.5000]
#  xxx
# [193.7000 - 196.8500]	Ses05M_script03_2_F031	xxx	[3.0000, 3.5000, 3.5000]
#  xxx
# [197.7600 - 199.5700]	Ses05M_script03_2_F032	xxx	[4.0000, 2.5000, 3.5000]
#  xxx
# [201.6300 - 203.6900]	Ses05M_script03_2_F033	xxx	[2.5000, 3.5000, 3.5000]
#  xxx
# [205.1300 - 209.4100]	Ses05M_script03_2_F034	ang	[2.0000, 3.5000, 4.0000]
#  ang
# [212.4400 - 215.4500]	Ses05M_script03_2_F035	ang	[1.5000, 3.5000, 3.5000]
#  ang
# [215.7200 - 219.0600]	Ses05M_script03_2_F036	ang	[1.5000, 4.5000, 4.0000]
#  ang
# [222.6300 - 227.9500]	Ses05M_script03_2_F037	ang	[2.0000, 3.5000, 4.5000]
#  ang
# [230.2800 - 236.8700]	Ses05M_script03_2_F038	ang	[1.5000, 4.5000, 4.5000]
#  ang
# [243.0400 - 246.3600]	Ses05M_script03_2_F039	ang	[1.5000, 4.5000, 4.5000]
#  ang
# [246.3700 - 248.7500]	Ses05M_script03_2_F040	ang	[1.0000, 4.5000, 5.0000]
#  ang
# [248.7600 - 257.3000]	Ses05M_script03_2_F041	ang	[1.5000, 4.5000, 5.0000]
#  ang
# [259.4500 - 260.4100]	Ses05M_script03_2_F042	ang	[2.0000, 4.5000, 4.5000]
#  ang
# [260.4200 - 261.4300]	Ses05M_script03_2_F043	ang	[1.5000, 4.5000, 5.0000]
#  ang
# [261.9100 - 263.0700]	Ses05M_script03_2_F044	ang	[1.0000, 4.5000, 5.0000]
#  ang
# [4.3240 - 9.3400]	Ses05M_script03_2_M000	xxx	[3.5000, 4.0000, 4.0000]
#  xxx
# [10.4400 - 13.7100]	Ses05M_script03_2_M001	xxx	[2.0000, 3.5000, 3.5000]
#  xxx
# [15.0600 - 18.9800]	Ses05M_script03_2_M002	xxx	[2.0000, 4.0000, 4.0000]
#  xxx
# [21.1100 - 25.4000]	Ses05M_script03_2_M003	xxx	[2.5000, 3.5000, 4.0000]
#  xxx
# [29.7800 - 32.9700]	Ses05M_script03_2_M004	fru	[2.5000, 3.5000, 3.5000]
#  fru
# [34.8500 - 37.6200]	Ses05M_script03_2_M005	fru	[2.0000, 4.0000, 4.0000]
#  fru
# [38.2400 - 39.8900]	Ses05M_script03_2_M006	xxx	[1.5000, 3.5000, 4.0000]
#  xxx
# [41.8900 - 43.7700]	Ses05M_script03_2_M007	xxx	[2.0000, 4.0000, 4.0000]
#  xxx
# [46.3500 - 49.2000]	Ses05M_script03_2_M008	ang	[1.5000, 4.0000, 4.5000]
#  ang
# [50.7000 - 52.9500]	Ses05M_script03_2_M009	ang	[2.0000, 3.5000, 4.0000]
#  ang
# [54.1500 - 56.0400]	Ses05M_script03_2_M010	neu	[3.0000, 2.5000, 2.0000]
#  neu
# [57.2500 - 59.1300]	Ses05M_script03_2_M011	neu	[3.0000, 3.5000, 3.0000]
#  neu
# [62.2700 - 65.9300]	Ses05M_script03_2_M012	xxx	[3.0000, 3.0000, 3.5000]
#  xxx
# [68.3600 - 77.7000]	Ses05M_script03_2_M013	xxx	[2.0000, 3.5000, 4.0000]
#  xxx
# [78.8500 - 83.0000]	Ses05M_script03_2_M014	xxx	[1.5000, 3.5000, 4.0000]
#  xxx
# [84.0600 - 86.0600]	Ses05M_script03_2_M015	ang	[1.5000, 3.0000, 3.5000]
#  ang
# [87.0900 - 92.7300]	Ses05M_script03_2_M016	fru	[2.5000, 3.0000, 3.0000]
#  fru
# [94.5500 - 98.9600]	Ses05M_script03_2_M017	fru	[4.0000, 3.0000, 3.0000]
#  fru
# [101.8100 - 103.9800]	Ses05M_script03_2_M018	xxx	[3.5000, 3.0000, 3.0000]
#  xxx
# [104.0100 - 105.1900]	Ses05M_script03_2_M019	xxx	[2.5000, 3.0000, 3.5000]
#  xxx
# [107.9400 - 113.2900]	Ses05M_script03_2_M020	ang	[2.5000, 3.0000, 3.5000]
#  ang
# [115.3900 - 117.7900]	Ses05M_script03_2_M021	xxx	[2.0000, 3.5000, 4.0000]
#  xxx
# [118.8300 - 122.3300]	Ses05M_script03_2_M022	fru	[1.5000, 3.5000, 4.0000]
#  fru
# [122.3400 - 123.5900]	Ses05M_script03_2_M023	ang	[1.5000, 4.0000, 4.5000]
#  ang
# [129.4400 - 136.1000]	Ses05M_script03_2_M024	neu	[2.5000, 3.0000, 4.0000]
#  neu
# [136.8800 - 141.2000]	Ses05M_script03_2_M025	ang	[3.5000, 3.0000, 3.5000]
#  ang
# [141.9200 - 149.3500]	Ses05M_script03_2_M026	ang	[1.5000, 4.0000, 4.5000]
#  ang
# [150.7700 - 153.7600]	Ses05M_script03_2_M027	ang	[2.0000, 3.5000, 4.5000]
#  ang
# [154.3900 - 162.3300]	Ses05M_script03_2_M028	ang	[1.5000, 4.0000, 5.0000]
#  ang
# [165.2600 - 169.8100]	Ses05M_script03_2_M029	ang	[2.0000, 4.5000, 4.5000]
#  ang
# [172.0500 - 177.6500]	Ses05M_script03_2_M030	ang	[2.0000, 5.0000, 4.5000]
#  ang
# [179.6000 - 183.2400]	Ses05M_script03_2_M031	ang	[1.5000, 4.0000, 4.5000]
#  ang
# [186.8900 - 188.9900]	Ses05M_script03_2_M032	ang	[2.0000, 3.5000, 3.5000]
#  ang
# [190.3300 - 193.9600]	Ses05M_script03_2_M033	ang	[2.5000, 3.5000, 3.5000]
#  ang
# [196.1700 - 198.6600]	Ses05M_script03_2_M034	ang	[2.5000, 3.5000, 3.5000]
#  ang
# [198.8600 - 201.7200]	Ses05M_script03_2_M035	ang	[2.0000, 3.5000, 4.0000]
#  ang
# [203.0700 - 205.2300]	Ses05M_script03_2_M036	ang	[2.5000, 3.5000, 3.5000]
#  ang
# [210.8600 - 213.3600]	Ses05M_script03_2_M037	ang	[1.0000, 4.0000, 4.5000]
#  ang
# [214.7900 - 216.2300]	Ses05M_script03_2_M038	ang	[1.5000, 4.0000, 4.5000]
#  ang
# [218.8300 - 221.3700]	Ses05M_script03_2_M039	ang	[2.0000, 3.0000, 4.0000]
#  ang
# [227.4800 - 230.8500]	Ses05M_script03_2_M040	ang	[4.0000, 4.0000, 3.5000]
#  ang
# [236.5700 - 244.8300]	Ses05M_script03_2_M041	ang	[1.0000, 4.5000, 5.0000]
#  ang
# [244.8400 - 246.5800]	Ses05M_script03_2_M042	ang	[1.0000, 4.5000, 4.5000]
#  ang
# [246.5900 - 248.8300]	Ses05M_script03_2_M043	ang	[1.5000, 4.0000, 4.5000]
#  ang
# [255.8600 - 260.3300]	Ses05M_script03_2_M044	ang	[1.0000, 5.0000, 5.0000]
#  ang
# [260.3400 - 266.3500]	Ses05M_script03_2_M045	ang	[1.0000, 5.0000, 5.0000]
#  ang

# %% [markdown]
# #### 02-1 convert label category
# - angry : 0        ang(1103)
# - happy : 1       exc(1041), hap(595)
# - sad : 2          sad(1084)
# - neutral : 3     neu(1708)

# %%
lines = []
with open('../data/processed/IEMOCAP/label.csv') as f :
    csv_reader = csv.reader(f)
    lines = [x for x in csv_reader]

# %%
with open('../data/processed/IEMOCAP/processed_label.txt', 'w') as f:
    
    with open('../data/processed/IEMOCAP/processed_ids.txt', 'w') as f2:
    
        for line in lines:
            if line[1] == 'ang':
                f.write('0\n')
                f2.write(line[0]+'\n')
            elif line[1] == 'hap':
                f.write('1\n')
                f2.write(line[0]+'\n')
            elif line[1] == 'exc':
                f.write('1\n')
                f2.write(line[0]+'\n')
            elif line[1] == 'sad':
                f.write('2\n')
                f2.write(line[0]+'\n')
            elif line[1] == 'neu':
                f.write('3\n')
                f2.write(line[0]+'\n')
            else :
                f.write('-1\n')

# %%
lines = []
with open('../data/processed/IEMOCAP/processed_label.txt') as f :
    lines = f.readlines()
lines = [x.strip() for x in lines]

print(len([x for x in lines if x=='0']))
print(len([x for x in lines if x=='1']))
print(len([x for x in lines if x=='2']))
print(len([x for x in lines if x=='3']))
# Out:
# 1103
# 1636
# 1084
# 1708

# %% [markdown]
# ## 03 verify

# %%
import csv

# %%
in_file = '../data/processed/IEMOCAP/processed_label.txt'
label = []
with open( in_file, 'r') as f:
    label = f.readlines()
    
label_id = [ x.strip() for x in label ]

# %%
in_file = '../data/processed/IEMOCAP/label.csv'
label = []
with open( in_file, 'r') as f:
    csv_reader = csv.reader( f )
    label = [x for x in csv_reader]
    
label_id = [ x[0] for x in label]

# %%
in_file = '../data/processed/IEMOCAP/processed_tran.csv'
tran = []
with open( in_file, 'r') as f:
    csv_reader = csv.reader( f )
    tran = [x for x in csv_reader]
    
tran_id = [ x[0] for x in tran]

# %%
for l, t in zip(label_id, tran_id):
    if l != t:
        print('ERROR')

# %% [markdown]
# ## 04 statistics

# %%
import numpy as np

# %%
in_file = '../data/processed/IEMOCAP/label.csv'
label = []
with open( in_file, 'r') as f:
    csv_reader = csv.reader( f )
    label = [x for x in csv_reader]
    
label_cat = [ x[1] for x in label]

# %%
count = np.zeros( len(category), dtype=np.int )

for cat in label_cat:
    count[ category[cat] ] = count[ category[cat] ] + 1

# %%
for key in category.keys():
    print(key + '\t:' + str(count[ category[key] ]))
# Out:
# ang	:1103
# hap	:595
# sad	:1084
# neu	:1708
# fru	:1849
# exc	:1041
# fea	:40
# sur	:107
# dis	:2
# oth	:3
# xxx	:2507
